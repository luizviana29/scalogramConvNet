# %%
# !pip install tensorflow==2.5.0
# !pip install numpy==1.20.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
shutil.copy2("/content/drive/MyDrive/utilities.py", "/content/utilities.py")
shutil.copy2("/content/drive/MyDrive/ConvNet.py", "/content/ConvNet.py")
shutil.copy2("/content/drive/MyDrive/config.py", "/content/config.py")
# Out:
# '/content/config.py'

# %%
import ConvNet
import config
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.utils import to_categorical
from tensorflow.data import AUTOTUNE
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import argparse
import os
import numpy as np
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MultiLabelBinarizer
from IPython.display import Audio, clear_output, display
from glob import glob
import random
from utilities import acuracia0, acuracia1, acuracia2
import utilities

# %%
model = ConvNet.ConvNet

# %%
model.summary()

# %% [markdown]
# # k=1

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/treino1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/teste1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/validation1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino1")
VAL_DATASET = os.path.join("/content", "validation1")
TEST_DATASET = os.path.join("/content", "teste1")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7060, 40, 256, 1)
# (883, 40, 256, 1)
# (7060,)
# (883,)
# (883,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 41s - loss: 5.2163 - accuracy: 0.0156
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0805s vs `on_train_batch_end` time: 0.2627s). Check your callbacks.
# 111/111 [==============================] - 9s 76ms/step
# Train - Acurácia 0:  0.18909348441926346
# Train - Acurácia 2:  0.443342776203966
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.159682899207248
# validation - Acurácia 2:  0.44280860702151753
# 111/111 [==============================] - 80s 571ms/step - loss: 4.0119 - accuracy: 0.1864 - val_loss: 4.9426 - val_accuracy: 0.1597
# Epoch 2/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.271671388101983
# Train - Acurácia 2:  0.5589235127478753
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.23556058890147225
# validation - Acurácia 2:  0.5673839184597962
# 111/111 [==============================] - 61s 548ms/step - loss: 2.9251 - accuracy: 0.3153 - val_loss: 3.5958 - val_accuracy: 0.2356
# Epoch 3/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.30269121813031163
# Train - Acurácia 2:  0.7110481586402266
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.27746319365798416
# validation - Acurácia 2:  0.6998867497168743
# 111/111 [==============================] - 60s 542ms/step - loss: 2.5115 - accuracy: 0.3773 - val_loss: 2.9540 - val_accuracy: 0.2775
# Epoch 4/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.3902266288951841
# Train - Acurácia 2:  0.7514164305949008
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.34428086070215175
# validation - Acurácia 2:  0.7406568516421291
# 111/111 [==============================] - 60s 545ms/step - loss: 2.3029 - accuracy: 0.4152 - val_loss: 2.7696 - val_accuracy: 0.3443
# Epoch 5/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4671388101983003
# Train - Acurácia 2:  0.8365439093484419
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.41676104190260477
# validation - Acurácia 2:  0.8210645526613817
# 111/111 [==============================] - 60s 545ms/step - loss: 2.0789 - accuracy: 0.4550 - val_loss: 2.2296 - val_accuracy: 0.4168
# Epoch 6/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.40609065155807367
# Train - Acurácia 2:  0.794900849858357
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.36919592298980747
# validation - Acurácia 2:  0.7995469988674971
# 111/111 [==============================] - 60s 544ms/step - loss: 1.9425 - accuracy: 0.4779 - val_loss: 2.4042 - val_accuracy: 0.3692
# Epoch 7/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.43725212464589236
# Train - Acurácia 2:  0.8613314447592068
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.3884484711211778
# validation - Acurácia 2:  0.8459796149490374
# 111/111 [==============================] - 60s 543ms/step - loss: 1.8481 - accuracy: 0.4914 - val_loss: 2.2387 - val_accuracy: 0.3884
# Epoch 8/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.48810198300283286
# Train - Acurácia 2:  0.8763456090651558
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.43827859569648925
# validation - Acurácia 2:  0.8720271800679502
# 111/111 [==============================] - 60s 545ms/step - loss: 1.7431 - accuracy: 0.5113 - val_loss: 2.1273 - val_accuracy: 0.4383
# Epoch 9/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.508356940509915
# Train - Acurácia 2:  0.88342776203966
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.43827859569648925
# validation - Acurácia 2:  0.8425821064552661
# 111/111 [==============================] - 60s 542ms/step - loss: 1.6854 - accuracy: 0.5266 - val_loss: 2.0771 - val_accuracy: 0.4383
# Epoch 10/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5460339943342776
# Train - Acurácia 2:  0.8998583569405099
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4575311438278596
# validation - Acurácia 2:  0.8527746319365799
# 111/111 [==============================] - 60s 542ms/step - loss: 1.5838 - accuracy: 0.5445 - val_loss: 2.0144 - val_accuracy: 0.4575
# Epoch 11/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.5786118980169972
# Train - Acurácia 2:  0.9259206798866856
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46206115515288787
# validation - Acurácia 2:  0.8958097395243488
# 111/111 [==============================] - 60s 543ms/step - loss: 1.4910 - accuracy: 0.5661 - val_loss: 1.8933 - val_accuracy: 0.4621
# Epoch 12/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.5511331444759207
# Train - Acurácia 2:  0.8977337110481587
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47451868629671573
# validation - Acurácia 2:  0.8720271800679502
# 111/111 [==============================] - 60s 542ms/step - loss: 1.3988 - accuracy: 0.5833 - val_loss: 2.0425 - val_accuracy: 0.4745
# Epoch 13/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.6288951841359773
# Train - Acurácia 2:  0.9467422096317281
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49377123442808607
# validation - Acurácia 2:  0.8980747451868629
# 111/111 [==============================] - 60s 543ms/step - loss: 1.3267 - accuracy: 0.5956 - val_loss: 1.8277 - val_accuracy: 0.4938
# Epoch 14/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6558073654390935
# Train - Acurácia 2:  0.9556657223796033
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4971687429218573
# validation - Acurácia 2:  0.9241223103057757
# 111/111 [==============================] - 60s 544ms/step - loss: 1.2321 - accuracy: 0.6272 - val_loss: 1.8362 - val_accuracy: 0.4972
# Epoch 15/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6460339943342777
# Train - Acurácia 2:  0.9405099150141643
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4801812004530011
# validation - Acurácia 2:  0.8856172140430351
# 111/111 [==============================] - 60s 544ms/step - loss: 1.1657 - accuracy: 0.6384 - val_loss: 1.9862 - val_accuracy: 0.4802
# Epoch 16/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.6424929178470254
# Train - Acurácia 2:  0.9541076487252125
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4801812004530011
# validation - Acurácia 2:  0.9014722536806342
# 111/111 [==============================] - 60s 541ms/step - loss: 1.0947 - accuracy: 0.6554 - val_loss: 1.9847 - val_accuracy: 0.4802
# Epoch 17/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6977337110481586
# Train - Acurácia 2:  0.9647308781869688
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4983012457531144
# validation - Acurácia 2:  0.9161947904869762
# 111/111 [==============================] - 60s 542ms/step - loss: 1.0106 - accuracy: 0.6792 - val_loss: 1.9236 - val_accuracy: 0.4983
# Epoch 18/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7229461756373937
# Train - Acurácia 2:  0.9635977337110482
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.49490373725934317
# validation - Acurácia 2:  0.8969422423556059
# 111/111 [==============================] - 60s 541ms/step - loss: 0.9446 - accuracy: 0.6976 - val_loss: 1.9421 - val_accuracy: 0.4949
# Epoch 19/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.7073654390934844
# Train - Acurácia 2:  0.9514164305949009
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4450736126840317
# validation - Acurácia 2:  0.8878822197055493
# 111/111 [==============================] - 60s 543ms/step - loss: 0.8761 - accuracy: 0.7248 - val_loss: 2.1548 - val_accuracy: 0.4451
# Epoch 20/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.781586402266289
# Train - Acurácia 2:  0.9735127478753541
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4971687429218573
# validation - Acurácia 2:  0.9003397508493771
# 111/111 [==============================] - 60s 541ms/step - loss: 0.7686 - accuracy: 0.7508 - val_loss: 1.9955 - val_accuracy: 0.4972
# Epoch 21/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7277620396600567
# Train - Acurácia 2:  0.940084985835694
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.46885617214043035
# validation - Acurácia 2:  0.8765571913929785
# 111/111 [==============================] - 60s 544ms/step - loss: 0.7264 - accuracy: 0.7704 - val_loss: 2.3711 - val_accuracy: 0.4689
# Epoch 22/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7845609065155807
# Train - Acurácia 2:  0.9603399433427762
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4813137032842582
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 60s 542ms/step - loss: 0.6847 - accuracy: 0.7822 - val_loss: 2.2354 - val_accuracy: 0.4813
# Epoch 23/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8011331444759207
# Train - Acurácia 2:  0.9713881019830028
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4869762174405436
# validation - Acurácia 2:  0.8946772366930917
# 111/111 [==============================] - 60s 544ms/step - loss: 0.6072 - accuracy: 0.8110 - val_loss: 2.2689 - val_accuracy: 0.4870
# Epoch 24/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8624645892351275
# Train - Acurácia 2:  0.9838526912181303
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5096262740656852
# validation - Acurácia 2:  0.9014722536806342
# 111/111 [==============================] - 60s 541ms/step - loss: 0.5290 - accuracy: 0.8331 - val_loss: 2.3013 - val_accuracy: 0.5096
# Epoch 25/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8327195467422096
# Train - Acurácia 2:  0.9764872521246459
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49263873159682897
# validation - Acurácia 2:  0.8765571913929785
# 111/111 [==============================] - 60s 543ms/step - loss: 0.4934 - accuracy: 0.8455 - val_loss: 2.3527 - val_accuracy: 0.4926
# Epoch 26/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.81671388101983
# Train - Acurácia 2:  0.9756373937677054
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46885617214043035
# validation - Acurácia 2:  0.8912797281993206
# 111/111 [==============================] - 60s 542ms/step - loss: 0.4498 - accuracy: 0.8595 - val_loss: 2.3353 - val_accuracy: 0.4689
# Epoch 27/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8936260623229462
# Train - Acurácia 2:  0.9903682719546743
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5107587768969423
# validation - Acurácia 2:  0.9082672706681767
# 111/111 [==============================] - 60s 543ms/step - loss: 0.4382 - accuracy: 0.8619 - val_loss: 2.3980 - val_accuracy: 0.5108
# Epoch 28/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8980169971671388
# Train - Acurácia 2:  0.989943342776204
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5062287655719139
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 60s 540ms/step - loss: 0.4010 - accuracy: 0.8721 - val_loss: 2.3875 - val_accuracy: 0.5062
# Epoch 29/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8487252124645892
# Train - Acurácia 2:  0.9825779036827196
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49037372593431483
# validation - Acurácia 2:  0.8946772366930917
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3967 - accuracy: 0.8690 - val_loss: 2.6293 - val_accuracy: 0.4904
# Epoch 30/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8862606232294618
# Train - Acurácia 2:  0.989943342776204
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5107587768969423
# validation - Acurácia 2:  0.9014722536806342
# 111/111 [==============================] - 60s 542ms/step - loss: 0.3712 - accuracy: 0.8805 - val_loss: 2.5011 - val_accuracy: 0.5108
# Epoch 31/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8796033994334278
# Train - Acurácia 2:  0.9875354107648725
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.48357870894677235
# validation - Acurácia 2:  0.8912797281993206
# 111/111 [==============================] - 60s 541ms/step - loss: 0.3487 - accuracy: 0.8891 - val_loss: 2.5006 - val_accuracy: 0.4836
# Epoch 32/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8713881019830029
# Train - Acurácia 2:  0.9779036827195468
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4722536806342016
# validation - Acurácia 2:  0.883352208380521
# 111/111 [==============================] - 60s 541ms/step - loss: 0.3120 - accuracy: 0.8976 - val_loss: 2.6792 - val_accuracy: 0.4723
# Epoch 33/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.920113314447592
# Train - Acurácia 2:  0.9902266288951841
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5379388448471121
# validation - Acurácia 2:  0.9093997734994338
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2891 - accuracy: 0.9081 - val_loss: 2.6259 - val_accuracy: 0.5379
# Epoch 34/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9134560906515581
# Train - Acurácia 2:  0.9929178470254958
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4960362400906002
# validation - Acurácia 2:  0.9026047565118913
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2829 - accuracy: 0.9055 - val_loss: 2.7287 - val_accuracy: 0.4960
# Epoch 35/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9260623229461756
# Train - Acurácia 2:  0.9917847025495751
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5107587768969423
# validation - Acurácia 2:  0.8958097395243488
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2701 - accuracy: 0.9112 - val_loss: 2.6873 - val_accuracy: 0.5108
# Epoch 36/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9372521246458924
# Train - Acurácia 2:  0.9973087818696884
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5379388448471121
# validation - Acurácia 2:  0.89920724801812
# 111/111 [==============================] - 60s 540ms/step - loss: 0.2537 - accuracy: 0.9142 - val_loss: 2.6166 - val_accuracy: 0.5379
# Epoch 37/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9067988668555241
# Train - Acurácia 2:  0.9910764872521246
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47565118912797283
# validation - Acurácia 2:  0.8776896942242356
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2950 - accuracy: 0.8989 - val_loss: 2.9211 - val_accuracy: 0.4757
# Epoch 38/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9269121813031161
# Train - Acurácia 2:  0.9922096317280453
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5254813137032842
# validation - Acurácia 2:  0.8946772366930917
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2503 - accuracy: 0.9146 - val_loss: 2.7582 - val_accuracy: 0.5255
# Epoch 39/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9267705382436261
# Train - Acurácia 2:  0.9953257790368272
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4869762174405436
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2384 - accuracy: 0.9170 - val_loss: 2.8399 - val_accuracy: 0.4870
# Epoch 40/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.931586402266289
# Train - Acurácia 2:  0.9960339943342776
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5311438278595696
# validation - Acurácia 2:  0.9060022650056625
# 111/111 [==============================] - 60s 541ms/step - loss: 0.2494 - accuracy: 0.9135 - val_loss: 2.6941 - val_accuracy: 0.5311
# Epoch 41/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9290368271954674
# Train - Acurácia 2:  0.9947592067988669
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5186862967157417
# validation - Acurácia 2:  0.8924122310305775
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2345 - accuracy: 0.9186 - val_loss: 2.8956 - val_accuracy: 0.5187
# Epoch 42/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9266288951841359
# Train - Acurácia 2:  0.989943342776204
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5062287655719139
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2190 - accuracy: 0.9224 - val_loss: 2.8077 - val_accuracy: 0.5062
# Epoch 43/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9240793201133144
# Train - Acurácia 2:  0.993342776203966
# 14/14 [==============================] - 1s 82ms/step
# Validation - Acurácia 0:  0.5152887882219706
# validation - Acurácia 2:  0.8969422423556059
# 111/111 [==============================] - 62s 557ms/step - loss: 0.2232 - accuracy: 0.9193 - val_loss: 2.9736 - val_accuracy: 0.5153
# Epoch 44/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8998583569405099
# Train - Acurácia 2:  0.9929178470254958
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47904869762174407
# validation - Acurácia 2:  0.8844847112117781
# 111/111 [==============================] - 60s 541ms/step - loss: 0.2337 - accuracy: 0.9143 - val_loss: 2.8774 - val_accuracy: 0.4790
# Epoch 45/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9155807365439094
# Train - Acurácia 2:  0.9930594900849858
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.49943374858437145
# validation - Acurácia 2:  0.8912797281993206
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2388 - accuracy: 0.9153 - val_loss: 2.9557 - val_accuracy: 0.4994
# Epoch 46/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9361189801699716
# Train - Acurácia 2:  0.9944759206798867
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5130237825594564
# validation - Acurácia 2:  0.8856172140430351
# 111/111 [==============================] - 60s 541ms/step - loss: 0.2226 - accuracy: 0.9163 - val_loss: 2.8923 - val_accuracy: 0.5130
# Epoch 47/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9395184135977337
# Train - Acurácia 2:  0.9968838526912182
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5345413363533409
# validation - Acurácia 2:  0.9003397508493771
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2024 - accuracy: 0.9248 - val_loss: 2.8886 - val_accuracy: 0.5345
# Epoch 48/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9341359773371105
# Train - Acurácia 2:  0.9951841359773371
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5209513023782559
# validation - Acurácia 2:  0.8856172140430351
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2329 - accuracy: 0.9174 - val_loss: 2.9226 - val_accuracy: 0.5210
# Epoch 49/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9093484419263456
# Train - Acurácia 2:  0.9926345609065156
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5028312570781427
# validation - Acurácia 2:  0.8924122310305775
# 111/111 [==============================] - 60s 541ms/step - loss: 0.2278 - accuracy: 0.9171 - val_loss: 2.8878 - val_accuracy: 0.5028
# Epoch 50/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9220963172804533
# Train - Acurácia 2:  0.9954674220963173
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.48584371460928655
# validation - Acurácia 2:  0.9003397508493771
# 111/111 [==============================] - 60s 541ms/step - loss: 0.2090 - accuracy: 0.9262 - val_loss: 2.9032 - val_accuracy: 0.4858
# CPU times: user 52min 44s, sys: 1min 38s, total: 54min 22s
# Wall time: 50min 26s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'1')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k1'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k1',acc)
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_'+'k1',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k1')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k1')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 9s 77ms/step
# (7060, 140)
# (7060,)
# (7060,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento shan_6 k=1', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_train_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_shan_6_k=1'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_shan_6_k=1    0.922096    0.994476     0.995467

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 77ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação shan_6 k=1', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_validation_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_shan_6_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=1    0.922096    0.994476     0.995467
# 1  validation_shan_6_k=1    0.485844    0.861835     0.900340

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 77ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste shan_6 k=1', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_test_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_shan_6_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=1    0.922096    0.994476     0.995467
# 1  validation_shan_6_k=1    0.485844    0.861835     0.900340
# 2        test_shan_6_k=1    0.500566    0.844847     0.877690

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/shan_6_kfold/Resultados_shan_6_k1.xlsx", index=False)

# %% [markdown]
# # k=2

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/treino2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/teste2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/validation2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino2")
VAL_DATASET = os.path.join("/content", "validation2")
TEST_DATASET = os.path.join("/content", "teste2")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 45s - loss: 5.1505 - accuracy: 0.0182
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0862s vs `on_train_batch_end` time: 0.2880s). Check your callbacks.
# 111/111 [==============================] - 9s 76ms/step
# Train - Acurácia 0:  0.1411781365052393
# Train - Acurácia 2:  0.42834890965732086
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.14625850340136054
# validation - Acurácia 2:  0.41950113378684806
# 111/111 [==============================] - 77s 599ms/step - loss: 3.9725 - accuracy: 0.1895 - val_loss: 11.8427 - val_accuracy: 0.1463
# Epoch 2/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.11342395921835174
# Train - Acurácia 2:  0.22429906542056074
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.10430839002267574
# validation - Acurácia 2:  0.20521541950113378
# 111/111 [==============================] - 60s 544ms/step - loss: 2.9626 - accuracy: 0.3044 - val_loss: 6.6658 - val_accuracy: 0.1043
# Epoch 3/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.2609742282639479
# Train - Acurácia 2:  0.6091758708581139
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.264172335600907
# validation - Acurácia 2:  0.5986394557823129
# 111/111 [==============================] - 60s 541ms/step - loss: 2.5571 - accuracy: 0.3658 - val_loss: 3.7409 - val_accuracy: 0.2642
# Epoch 4/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.04078164825828377
# Train - Acurácia 2:  0.2068819031435854
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.04195011337868481
# validation - Acurácia 2:  0.18480725623582767
# 111/111 [==============================] - 60s 543ms/step - loss: 2.3648 - accuracy: 0.3949 - val_loss: 8.5220 - val_accuracy: 0.0420
# Epoch 5/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.22783913905409234
# Train - Acurácia 2:  0.5007080147267063
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.2199546485260771
# validation - Acurácia 2:  0.49206349206349204
# 111/111 [==============================] - 60s 545ms/step - loss: 2.1898 - accuracy: 0.4268 - val_loss: 4.4341 - val_accuracy: 0.2200
# Epoch 6/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.32710280373831774
# Train - Acurácia 2:  0.6236193712829227
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.30385487528344673
# validation - Acurácia 2:  0.5895691609977324
# 111/111 [==============================] - 60s 544ms/step - loss: 2.0709 - accuracy: 0.4446 - val_loss: 3.3443 - val_accuracy: 0.3039
# Epoch 7/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.40923251203625033
# Train - Acurácia 2:  0.8031719059756443
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.36281179138321995
# validation - Acurácia 2:  0.7653061224489796
# 111/111 [==============================] - 60s 543ms/step - loss: 1.9371 - accuracy: 0.4734 - val_loss: 2.4956 - val_accuracy: 0.3628
# Epoch 8/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.47904276408949303
# Train - Acurácia 2:  0.8586802605494195
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.42630385487528344
# validation - Acurácia 2:  0.828798185941043
# 111/111 [==============================] - 60s 542ms/step - loss: 1.8627 - accuracy: 0.4894 - val_loss: 2.1681 - val_accuracy: 0.4263
# Epoch 9/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.4966015293118097
# Train - Acurácia 2:  0.90470121778533
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4331065759637188
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 60s 542ms/step - loss: 1.7620 - accuracy: 0.5089 - val_loss: 2.1179 - val_accuracy: 0.4331
# Epoch 10/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5216652506372133
# Train - Acurácia 2:  0.9150382327952421
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4421768707482993
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 60s 541ms/step - loss: 1.6481 - accuracy: 0.5263 - val_loss: 2.0935 - val_accuracy: 0.4422
# Epoch 11/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.5676862078731237
# Train - Acurácia 2:  0.921976777116964
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 542ms/step - loss: 1.5715 - accuracy: 0.5433 - val_loss: 1.9472 - val_accuracy: 0.4603
# Epoch 12/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.18323421127159445
# Train - Acurácia 2:  0.7040498442367601
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.14285714285714285
# validation - Acurácia 2:  0.671201814058957
# 111/111 [==============================] - 60s 542ms/step - loss: 1.5181 - accuracy: 0.5555 - val_loss: 3.3631 - val_accuracy: 0.1429
# Epoch 13/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5835457377513452
# Train - Acurácia 2:  0.9325969980175588
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 60s 541ms/step - loss: 1.4676 - accuracy: 0.5607 - val_loss: 2.0630 - val_accuracy: 0.4717
# Epoch 14/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.5988388558482016
# Train - Acurácia 2:  0.9418011894647409
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4501133786848073
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 60s 541ms/step - loss: 1.3618 - accuracy: 0.5901 - val_loss: 2.0040 - val_accuracy: 0.4501
# Epoch 15/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.6292834890965732
# Train - Acurácia 2:  0.949447748513169
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.45918367346938777
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 541ms/step - loss: 1.2756 - accuracy: 0.6120 - val_loss: 2.0896 - val_accuracy: 0.4592
# Epoch 16/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.6251770036816766
# Train - Acurácia 2:  0.9256584536958369
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 60s 541ms/step - loss: 1.2257 - accuracy: 0.6243 - val_loss: 2.0834 - val_accuracy: 0.4728
# Epoch 17/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6578872840555083
# Train - Acurácia 2:  0.9418011894647409
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46485260770975056
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 60s 542ms/step - loss: 1.1161 - accuracy: 0.6529 - val_loss: 2.0939 - val_accuracy: 0.4649
# Epoch 18/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5829793259699801
# Train - Acurácia 2:  0.933305012744265
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.3820861678004535
# validation - Acurácia 2:  0.8571428571428571
# 111/111 [==============================] - 60s 541ms/step - loss: 1.0788 - accuracy: 0.6570 - val_loss: 2.3480 - val_accuracy: 0.3821
# Epoch 19/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.6804021523647692
# Train - Acurácia 2:  0.9627584253752478
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4331065759637188
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 60s 541ms/step - loss: 0.9850 - accuracy: 0.6883 - val_loss: 2.2982 - val_accuracy: 0.4331
# Epoch 20/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.7183517417162277
# Train - Acurácia 2:  0.9651656754460493
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4614512471655329
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 541ms/step - loss: 0.9231 - accuracy: 0.7043 - val_loss: 2.2665 - val_accuracy: 0.4615
# Epoch 21/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.7652223166241858
# Train - Acurácia 2:  0.9660152931180969
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 541ms/step - loss: 0.8494 - accuracy: 0.7294 - val_loss: 2.2423 - val_accuracy: 0.5000
# Epoch 22/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.7766921551968281
# Train - Acurácia 2:  0.9706881903143585
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 60s 541ms/step - loss: 0.7476 - accuracy: 0.7576 - val_loss: 2.3565 - val_accuracy: 0.4875
# Epoch 23/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.7740016992353441
# Train - Acurácia 2:  0.9527046162560181
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4467120181405896
# validation - Acurácia 2:  0.8594104308390023
# 111/111 [==============================] - 60s 542ms/step - loss: 0.6850 - accuracy: 0.7815 - val_loss: 2.3808 - val_accuracy: 0.4467
# Epoch 24/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.7969413763806287
# Train - Acurácia 2:  0.9745114698385726
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 542ms/step - loss: 0.6506 - accuracy: 0.7926 - val_loss: 2.5404 - val_accuracy: 0.4796
# Epoch 25/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8415463041631266
# Train - Acurácia 2:  0.9815916171056358
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.46485260770975056
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 541ms/step - loss: 0.6149 - accuracy: 0.8012 - val_loss: 2.4468 - val_accuracy: 0.4649
# Epoch 26/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8197394505805721
# Train - Acurácia 2:  0.9678561314075332
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46485260770975056
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 540ms/step - loss: 0.5505 - accuracy: 0.8243 - val_loss: 2.7328 - val_accuracy: 0.4649
# Epoch 27/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8442367601246106
# Train - Acurácia 2:  0.9745114698385726
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 541ms/step - loss: 0.5222 - accuracy: 0.8366 - val_loss: 2.6002 - val_accuracy: 0.4773
# Epoch 28/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8639195695270462
# Train - Acurácia 2:  0.9723874256584537
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 60s 542ms/step - loss: 0.4762 - accuracy: 0.8489 - val_loss: 2.6490 - val_accuracy: 0.4830
# Epoch 29/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8802039082412915
# Train - Acurácia 2:  0.9878221467006514
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 541ms/step - loss: 0.4491 - accuracy: 0.8574 - val_loss: 2.6545 - val_accuracy: 0.4989
# Epoch 30/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8735485698102521
# Train - Acurácia 2:  0.9766355140186916
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 540ms/step - loss: 0.4030 - accuracy: 0.8724 - val_loss: 2.7734 - val_accuracy: 0.4683
# Epoch 31/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9191447182101388
# Train - Acurácia 2:  0.9902293967714528
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3549 - accuracy: 0.8871 - val_loss: 2.6745 - val_accuracy: 0.5147
# Epoch 32/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9173038799207024
# Train - Acurácia 2:  0.9922118380062306
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 540ms/step - loss: 0.3301 - accuracy: 0.8990 - val_loss: 2.8497 - val_accuracy: 0.4887
# Epoch 33/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.90470121778533
# Train - Acurácia 2:  0.985981308411215
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46258503401360546
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 539ms/step - loss: 0.3322 - accuracy: 0.8920 - val_loss: 2.8432 - val_accuracy: 0.4626
# Epoch 34/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9048428207306712
# Train - Acurácia 2:  0.9876805437553101
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 60s 540ms/step - loss: 0.3438 - accuracy: 0.8924 - val_loss: 2.9024 - val_accuracy: 0.4875
# Epoch 35/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9218351741716228
# Train - Acurácia 2:  0.9926366468422543
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 540ms/step - loss: 0.3364 - accuracy: 0.8912 - val_loss: 2.7874 - val_accuracy: 0.4955
# Epoch 36/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9310393656188048
# Train - Acurácia 2:  0.9939110733503257
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 541ms/step - loss: 0.2851 - accuracy: 0.9054 - val_loss: 2.8684 - val_accuracy: 0.5000
# Epoch 37/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9199943358821864
# Train - Acurácia 2:  0.9895213820447465
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2926 - accuracy: 0.9012 - val_loss: 3.1383 - val_accuracy: 0.4932
# Epoch 38/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8916737468139337
# Train - Acurácia 2:  0.9837156612857547
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 540ms/step - loss: 0.2898 - accuracy: 0.9027 - val_loss: 3.2114 - val_accuracy: 0.4660
# Epoch 39/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9252336448598131
# Train - Acurácia 2:  0.994052676295667
# 14/14 [==============================] - 1s 83ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 62s 555ms/step - loss: 0.2591 - accuracy: 0.9167 - val_loss: 3.1722 - val_accuracy: 0.4887
# Epoch 40/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9338714245256301
# Train - Acurácia 2:  0.9957519116397621
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2450 - accuracy: 0.9162 - val_loss: 3.0777 - val_accuracy: 0.4955
# Epoch 41/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.937553101104503
# Train - Acurácia 2:  0.9960351175304446
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 60s 540ms/step - loss: 0.2371 - accuracy: 0.9208 - val_loss: 3.0645 - val_accuracy: 0.5113
# Epoch 42/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8225715094873973
# Train - Acurácia 2:  0.9653072783913905
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4126984126984127
# validation - Acurácia 2:  0.8514739229024944
# 111/111 [==============================] - 60s 539ms/step - loss: 0.2502 - accuracy: 0.9143 - val_loss: 3.3148 - val_accuracy: 0.4127
# Epoch 43/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9236760124610592
# Train - Acurácia 2:  0.9907958085528179
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 539ms/step - loss: 0.3057 - accuracy: 0.8968 - val_loss: 3.1356 - val_accuracy: 0.4955
# Epoch 44/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.7652223166241858
# Train - Acurácia 2:  0.9534126309827244
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.35374149659863946
# validation - Acurácia 2:  0.8401360544217688
# 111/111 [==============================] - 60s 540ms/step - loss: 0.2472 - accuracy: 0.9123 - val_loss: 3.5158 - val_accuracy: 0.3537
# Epoch 45/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9338714245256301
# Train - Acurácia 2:  0.9937694704049844
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 60s 540ms/step - loss: 0.2255 - accuracy: 0.9174 - val_loss: 3.0021 - val_accuracy: 0.4943
# Epoch 46/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9393939393939394
# Train - Acurácia 2:  0.9975927499291986
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 539ms/step - loss: 0.2139 - accuracy: 0.9220 - val_loss: 3.1926 - val_accuracy: 0.4864
# Epoch 47/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.9272160860945907
# Train - Acurácia 2:  0.992495043896913
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 540ms/step - loss: 0.2040 - accuracy: 0.9238 - val_loss: 3.3692 - val_accuracy: 0.4580
# Epoch 48/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9328802039082413
# Train - Acurácia 2:  0.9950438969130558
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 60s 539ms/step - loss: 0.2039 - accuracy: 0.9211 - val_loss: 3.2248 - val_accuracy: 0.5125
# Epoch 49/50
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.8432455395072217
# Train - Acurácia 2:  0.9648824695553667
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8514739229024944
# 111/111 [==============================] - 60s 539ms/step - loss: 0.1980 - accuracy: 0.9235 - val_loss: 3.5300 - val_accuracy: 0.4728
# Epoch 50/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9342962333616539
# Train - Acurácia 2:  0.994052676295667
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 60s 540ms/step - loss: 0.1912 - accuracy: 0.9262 - val_loss: 3.2698 - val_accuracy: 0.5057
# CPU times: user 52min 47s, sys: 1min 33s, total: 54min 20s
# Wall time: 50min 24s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'2')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k2'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k2',acc)
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_'+'k2',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k2')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k2')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 9s 77ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento shan_6 k=2', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_train_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_shan_6_k=2'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_shan_6_k=2    0.934296    0.991362     0.994053

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 77ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação shan_6 k=2', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_validation_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_shan_6_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=2    0.934296    0.991362     0.994053
# 1  validation_shan_6_k=2    0.505669    0.861678     0.886621

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 77ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste shan_6 k=2', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_test_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_shan_6_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=2    0.934296    0.991362     0.994053
# 1  validation_shan_6_k=2    0.505669    0.861678     0.886621
# 2        test_shan_6_k=2    0.521542    0.858277     0.887755

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/shan_6_kfold/Resultados_shan_6_k2.xlsx", index=False)

# %% [markdown]
# # k=3

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/treino3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/teste3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/validation3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino3")
VAL_DATASET = os.path.join("/content", "validation3")
TEST_DATASET = os.path.join("/content", "teste3")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.18465024072500708
# Train - Acurácia 2:  0.4597847635230813
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.17346938775510204
# validation - Acurácia 2:  0.4546485260770975
# 111/111 [==============================] - 30s 155ms/step - loss: 4.1551 - accuracy: 0.1614 - val_loss: 4.3340 - val_accuracy: 0.1735
# Epoch 2/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.1903143585386576
# Train - Acurácia 2:  0.5209572359105069
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.19160997732426305
# validation - Acurácia 2:  0.5238095238095238
# 111/111 [==============================] - 14s 131ms/step - loss: 3.0916 - accuracy: 0.2903 - val_loss: 3.9400 - val_accuracy: 0.1916
# Epoch 3/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.19555366751628434
# Train - Acurácia 2:  0.5004248088360238
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.1984126984126984
# validation - Acurácia 2:  0.4943310657596372
# 111/111 [==============================] - 14s 130ms/step - loss: 2.7553 - accuracy: 0.3304 - val_loss: 3.6901 - val_accuracy: 0.1984
# Epoch 4/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.3503256867742849
# Train - Acurácia 2:  0.7339280657037667
# 14/14 [==============================] - 0s 36ms/step
# Validation - Acurácia 0:  0.3378684807256236
# validation - Acurácia 2:  0.7426303854875284
# 111/111 [==============================] - 14s 129ms/step - loss: 2.4973 - accuracy: 0.3723 - val_loss: 2.6069 - val_accuracy: 0.3379
# Epoch 5/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.39238176154064003
# Train - Acurácia 2:  0.7595581988105352
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.35941043083900226
# validation - Acurácia 2:  0.7517006802721088
# 111/111 [==============================] - 14s 129ms/step - loss: 2.3106 - accuracy: 0.4119 - val_loss: 2.4444 - val_accuracy: 0.3594
# Epoch 6/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.43712829226847916
# Train - Acurácia 2:  0.8290852449730954
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.40476190476190477
# validation - Acurácia 2:  0.8106575963718821
# 111/111 [==============================] - 14s 128ms/step - loss: 2.1351 - accuracy: 0.4434 - val_loss: 2.1927 - val_accuracy: 0.4048
# Epoch 7/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.4209855564995752
# Train - Acurácia 2:  0.7758425375247805
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.3934240362811791
# validation - Acurácia 2:  0.7687074829931972
# 111/111 [==============================] - 14s 129ms/step - loss: 2.0016 - accuracy: 0.4659 - val_loss: 2.3737 - val_accuracy: 0.3934
# Epoch 8/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.4658736901727556
# Train - Acurácia 2:  0.8503256867742849
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.41383219954648526
# validation - Acurácia 2:  0.8231292517006803
# 111/111 [==============================] - 14s 128ms/step - loss: 1.8773 - accuracy: 0.4874 - val_loss: 2.1881 - val_accuracy: 0.4138
# Epoch 9/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.44151798357405836
# Train - Acurácia 2:  0.8494760691022373
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.3866213151927438
# validation - Acurácia 2:  0.8095238095238095
# 111/111 [==============================] - 14s 129ms/step - loss: 1.7774 - accuracy: 0.4992 - val_loss: 2.4154 - val_accuracy: 0.3866
# Epoch 10/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.5281789861229114
# Train - Acurácia 2:  0.9113565562163694
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 14s 127ms/step - loss: 1.6887 - accuracy: 0.5191 - val_loss: 2.0002 - val_accuracy: 0.4603
# Epoch 11/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5283205890682526
# Train - Acurácia 2:  0.9080996884735203
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4512471655328798
# validation - Acurácia 2:  0.8650793650793651
# 111/111 [==============================] - 14s 127ms/step - loss: 1.6148 - accuracy: 0.5334 - val_loss: 2.0269 - val_accuracy: 0.4512
# Epoch 12/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.5787312376097423
# Train - Acurácia 2:  0.9396771452846219
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4671201814058957
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 14s 129ms/step - loss: 1.5304 - accuracy: 0.5500 - val_loss: 1.8859 - val_accuracy: 0.4671
# Epoch 13/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.5897762673463608
# Train - Acurácia 2:  0.9289153214386859
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 128ms/step - loss: 1.4571 - accuracy: 0.5688 - val_loss: 1.9392 - val_accuracy: 0.4683
# Epoch 14/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.6077598414047012
# Train - Acurácia 2:  0.9538374398187482
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 14s 127ms/step - loss: 1.3546 - accuracy: 0.5899 - val_loss: 1.9156 - val_accuracy: 0.4785
# Epoch 15/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.6450014160294534
# Train - Acurácia 2:  0.9466156896063438
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.5170068027210885
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 14s 127ms/step - loss: 1.2936 - accuracy: 0.6015 - val_loss: 1.8081 - val_accuracy: 0.5170
# Epoch 16/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.602803738317757
# Train - Acurácia 2:  0.9154630416312659
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8514739229024944
# 111/111 [==============================] - 14s 128ms/step - loss: 1.2248 - accuracy: 0.6187 - val_loss: 2.0744 - val_accuracy: 0.4603
# Epoch 17/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.6015293118096856
# Train - Acurácia 2:  0.9011611441517984
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4070294784580499
# validation - Acurácia 2:  0.8197278911564626
# 111/111 [==============================] - 14s 128ms/step - loss: 1.1558 - accuracy: 0.6402 - val_loss: 2.2773 - val_accuracy: 0.4070
# Epoch 18/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.6896063438119513
# Train - Acurácia 2:  0.9535542339280657
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.5102040816326531
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 14s 129ms/step - loss: 1.0779 - accuracy: 0.6620 - val_loss: 1.9686 - val_accuracy: 0.5102
# Epoch 19/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.7074483149249504
# Train - Acurácia 2:  0.9602095723591051
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 14s 128ms/step - loss: 0.9942 - accuracy: 0.6832 - val_loss: 2.0913 - val_accuracy: 0.4785
# Epoch 20/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7523364485981309
# Train - Acurácia 2:  0.9723874256584537
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 14s 128ms/step - loss: 0.9236 - accuracy: 0.7072 - val_loss: 2.0945 - val_accuracy: 0.4864
# Epoch 21/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.7669215519682809
# Train - Acurácia 2:  0.9797507788161994
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 14s 127ms/step - loss: 0.8504 - accuracy: 0.7268 - val_loss: 2.1745 - val_accuracy: 0.4773
# Epoch 22/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.7285471537807986
# Train - Acurácia 2:  0.9578023222883036
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 14s 128ms/step - loss: 0.7796 - accuracy: 0.7499 - val_loss: 2.4492 - val_accuracy: 0.4785
# Epoch 23/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.74327386009629
# Train - Acurácia 2:  0.9606343811951289
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 14s 127ms/step - loss: 0.7201 - accuracy: 0.7689 - val_loss: 2.4760 - val_accuracy: 0.4603
# Epoch 24/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8149249504389692
# Train - Acurácia 2:  0.9818748229963183
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.46938775510204084
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 14s 128ms/step - loss: 0.6997 - accuracy: 0.7788 - val_loss: 2.4174 - val_accuracy: 0.4694
# Epoch 25/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8346077598414047
# Train - Acurácia 2:  0.9787595581988106
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 14s 128ms/step - loss: 0.6028 - accuracy: 0.8087 - val_loss: 2.3669 - val_accuracy: 0.4875
# Epoch 26/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8443783630699518
# Train - Acurácia 2:  0.9749362786745964
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 14s 127ms/step - loss: 0.5609 - accuracy: 0.8180 - val_loss: 2.4478 - val_accuracy: 0.4773
# Epoch 27/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8625035400736335
# Train - Acurácia 2:  0.9839988671764373
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.481859410430839
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 14s 127ms/step - loss: 0.5168 - accuracy: 0.8381 - val_loss: 2.4736 - val_accuracy: 0.4819
# Epoch 28/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8639195695270462
# Train - Acurácia 2:  0.9885301614273577
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 127ms/step - loss: 0.4459 - accuracy: 0.8607 - val_loss: 2.4417 - val_accuracy: 0.4875
# Epoch 29/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8785046728971962
# Train - Acurácia 2:  0.9854148966298499
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 14s 128ms/step - loss: 0.4241 - accuracy: 0.8659 - val_loss: 2.6470 - val_accuracy: 0.4898
# Epoch 30/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8976210705182668
# Train - Acurácia 2:  0.988671764372699
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 14s 128ms/step - loss: 0.4021 - accuracy: 0.8726 - val_loss: 2.6711 - val_accuracy: 0.4921
# Epoch 31/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.87892948173322
# Train - Acurácia 2:  0.9861229113565562
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 14s 128ms/step - loss: 0.3859 - accuracy: 0.8758 - val_loss: 2.7079 - val_accuracy: 0.4887
# Epoch 32/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8678844519966016
# Train - Acurácia 2:  0.9832908524497309
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.47392290249433106
# validation - Acurácia 2:  0.8594104308390023
# 111/111 [==============================] - 14s 128ms/step - loss: 0.3517 - accuracy: 0.8888 - val_loss: 2.9875 - val_accuracy: 0.4739
# Epoch 33/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.854148966298499
# Train - Acurácia 2:  0.9704049844236761
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 14s 128ms/step - loss: 0.3431 - accuracy: 0.8883 - val_loss: 2.9452 - val_accuracy: 0.4728
# Epoch 34/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9107901444350043
# Train - Acurácia 2:  0.9902293967714528
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 14s 128ms/step - loss: 0.3160 - accuracy: 0.8972 - val_loss: 2.7386 - val_accuracy: 0.5125
# Epoch 35/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9226847918436704
# Train - Acurácia 2:  0.9943358821863495
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2915 - accuracy: 0.9060 - val_loss: 2.7277 - val_accuracy: 0.5023
# Epoch 36/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.8963466440101954
# Train - Acurácia 2:  0.9855564995751912
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8605442176870748
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2773 - accuracy: 0.9050 - val_loss: 2.9040 - val_accuracy: 0.5011
# Epoch 37/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9153214386859246
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 14s 128ms/step - loss: 0.2781 - accuracy: 0.9065 - val_loss: 2.8866 - val_accuracy: 0.4932
# Epoch 38/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9335882186349476
# Train - Acurácia 2:  0.9960351175304446
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2544 - accuracy: 0.9108 - val_loss: 2.7423 - val_accuracy: 0.5113
# Epoch 39/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9181534975927499
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 14s 128ms/step - loss: 0.2442 - accuracy: 0.9184 - val_loss: 2.9117 - val_accuracy: 0.5181
# Epoch 40/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9157462475219484
# Train - Acurácia 2:  0.9927782497875955
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2454 - accuracy: 0.9146 - val_loss: 2.9888 - val_accuracy: 0.4909
# Epoch 41/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9083828943642028
# Train - Acurácia 2:  0.9881053525913339
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 14s 128ms/step - loss: 0.3029 - accuracy: 0.8999 - val_loss: 3.1216 - val_accuracy: 0.4875
# Epoch 42/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.921410365335599
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2840 - accuracy: 0.9037 - val_loss: 3.0167 - val_accuracy: 0.5000
# Epoch 43/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9291985273293685
# Train - Acurácia 2:  0.9926366468422543
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 128ms/step - loss: 0.2635 - accuracy: 0.9073 - val_loss: 2.8595 - val_accuracy: 0.5091
# Epoch 44/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9201359388275276
# Train - Acurácia 2:  0.989804587935429
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 14s 128ms/step - loss: 0.2481 - accuracy: 0.9101 - val_loss: 3.0204 - val_accuracy: 0.4796
# Epoch 45/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9270744831492495
# Train - Acurácia 2:  0.9949022939677146
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 14s 128ms/step - loss: 0.2322 - accuracy: 0.9193 - val_loss: 3.0245 - val_accuracy: 0.4966
# Epoch 46/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9314641744548287
# Train - Acurácia 2:  0.991928632115548
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2353 - accuracy: 0.9162 - val_loss: 2.9403 - val_accuracy: 0.5193
# Epoch 47/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9358538657604079
# Train - Acurácia 2:  0.9943358821863495
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2203 - accuracy: 0.9172 - val_loss: 2.9302 - val_accuracy: 0.5057
# Epoch 48/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9259416595865194
# Train - Acurácia 2:  0.9943358821863495
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8662131519274376
# 111/111 [==============================] - 14s 129ms/step - loss: 0.2008 - accuracy: 0.9237 - val_loss: 3.0731 - val_accuracy: 0.5068
# Epoch 49/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9386859246672331
# Train - Acurácia 2:  0.9975927499291986
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5158730158730159
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 128ms/step - loss: 0.2060 - accuracy: 0.9208 - val_loss: 3.0292 - val_accuracy: 0.5159
# Epoch 50/50
# 111/111 [==============================] - 4s 35ms/step
# Train - Acurácia 0:  0.9153214386859246
# Train - Acurácia 2:  0.994052676295667
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8650793650793651
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2054 - accuracy: 0.9223 - val_loss: 3.0256 - val_accuracy: 0.4807
# CPU times: user 21min 44s, sys: 2min 15s, total: 23min 59s
# Wall time: 12min 3s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'3')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k3'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k3',acc)
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_'+'k3',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k3')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k3')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 4s 35ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento shan_6 k=3', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_train_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_shan_6_k=3'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_shan_6_k=3    0.915321    0.989663     0.994053

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 0s 35ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação shan_6 k=3', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_validation_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_shan_6_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=3    0.915321    0.989663     0.994053
# 1  validation_shan_6_k=3    0.480726    0.835601     0.865079

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 0s 34ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste shan_6 k=3', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_test_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_shan_6_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=3    0.915321    0.989663     0.994053
# 1  validation_shan_6_k=3    0.480726    0.835601     0.865079
# 2        test_shan_6_k=3    0.477324    0.846939     0.877551

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/shan_6_kfold/Resultados_shan_6_k3.xlsx", index=False)

# %% [markdown]
# # k=4

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/treino4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/teste4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/validation4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino4")
VAL_DATASET = os.path.join("/content", "validation4")
TEST_DATASET = os.path.join("/content", "teste4")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.2080147267063155
# Train - Acurácia 2:  0.4464740866610025
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.21768707482993196
# validation - Acurácia 2:  0.4410430839002268
# 111/111 [==============================] - 24s 153ms/step - loss: 3.9339 - accuracy: 0.1997 - val_loss: 6.0563 - val_accuracy: 0.2177
# Epoch 2/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.25417728688756724
# Train - Acurácia 2:  0.570518266779949
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.25510204081632654
# validation - Acurácia 2:  0.564625850340136
# 111/111 [==============================] - 14s 129ms/step - loss: 2.8914 - accuracy: 0.3203 - val_loss: 3.7253 - val_accuracy: 0.2551
# Epoch 3/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.3200226564712546
# Train - Acurácia 2:  0.6805437553101105
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.35827664399092973
# validation - Acurácia 2:  0.6972789115646258
# 111/111 [==============================] - 14s 127ms/step - loss: 2.5125 - accuracy: 0.3873 - val_loss: 3.0244 - val_accuracy: 0.3583
# Epoch 4/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.4316057774001699
# Train - Acurácia 2:  0.8112432738600963
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4421768707482993
# validation - Acurácia 2:  0.8015873015873016
# 111/111 [==============================] - 14s 126ms/step - loss: 2.2924 - accuracy: 0.4189 - val_loss: 2.3456 - val_accuracy: 0.4422
# Epoch 5/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.42268479184367036
# Train - Acurácia 2:  0.8139337298215803
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.42403628117913833
# validation - Acurácia 2:  0.8061224489795918
# 111/111 [==============================] - 14s 128ms/step - loss: 2.1025 - accuracy: 0.4521 - val_loss: 2.4220 - val_accuracy: 0.4240
# Epoch 6/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.4512885868026055
# Train - Acurácia 2:  0.8558482016425941
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.46258503401360546
# validation - Acurácia 2:  0.8333333333333334
# 111/111 [==============================] - 14s 127ms/step - loss: 1.9537 - accuracy: 0.4703 - val_loss: 2.1538 - val_accuracy: 0.4626
# Epoch 7/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.4715378079864061
# Train - Acurácia 2:  0.8576890399320306
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.8390022675736961
# 111/111 [==============================] - 14s 127ms/step - loss: 1.8453 - accuracy: 0.4919 - val_loss: 2.2102 - val_accuracy: 0.4580
# Epoch 8/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.47210421976777117
# Train - Acurácia 2:  0.8777966581704899
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.45691609977324266
# validation - Acurácia 2:  0.8605442176870748
# 111/111 [==============================] - 14s 126ms/step - loss: 1.7563 - accuracy: 0.5102 - val_loss: 2.1390 - val_accuracy: 0.4569
# Epoch 9/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5178419711129991
# Train - Acurácia 2:  0.8979042764089493
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8650793650793651
# 111/111 [==============================] - 14s 126ms/step - loss: 1.6848 - accuracy: 0.5262 - val_loss: 2.0076 - val_accuracy: 0.4887
# Epoch 10/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.4776267346360804
# Train - Acurácia 2:  0.8974794675729255
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 14s 126ms/step - loss: 1.5910 - accuracy: 0.5412 - val_loss: 2.1682 - val_accuracy: 0.4580
# Epoch 11/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5648541489662985
# Train - Acurácia 2:  0.9212687623902577
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 14s 127ms/step - loss: 1.5216 - accuracy: 0.5556 - val_loss: 1.9176 - val_accuracy: 0.5113
# Epoch 12/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5022656471254602
# Train - Acurácia 2:  0.8868592466723307
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.41950113378684806
# validation - Acurácia 2:  0.8435374149659864
# 111/111 [==============================] - 14s 126ms/step - loss: 1.4523 - accuracy: 0.5673 - val_loss: 2.1872 - val_accuracy: 0.4195
# Epoch 13/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5474369866893232
# Train - Acurácia 2:  0.8639195695270462
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8378684807256236
# 111/111 [==============================] - 14s 127ms/step - loss: 1.3746 - accuracy: 0.5855 - val_loss: 2.1974 - val_accuracy: 0.5079
# Epoch 14/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6023789294817332
# Train - Acurácia 2:  0.91928632115548
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8650793650793651
# 111/111 [==============================] - 14s 126ms/step - loss: 1.3186 - accuracy: 0.6031 - val_loss: 2.0610 - val_accuracy: 0.4864
# Epoch 15/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6493911073350326
# Train - Acurácia 2:  0.9405267629566695
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 14s 127ms/step - loss: 1.2016 - accuracy: 0.6252 - val_loss: 1.9128 - val_accuracy: 0.5091
# Epoch 16/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5259133389974512
# Train - Acurácia 2:  0.9129141886151232
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.3968253968253968
# validation - Acurácia 2:  0.8560090702947846
# 111/111 [==============================] - 14s 126ms/step - loss: 1.1504 - accuracy: 0.6433 - val_loss: 2.2530 - val_accuracy: 0.3968
# Epoch 17/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6955536675162843
# Train - Acurácia 2:  0.9629000283205891
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.536281179138322
# validation - Acurácia 2:  0.9047619047619048
# 111/111 [==============================] - 14s 126ms/step - loss: 1.0779 - accuracy: 0.6599 - val_loss: 1.9582 - val_accuracy: 0.5363
# Epoch 18/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7092891532143869
# Train - Acurácia 2:  0.956952704616256
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.528344671201814
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 14s 129ms/step - loss: 0.9975 - accuracy: 0.6798 - val_loss: 2.0521 - val_accuracy: 0.5283
# Epoch 19/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.68946474086661
# Train - Acurácia 2:  0.94619088077032
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.8650793650793651
# 111/111 [==============================] - 14s 127ms/step - loss: 0.9003 - accuracy: 0.7111 - val_loss: 2.1628 - val_accuracy: 0.4683
# Epoch 20/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6822429906542056
# Train - Acurácia 2:  0.9565278957802322
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4467120181405896
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 14s 126ms/step - loss: 0.8674 - accuracy: 0.7285 - val_loss: 2.2101 - val_accuracy: 0.4467
# Epoch 21/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7727272727272727
# Train - Acurácia 2:  0.9651656754460493
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 14s 126ms/step - loss: 0.7706 - accuracy: 0.7467 - val_loss: 2.2989 - val_accuracy: 0.4932
# Epoch 22/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8033135089209855
# Train - Acurácia 2:  0.9695553667516285
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 14s 126ms/step - loss: 0.7315 - accuracy: 0.7661 - val_loss: 2.1634 - val_accuracy: 0.5057
# Epoch 23/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.82398753894081
# Train - Acurácia 2:  0.975219484565279
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5238095238095238
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 14s 127ms/step - loss: 0.6508 - accuracy: 0.7876 - val_loss: 2.2410 - val_accuracy: 0.5238
# Epoch 24/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8500424808836023
# Train - Acurácia 2:  0.9844236760124611
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 14s 126ms/step - loss: 0.5848 - accuracy: 0.8153 - val_loss: 2.2285 - val_accuracy: 0.5181
# Epoch 25/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8531577456811101
# Train - Acurácia 2:  0.9815916171056358
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.536281179138322
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 14s 126ms/step - loss: 0.5703 - accuracy: 0.8192 - val_loss: 2.3053 - val_accuracy: 0.5363
# Epoch 26/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8462192013593883
# Train - Acurácia 2:  0.9769187199093741
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 125ms/step - loss: 0.5154 - accuracy: 0.8360 - val_loss: 2.4489 - val_accuracy: 0.5011
# Epoch 27/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8664684225431889
# Train - Acurácia 2:  0.9780515434721042
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5226757369614512
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 14s 127ms/step - loss: 0.4839 - accuracy: 0.8444 - val_loss: 2.4513 - val_accuracy: 0.5227
# Epoch 28/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.859529878221467
# Train - Acurácia 2:  0.9745114698385726
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 126ms/step - loss: 0.4274 - accuracy: 0.8700 - val_loss: 2.7537 - val_accuracy: 0.4898
# Epoch 29/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7963749645992637
# Train - Acurácia 2:  0.9613423959218351
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.46485260770975056
# validation - Acurácia 2:  0.8401360544217688
# 111/111 [==============================] - 14s 126ms/step - loss: 0.4146 - accuracy: 0.8692 - val_loss: 2.8596 - val_accuracy: 0.4649
# Epoch 30/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9163126593033135
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 14s 126ms/step - loss: 0.3582 - accuracy: 0.8897 - val_loss: 2.4166 - val_accuracy: 0.5181
# Epoch 31/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8953554233928066
# Train - Acurácia 2:  0.9900877938261116
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 14s 127ms/step - loss: 0.3519 - accuracy: 0.8883 - val_loss: 2.5712 - val_accuracy: 0.4864
# Epoch 32/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9095157179269329
# Train - Acurácia 2:  0.9902293967714528
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 14s 126ms/step - loss: 0.3332 - accuracy: 0.8910 - val_loss: 2.5444 - val_accuracy: 0.5023
# Epoch 33/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9199943358821864
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5385487528344671
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 14s 127ms/step - loss: 0.3229 - accuracy: 0.8928 - val_loss: 2.6850 - val_accuracy: 0.5385
# Epoch 34/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9256584536958369
# Train - Acurácia 2:  0.9950438969130558
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5170068027210885
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2931 - accuracy: 0.9095 - val_loss: 2.6777 - val_accuracy: 0.5170
# Epoch 35/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.921976777116964
# Train - Acurácia 2:  0.9910790144435004
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 14s 127ms/step - loss: 0.3049 - accuracy: 0.9009 - val_loss: 2.7493 - val_accuracy: 0.5193
# Epoch 36/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9209855564995751
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5226757369614512
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2830 - accuracy: 0.9074 - val_loss: 2.8561 - val_accuracy: 0.5227
# Epoch 37/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7698952138204475
# Train - Acurácia 2:  0.9548286604361371
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.42630385487528344
# validation - Acurácia 2:  0.8469387755102041
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2983 - accuracy: 0.9012 - val_loss: 3.0904 - val_accuracy: 0.4263
# Epoch 38/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9323137921268763
# Train - Acurácia 2:  0.9958935145851033
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5215419501133787
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2673 - accuracy: 0.9089 - val_loss: 2.6698 - val_accuracy: 0.5215
# Epoch 39/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9030019824412348
# Train - Acurácia 2:  0.963891248937978
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2594 - accuracy: 0.9119 - val_loss: 3.3645 - val_accuracy: 0.5147
# Epoch 40/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9236760124610592
# Train - Acurácia 2:  0.9930614556782781
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2728 - accuracy: 0.9064 - val_loss: 2.9598 - val_accuracy: 0.5113
# Epoch 41/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9324553950722175
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5294784580498866
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2769 - accuracy: 0.9077 - val_loss: 2.8213 - val_accuracy: 0.5295
# Epoch 42/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9175870858113849
# Train - Acurácia 2:  0.9903709997167941
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2705 - accuracy: 0.9082 - val_loss: 2.9766 - val_accuracy: 0.5181
# Epoch 43/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9316057774001699
# Train - Acurácia 2:  0.9966015293118097
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 14s 128ms/step - loss: 0.2482 - accuracy: 0.9114 - val_loss: 2.8704 - val_accuracy: 0.5147
# Epoch 44/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9194279241008213
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2487 - accuracy: 0.9121 - val_loss: 2.9237 - val_accuracy: 0.5147
# Epoch 45/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9325969980175588
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5238095238095238
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2303 - accuracy: 0.9157 - val_loss: 2.9982 - val_accuracy: 0.5238
# Epoch 46/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9330218068535826
# Train - Acurácia 2:  0.9949022939677146
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5249433106575964
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2223 - accuracy: 0.9193 - val_loss: 3.0117 - val_accuracy: 0.5249
# Epoch 47/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.942367601246106
# Train - Acurácia 2:  0.9987255734919286
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5328798185941043
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 14s 127ms/step - loss: 0.2092 - accuracy: 0.9182 - val_loss: 2.7604 - val_accuracy: 0.5329
# Epoch 48/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9215519682809402
# Train - Acurácia 2:  0.9909374114981592
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.528344671201814
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2009 - accuracy: 0.9251 - val_loss: 2.9846 - val_accuracy: 0.5283
# Epoch 49/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9299065420560748
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5385487528344671
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2124 - accuracy: 0.9203 - val_loss: 2.9558 - val_accuracy: 0.5385
# Epoch 50/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9202775417728689
# Train - Acurácia 2:  0.9903709997167941
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5102040816326531
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2070 - accuracy: 0.9170 - val_loss: 2.9045 - val_accuracy: 0.5102
# CPU times: user 21min 40s, sys: 2min 14s, total: 23min 55s
# Wall time: 11min 49s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'4')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k4'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k4',acc)
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_'+'k4',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k4')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k4')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 4s 34ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento shan_6 k=4', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_train_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_shan_6_k=4'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_shan_6_k=4    0.920278    0.987397     0.990371

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 0s 34ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação shan_6 k=4', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_validation_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_shan_6_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=4    0.920278    0.987397     0.990371
# 1  validation_shan_6_k=4    0.510204    0.849206     0.878685

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 0s 34ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste shan_6 k=4', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_test_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_shan_6_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=4    0.920278    0.987397     0.990371
# 1  validation_shan_6_k=4    0.510204    0.849206     0.878685
# 2        test_shan_6_k=4    0.496599    0.834467     0.871882

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/shan_6_kfold/Resultados_shan_6_k4.xlsx", index=False)

# %% [markdown]
# # k=5

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/treino5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/teste5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_shan_6_review_split/validation5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino5")
VAL_DATASET = os.path.join("/content", "validation5")
TEST_DATASET = os.path.join("/content", "teste5")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.062022090059473234
# Train - Acurácia 2:  0.2507788161993769
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.04421768707482993
# validation - Acurácia 2:  0.24603174603174602
# 111/111 [==============================] - 24s 154ms/step - loss: 3.8492 - accuracy: 0.2056 - val_loss: 12.8648 - val_accuracy: 0.0442
# Epoch 2/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.15151515151515152
# Train - Acurácia 2:  0.5165675446049278
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.1349206349206349
# validation - Acurácia 2:  0.4886621315192744
# 111/111 [==============================] - 14s 130ms/step - loss: 2.8287 - accuracy: 0.3364 - val_loss: 4.4990 - val_accuracy: 0.1349
# Epoch 3/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.29793259699801755
# Train - Acurácia 2:  0.6789861229113565
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.28458049886621317
# validation - Acurácia 2:  0.6621315192743764
# 111/111 [==============================] - 14s 128ms/step - loss: 2.5024 - accuracy: 0.3734 - val_loss: 3.2214 - val_accuracy: 0.2846
# Epoch 4/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.39507221750212407
# Train - Acurácia 2:  0.7694704049844237
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.36961451247165533
# validation - Acurácia 2:  0.7403628117913832
# 111/111 [==============================] - 14s 127ms/step - loss: 2.2797 - accuracy: 0.3983 - val_loss: 2.5981 - val_accuracy: 0.3696
# Epoch 5/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.3889832908524497
# Train - Acurácia 2:  0.8044463324837157
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.3673469387755102
# validation - Acurácia 2:  0.7857142857142857
# 111/111 [==============================] - 14s 127ms/step - loss: 2.1474 - accuracy: 0.4235 - val_loss: 2.5752 - val_accuracy: 0.3673
# Epoch 6/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.3684508637779666
# Train - Acurácia 2:  0.7635230812800906
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.336734693877551
# validation - Acurácia 2:  0.753968253968254
# 111/111 [==============================] - 14s 128ms/step - loss: 2.0179 - accuracy: 0.4470 - val_loss: 2.5921 - val_accuracy: 0.3367
# Epoch 7/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.4427924100821297
# Train - Acurácia 2:  0.8623619371282922
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.37755102040816324
# validation - Acurácia 2:  0.8344671201814059
# 111/111 [==============================] - 14s 126ms/step - loss: 1.8834 - accuracy: 0.4766 - val_loss: 2.2814 - val_accuracy: 0.3776
# Epoch 8/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.4382611158312093
# Train - Acurácia 2:  0.7901444350042481
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.3979591836734694
# validation - Acurácia 2:  0.7755102040816326
# 111/111 [==============================] - 14s 127ms/step - loss: 1.7909 - accuracy: 0.4939 - val_loss: 2.3683 - val_accuracy: 0.3980
# Epoch 9/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.3925233644859813
# Train - Acurácia 2:  0.8033135089209855
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.35600907029478457
# validation - Acurácia 2:  0.7789115646258503
# 111/111 [==============================] - 14s 127ms/step - loss: 1.7092 - accuracy: 0.5136 - val_loss: 2.4962 - val_accuracy: 0.3560
# Epoch 10/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5025488530161427
# Train - Acurácia 2:  0.8925233644859814
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4421768707482993
# validation - Acurácia 2:  0.8605442176870748
# 111/111 [==============================] - 14s 126ms/step - loss: 1.6338 - accuracy: 0.5244 - val_loss: 2.1331 - val_accuracy: 0.4422
# Epoch 11/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5152931180968564
# Train - Acurácia 2:  0.8988954970263382
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.445578231292517
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 14s 127ms/step - loss: 1.5514 - accuracy: 0.5443 - val_loss: 2.0898 - val_accuracy: 0.4456
# Epoch 12/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5372415746247522
# Train - Acurácia 2:  0.911781365052393
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4342403628117914
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 14s 126ms/step - loss: 1.4757 - accuracy: 0.5620 - val_loss: 2.1137 - val_accuracy: 0.4342
# Epoch 13/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5902010761823846
# Train - Acurácia 2:  0.9320305862361937
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 14s 126ms/step - loss: 1.4033 - accuracy: 0.5786 - val_loss: 1.9652 - val_accuracy: 0.4932
# Epoch 14/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5100538091192297
# Train - Acurácia 2:  0.9146134239592183
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.40476190476190477
# validation - Acurácia 2:  0.8503401360544217
# 111/111 [==============================] - 14s 126ms/step - loss: 1.3425 - accuracy: 0.5963 - val_loss: 2.2325 - val_accuracy: 0.4048
# Epoch 15/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.4800339847068819
# Train - Acurácia 2:  0.9042764089493062
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.36167800453514737
# validation - Acurácia 2:  0.8526077097505669
# 111/111 [==============================] - 14s 126ms/step - loss: 1.2890 - accuracy: 0.6028 - val_loss: 2.2829 - val_accuracy: 0.3617
# Epoch 16/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6206457094307561
# Train - Acurácia 2:  0.9481733220050977
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4399092970521542
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 14s 126ms/step - loss: 1.2230 - accuracy: 0.6191 - val_loss: 2.0024 - val_accuracy: 0.4399
# Epoch 17/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.608184650240725
# Train - Acurácia 2:  0.945624468988955
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4365079365079365
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 126ms/step - loss: 1.1227 - accuracy: 0.6498 - val_loss: 2.1232 - val_accuracy: 0.4365
# Epoch 18/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6959784763523081
# Train - Acurácia 2:  0.9630416312659303
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 14s 127ms/step - loss: 1.0717 - accuracy: 0.6593 - val_loss: 2.0433 - val_accuracy: 0.4943
# Epoch 19/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6682242990654206
# Train - Acurácia 2:  0.9551118663268195
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.45691609977324266
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 14s 126ms/step - loss: 1.0350 - accuracy: 0.6651 - val_loss: 2.1733 - val_accuracy: 0.4569
# Epoch 20/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6581704899461909
# Train - Acurácia 2:  0.9501557632398754
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4399092970521542
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 14s 126ms/step - loss: 0.9789 - accuracy: 0.6872 - val_loss: 2.2833 - val_accuracy: 0.4399
# Epoch 21/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6847918436703483
# Train - Acurácia 2:  0.9582271311243273
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4399092970521542
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 14s 126ms/step - loss: 0.8945 - accuracy: 0.7117 - val_loss: 2.3271 - val_accuracy: 0.4399
# Epoch 22/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7424242424242424
# Train - Acurácia 2:  0.968280940243557
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4376417233560091
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 14s 125ms/step - loss: 0.8344 - accuracy: 0.7281 - val_loss: 2.2683 - val_accuracy: 0.4376
# Epoch 23/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.761540640045313
# Train - Acurácia 2:  0.9695553667516285
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 14s 126ms/step - loss: 0.7742 - accuracy: 0.7492 - val_loss: 2.2823 - val_accuracy: 0.4898
# Epoch 24/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.5654205607476636
# Train - Acurácia 2:  0.9127725856697819
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.336734693877551
# validation - Acurácia 2:  0.8424036281179138
# 111/111 [==============================] - 14s 126ms/step - loss: 0.7426 - accuracy: 0.7597 - val_loss: 2.8822 - val_accuracy: 0.3367
# Epoch 25/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7156612857547437
# Train - Acurácia 2:  0.9293401302747097
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.46258503401360546
# validation - Acurácia 2:  0.8378684807256236
# 111/111 [==============================] - 14s 126ms/step - loss: 0.6723 - accuracy: 0.7814 - val_loss: 2.5698 - val_accuracy: 0.4626
# Epoch 26/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.6066270178419712
# Train - Acurácia 2:  0.9140470121778533
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.36167800453514737
# validation - Acurácia 2:  0.8242630385487528
# 111/111 [==============================] - 14s 127ms/step - loss: 0.6470 - accuracy: 0.7907 - val_loss: 2.9550 - val_accuracy: 0.3617
# Epoch 27/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.7557349192863212
# Train - Acurácia 2:  0.9538374398187482
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.42970521541950113
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 14s 126ms/step - loss: 0.5868 - accuracy: 0.8088 - val_loss: 2.7580 - val_accuracy: 0.4297
# Epoch 28/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8388558482016426
# Train - Acurácia 2:  0.9689889549702634
# 14/14 [==============================] - 0s 33ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 14s 126ms/step - loss: 0.5348 - accuracy: 0.8301 - val_loss: 2.5632 - val_accuracy: 0.4807
# Epoch 29/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8561314075332767
# Train - Acurácia 2:  0.9822996318323421
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4671201814058957
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 14s 125ms/step - loss: 0.5099 - accuracy: 0.8353 - val_loss: 2.5302 - val_accuracy: 0.4671
# Epoch 30/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8647691871990938
# Train - Acurácia 2:  0.9844236760124611
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 14s 125ms/step - loss: 0.4793 - accuracy: 0.8442 - val_loss: 2.5269 - val_accuracy: 0.4773
# Epoch 31/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8565562163693005
# Train - Acurácia 2:  0.9733786462758426
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 14s 126ms/step - loss: 0.4736 - accuracy: 0.8479 - val_loss: 2.6399 - val_accuracy: 0.4921
# Epoch 32/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8197394505805721
# Train - Acurácia 2:  0.9612007929764939
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.43537414965986393
# validation - Acurácia 2:  0.8526077097505669
# 111/111 [==============================] - 14s 126ms/step - loss: 0.4450 - accuracy: 0.8578 - val_loss: 2.8670 - val_accuracy: 0.4354
# Epoch 33/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8793542905692439
# Train - Acurácia 2:  0.983857264231096
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4614512471655329
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 14s 126ms/step - loss: 0.4072 - accuracy: 0.8687 - val_loss: 2.6732 - val_accuracy: 0.4615
# Epoch 34/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9065420560747663
# Train - Acurácia 2:  0.9851316907391674
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.481859410430839
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 14s 125ms/step - loss: 0.3684 - accuracy: 0.8816 - val_loss: 2.6160 - val_accuracy: 0.4819
# Epoch 35/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8901161144151798
# Train - Acurácia 2:  0.9890965732087228
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 14s 126ms/step - loss: 0.3428 - accuracy: 0.8881 - val_loss: 2.7343 - val_accuracy: 0.4751
# Epoch 36/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8912489379779099
# Train - Acurácia 2:  0.9881053525913339
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4614512471655329
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 14s 125ms/step - loss: 0.3308 - accuracy: 0.8914 - val_loss: 2.7605 - val_accuracy: 0.4615
# Epoch 37/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8913905409232512
# Train - Acurácia 2:  0.9907958085528179
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 14s 125ms/step - loss: 0.3167 - accuracy: 0.8948 - val_loss: 2.7672 - val_accuracy: 0.4887
# Epoch 38/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8895497026338148
# Train - Acurácia 2:  0.9876805437553101
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 14s 125ms/step - loss: 0.3301 - accuracy: 0.8910 - val_loss: 2.7872 - val_accuracy: 0.4796
# Epoch 39/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9129141886151232
# Train - Acurácia 2:  0.9899461908807703
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.481859410430839
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 14s 126ms/step - loss: 0.3057 - accuracy: 0.9009 - val_loss: 2.8085 - val_accuracy: 0.4819
# Epoch 40/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9076748796374965
# Train - Acurácia 2:  0.9834324553950722
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8684807256235828
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2858 - accuracy: 0.9043 - val_loss: 2.9197 - val_accuracy: 0.4717
# Epoch 41/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8957802322288304
# Train - Acurácia 2:  0.9832908524497309
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4557823129251701
# validation - Acurácia 2:  0.8560090702947846
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2767 - accuracy: 0.9071 - val_loss: 3.0366 - val_accuracy: 0.4558
# Epoch 42/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9105069385443217
# Train - Acurácia 2:  0.9916454262248655
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2536 - accuracy: 0.9121 - val_loss: 2.9113 - val_accuracy: 0.4807
# Epoch 43/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9241008212970829
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 14s 126ms/step - loss: 0.3005 - accuracy: 0.8995 - val_loss: 2.8574 - val_accuracy: 0.5000
# Epoch 44/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8970546587369017
# Train - Acurácia 2:  0.9830076465590484
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2942 - accuracy: 0.9009 - val_loss: 3.1273 - val_accuracy: 0.4580
# Epoch 45/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9270744831492495
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 14s 125ms/step - loss: 0.2663 - accuracy: 0.9078 - val_loss: 2.9034 - val_accuracy: 0.4932
# Epoch 46/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9277824978759558
# Train - Acurácia 2:  0.9944774851316908
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 14s 125ms/step - loss: 0.2452 - accuracy: 0.9150 - val_loss: 3.0452 - val_accuracy: 0.4841
# Epoch 47/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9263664684225432
# Train - Acurácia 2:  0.9910790144435004
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2401 - accuracy: 0.9160 - val_loss: 2.9607 - val_accuracy: 0.4909
# Epoch 48/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.8967714528462192
# Train - Acurácia 2:  0.9869725290286038
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.4365079365079365
# validation - Acurácia 2:  0.8469387755102041
# 111/111 [==============================] - 14s 125ms/step - loss: 0.2464 - accuracy: 0.9153 - val_loss: 3.2873 - val_accuracy: 0.4365
# Epoch 49/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9222599830076466
# Train - Acurácia 2:  0.9895213820447465
# 14/14 [==============================] - 0s 35ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 14s 126ms/step - loss: 0.2460 - accuracy: 0.9125 - val_loss: 3.0324 - val_accuracy: 0.4762
# Epoch 50/50
# 111/111 [==============================] - 4s 34ms/step
# Train - Acurácia 0:  0.9197111299915038
# Train - Acurácia 2:  0.9917870291702068
# 14/14 [==============================] - 0s 34ms/step
# Validation - Acurácia 0:  0.47052154195011336
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 14s 125ms/step - loss: 0.2399 - accuracy: 0.9135 - val_loss: 3.0436 - val_accuracy: 0.4705
# CPU times: user 21min 39s, sys: 2min 11s, total: 23min 50s
# Wall time: 11min 47s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'5')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k5'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_'+'k5',acc)
np.save('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_'+'k5',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k5')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/shan_6_kfold/shan_6_kfold_'+'k5')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 4s 34ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento shan_6 k=5', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_train_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_shan_6_k=5'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_shan_6_k=5    0.919711    0.988955     0.991787

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 0s 34ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação shan_6 k=5', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_validation_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_shan_6_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=5    0.919711    0.988955     0.991787
# 1  validation_shan_6_k=5    0.470522    0.843537     0.873016

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 0s 34ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste shan_6 k=5', '/content/drive/MyDrive/Resultados/shan_6_kfold/prev_test_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_shan_6_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_shan_6_k=5    0.919711    0.988955     0.991787
# 1  validation_shan_6_k=5    0.470522    0.843537     0.873016
# 2        test_shan_6_k=5    0.501134    0.825397     0.859410

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/shan_6_kfold/Resultados_shan_6_k5.xlsx", index=False)
