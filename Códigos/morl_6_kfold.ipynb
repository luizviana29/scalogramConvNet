# %%
# !pip install tensorflow==2.5.0
# !pip install numpy==1.20.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
shutil.copy2("/content/drive/MyDrive/utilities.py", "/content/utilities.py")
shutil.copy2("/content/drive/MyDrive/ConvNet.py", "/content/ConvNet.py")
shutil.copy2("/content/drive/MyDrive/config.py", "/content/config.py")
# Out:
# '/content/config.py'

# %%
import ConvNet
import config
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.utils import to_categorical
from tensorflow.data import AUTOTUNE
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import argparse
import os
import numpy as np
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MultiLabelBinarizer
from IPython.display import Audio, clear_output, display
from glob import glob
import random
from utilities import acuracia0, acuracia1, acuracia2
import utilities

# %%
model = ConvNet.ConvNet

# %%
model.summary()

# %% [markdown]
# # k=1

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/treino1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/teste1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/validation1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino1")
VAL_DATASET = os.path.join("/content", "validation1")
TEST_DATASET = os.path.join("/content", "teste1")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7060, 40, 256, 1)
# (883, 40, 256, 1)
# (7060,)
# (883,)
# (883,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 42s - loss: 5.1977 - accuracy: 0.0052
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0814s vs `on_train_batch_end` time: 0.2651s). Check your callbacks.
# 111/111 [==============================] - 9s 75ms/step
# Train - Acurácia 0:  0.20892351274787535
# Train - Acurácia 2:  0.5559490084985835
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.16421291053227632
# validation - Acurácia 2:  0.5277463193657984
# 111/111 [==============================] - 80s 569ms/step - loss: 4.2215 - accuracy: 0.1571 - val_loss: 4.2587 - val_accuracy: 0.1642
# Epoch 2/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.24291784702549576
# Train - Acurácia 2:  0.5903682719546742
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.21517553793884484
# validation - Acurácia 2:  0.579841449603624
# 111/111 [==============================] - 60s 538ms/step - loss: 3.0674 - accuracy: 0.2960 - val_loss: 3.3882 - val_accuracy: 0.2152
# Epoch 3/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.31713881019830026
# Train - Acurácia 2:  0.746742209631728
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.2785956964892412
# validation - Acurácia 2:  0.7304643261608154
# 111/111 [==============================] - 59s 536ms/step - loss: 2.6382 - accuracy: 0.3469 - val_loss: 2.9846 - val_accuracy: 0.2786
# Epoch 4/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.41473087818696885
# Train - Acurácia 2:  0.8177053824362607
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.37032842582106457
# validation - Acurácia 2:  0.7995469988674971
# 111/111 [==============================] - 59s 535ms/step - loss: 2.3798 - accuracy: 0.3945 - val_loss: 2.3983 - val_accuracy: 0.3703
# Epoch 5/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.4201133144475921
# Train - Acurácia 2:  0.8381019830028329
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3737259343148358
# validation - Acurácia 2:  0.8312570781426953
# 111/111 [==============================] - 59s 536ms/step - loss: 2.2098 - accuracy: 0.4263 - val_loss: 2.3805 - val_accuracy: 0.3737
# Epoch 6/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.441643059490085
# Train - Acurácia 2:  0.8322946175637393
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.3793884484711212
# validation - Acurácia 2:  0.8108720271800679
# 111/111 [==============================] - 59s 536ms/step - loss: 2.0904 - accuracy: 0.4424 - val_loss: 2.3533 - val_accuracy: 0.3794
# Epoch 7/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.3575070821529745
# Train - Acurácia 2:  0.85
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.3318233295583239
# validation - Acurácia 2:  0.8086070215175538
# 111/111 [==============================] - 59s 536ms/step - loss: 1.9949 - accuracy: 0.4530 - val_loss: 2.4870 - val_accuracy: 0.3318
# Epoch 8/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.4382436260623229
# Train - Acurácia 2:  0.8800283286118981
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.37032842582106457
# validation - Acurácia 2:  0.8584371460928653
# 111/111 [==============================] - 59s 536ms/step - loss: 1.9029 - accuracy: 0.4755 - val_loss: 2.2287 - val_accuracy: 0.3703
# Epoch 9/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.5267705382436261
# Train - Acurácia 2:  0.8992917847025496
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.43148357870894677
# validation - Acurácia 2:  0.8663646659116648
# 111/111 [==============================] - 59s 536ms/step - loss: 1.8121 - accuracy: 0.5024 - val_loss: 2.0073 - val_accuracy: 0.4315
# Epoch 10/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.5053824362606232
# Train - Acurácia 2:  0.876770538243626
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4405436013590034
# validation - Acurácia 2:  0.8471121177802945
# 111/111 [==============================] - 59s 534ms/step - loss: 1.7098 - accuracy: 0.5095 - val_loss: 2.1693 - val_accuracy: 0.4405
# Epoch 11/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.543342776203966
# Train - Acurácia 2:  0.9253541076487252
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.43714609286523215
# validation - Acurácia 2:  0.8776896942242356
# 111/111 [==============================] - 59s 535ms/step - loss: 1.6631 - accuracy: 0.5159 - val_loss: 2.0036 - val_accuracy: 0.4371
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.44008498583569405
# Train - Acurácia 2:  0.8706798866855524
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.37485843714609285
# validation - Acurácia 2:  0.8346545866364666
# 111/111 [==============================] - 59s 535ms/step - loss: 1.5793 - accuracy: 0.5402 - val_loss: 2.3415 - val_accuracy: 0.3749
# Epoch 13/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.5654390934844192
# Train - Acurácia 2:  0.9168555240793201
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.44733861834654587
# validation - Acurácia 2:  0.8708946772366931
# 111/111 [==============================] - 59s 535ms/step - loss: 1.5462 - accuracy: 0.5472 - val_loss: 1.9972 - val_accuracy: 0.4473
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6021246458923513
# Train - Acurácia 2:  0.9325779036827195
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4563986409966025
# validation - Acurácia 2:  0.8799546998867497
# 111/111 [==============================] - 59s 534ms/step - loss: 1.4835 - accuracy: 0.5551 - val_loss: 1.9784 - val_accuracy: 0.4564
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.615014164305949
# Train - Acurácia 2:  0.9402266288951842
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.46998867497168745
# validation - Acurácia 2:  0.8776896942242356
# 111/111 [==============================] - 59s 535ms/step - loss: 1.3999 - accuracy: 0.5737 - val_loss: 1.9650 - val_accuracy: 0.4700
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5701133144475921
# Train - Acurácia 2:  0.9388101983002833
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.45300113250283125
# validation - Acurácia 2:  0.8776896942242356
# 111/111 [==============================] - 59s 534ms/step - loss: 1.3361 - accuracy: 0.5899 - val_loss: 2.0456 - val_accuracy: 0.4530
# Epoch 17/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.6168555240793201
# Train - Acurácia 2:  0.9245042492917847
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.45413363533408835
# validation - Acurácia 2:  0.853907134767837
# 111/111 [==============================] - 59s 535ms/step - loss: 1.2695 - accuracy: 0.6169 - val_loss: 2.0604 - val_accuracy: 0.4541
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.35793201133144475
# Train - Acurácia 2:  0.8848441926345609
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.29784824462061155
# validation - Acurácia 2:  0.8278595696489242
# 111/111 [==============================] - 59s 534ms/step - loss: 1.2110 - accuracy: 0.6228 - val_loss: 2.6388 - val_accuracy: 0.2978
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6270538243626063
# Train - Acurácia 2:  0.9505665722379604
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.44733861834654587
# validation - Acurácia 2:  0.8799546998867497
# 111/111 [==============================] - 59s 533ms/step - loss: 1.1453 - accuracy: 0.6414 - val_loss: 2.1195 - val_accuracy: 0.4473
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5222379603399433
# Train - Acurácia 2:  0.9209631728045325
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3793884484711212
# validation - Acurácia 2:  0.8527746319365799
# 111/111 [==============================] - 59s 534ms/step - loss: 1.0710 - accuracy: 0.6625 - val_loss: 2.4574 - val_accuracy: 0.3794
# Epoch 21/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.6889518413597734
# Train - Acurácia 2:  0.9559490084985836
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4575311438278596
# validation - Acurácia 2:  0.8742921857304643
# 111/111 [==============================] - 59s 534ms/step - loss: 1.0366 - accuracy: 0.6678 - val_loss: 2.1520 - val_accuracy: 0.4575
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7093484419263456
# Train - Acurácia 2:  0.9576487252124646
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.43827859569648925
# validation - Acurácia 2:  0.8607021517553793
# 111/111 [==============================] - 59s 533ms/step - loss: 0.9541 - accuracy: 0.6992 - val_loss: 2.1728 - val_accuracy: 0.4383
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7311614730878186
# Train - Acurácia 2:  0.9647308781869688
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4869762174405436
# validation - Acurácia 2:  0.8788221970554927
# 111/111 [==============================] - 59s 534ms/step - loss: 0.9241 - accuracy: 0.6997 - val_loss: 2.2753 - val_accuracy: 0.4870
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7298866855524079
# Train - Acurácia 2:  0.9620396600566572
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.43941109852774635
# validation - Acurácia 2:  0.8731596828992072
# 111/111 [==============================] - 59s 533ms/step - loss: 0.8393 - accuracy: 0.7286 - val_loss: 2.3444 - val_accuracy: 0.4394
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7747875354107648
# Train - Acurácia 2:  0.9686968838526913
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4733861834654587
# validation - Acurácia 2:  0.8708946772366931
# 111/111 [==============================] - 59s 533ms/step - loss: 0.8106 - accuracy: 0.7416 - val_loss: 2.3631 - val_accuracy: 0.4734
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7729461756373938
# Train - Acurácia 2:  0.9644475920679887
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.464326160815402
# validation - Acurácia 2:  0.869762174405436
# 111/111 [==============================] - 59s 533ms/step - loss: 0.7592 - accuracy: 0.7525 - val_loss: 2.4330 - val_accuracy: 0.4643
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7936260623229462
# Train - Acurácia 2:  0.9805949008498583
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46319365798414497
# validation - Acurácia 2:  0.8878822197055493
# 111/111 [==============================] - 59s 533ms/step - loss: 0.7029 - accuracy: 0.7779 - val_loss: 2.3675 - val_accuracy: 0.4632
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7906515580736544
# Train - Acurácia 2:  0.9780453257790368
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.43941109852774635
# validation - Acurácia 2:  0.8663646659116648
# 111/111 [==============================] - 59s 533ms/step - loss: 0.6312 - accuracy: 0.7999 - val_loss: 2.4812 - val_accuracy: 0.4394
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8320113314447593
# Train - Acurácia 2:  0.9759206798866855
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46998867497168745
# validation - Acurácia 2:  0.8924122310305775
# 111/111 [==============================] - 59s 535ms/step - loss: 0.6132 - accuracy: 0.8014 - val_loss: 2.4517 - val_accuracy: 0.4700
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6035410764872521
# Train - Acurácia 2:  0.9345609065155808
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3556058890147225
# validation - Acurácia 2:  0.8312570781426953
# 111/111 [==============================] - 59s 534ms/step - loss: 0.5632 - accuracy: 0.8237 - val_loss: 2.9834 - val_accuracy: 0.3556
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8379603399433427
# Train - Acurácia 2:  0.9725212464589235
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4813137032842582
# validation - Acurácia 2:  0.8629671574178935
# 111/111 [==============================] - 59s 534ms/step - loss: 0.5362 - accuracy: 0.8276 - val_loss: 2.5289 - val_accuracy: 0.4813
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7637393767705383
# Train - Acurácia 2:  0.9691218130311615
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.42242355605889015
# validation - Acurácia 2:  0.853907134767837
# 111/111 [==============================] - 59s 534ms/step - loss: 0.5239 - accuracy: 0.8286 - val_loss: 2.8591 - val_accuracy: 0.4224
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8198300283286118
# Train - Acurácia 2:  0.9801699716713881
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4507361268403171
# validation - Acurácia 2:  0.869762174405436
# 111/111 [==============================] - 59s 534ms/step - loss: 0.4645 - accuracy: 0.8490 - val_loss: 2.5973 - val_accuracy: 0.4507
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8791784702549575
# Train - Acurácia 2:  0.9856940509915014
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4824462061155153
# validation - Acurácia 2:  0.8686296715741789
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4209 - accuracy: 0.8646 - val_loss: 2.7662 - val_accuracy: 0.4824
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8498583569405099
# Train - Acurácia 2:  0.9715297450424929
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4575311438278596
# validation - Acurácia 2:  0.8505096262740657
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4383 - accuracy: 0.8579 - val_loss: 2.9507 - val_accuracy: 0.4575
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9104815864022663
# Train - Acurácia 2:  0.9909348441926346
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48924122310305773
# validation - Acurácia 2:  0.883352208380521
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4130 - accuracy: 0.8705 - val_loss: 2.6914 - val_accuracy: 0.4892
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8978753541076487
# Train - Acurácia 2:  0.9848441926345609
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47565118912797283
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3663 - accuracy: 0.8796 - val_loss: 2.7623 - val_accuracy: 0.4757
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8906515580736544
# Train - Acurácia 2:  0.9858356940509915
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48357870894677235
# validation - Acurácia 2:  0.8686296715741789
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3529 - accuracy: 0.8861 - val_loss: 2.8464 - val_accuracy: 0.4836
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9222379603399433
# Train - Acurácia 2:  0.9893767705382436
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4881087202718007
# validation - Acurácia 2:  0.8754246885617214
# 111/111 [==============================] - 59s 534ms/step - loss: 0.3172 - accuracy: 0.8959 - val_loss: 2.7990 - val_accuracy: 0.4881
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9094900849858357
# Train - Acurácia 2:  0.9839943342776204
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47565118912797283
# validation - Acurácia 2:  0.853907134767837
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3238 - accuracy: 0.8959 - val_loss: 2.9040 - val_accuracy: 0.4757
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8804532577903683
# Train - Acurácia 2:  0.9834277620396601
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.45979614949037373
# validation - Acurácia 2:  0.8640996602491506
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3378 - accuracy: 0.8925 - val_loss: 2.8445 - val_accuracy: 0.4598
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7980169971671388
# Train - Acurácia 2:  0.9679886685552408
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.42129105322763305
# validation - Acurácia 2:  0.8527746319365799
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3125 - accuracy: 0.8955 - val_loss: 3.0528 - val_accuracy: 0.4213
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9276203966005666
# Train - Acurácia 2:  0.9910764872521246
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5039637599093998
# validation - Acurácia 2:  0.8720271800679502
# 111/111 [==============================] - 59s 535ms/step - loss: 0.2833 - accuracy: 0.9058 - val_loss: 2.8711 - val_accuracy: 0.5040
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9298866855524079
# Train - Acurácia 2:  0.9913597733711048
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48584371460928655
# validation - Acurácia 2:  0.8686296715741789
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2636 - accuracy: 0.9130 - val_loss: 2.9577 - val_accuracy: 0.4858
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8873937677053825
# Train - Acurácia 2:  0.9847025495750709
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.44733861834654587
# validation - Acurácia 2:  0.8720271800679502
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2630 - accuracy: 0.9113 - val_loss: 3.0916 - val_accuracy: 0.4473
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9165722379603399
# Train - Acurácia 2:  0.991643059490085
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47904869762174407
# validation - Acurácia 2:  0.8822197055492639
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2586 - accuracy: 0.9089 - val_loss: 3.0338 - val_accuracy: 0.4790
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8913597733711048
# Train - Acurácia 2:  0.9715297450424929
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4711211778029445
# validation - Acurácia 2:  0.8369195922989807
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2592 - accuracy: 0.9084 - val_loss: 3.2863 - val_accuracy: 0.4711
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9296033994334277
# Train - Acurácia 2:  0.9953257790368272
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.49150622876557193
# validation - Acurácia 2:  0.8810872027180068
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2348 - accuracy: 0.9157 - val_loss: 3.0426 - val_accuracy: 0.4915
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9382436260623229
# Train - Acurácia 2:  0.9939093484419264
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.507361268403171
# validation - Acurácia 2:  0.8640996602491506
# 111/111 [==============================] - 59s 534ms/step - loss: 0.2215 - accuracy: 0.9224 - val_loss: 2.8893 - val_accuracy: 0.5074
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8854107648725212
# Train - Acurácia 2:  0.976770538243626
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.45979614949037373
# validation - Acurácia 2:  0.8425821064552661
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2420 - accuracy: 0.9144 - val_loss: 3.1781 - val_accuracy: 0.4598
# CPU times: user 52min 34s, sys: 1min 24s, total: 53min 58s
# Wall time: 49min 39s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'1')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k1'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k1',acc)
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_'+'k1',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k1')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k1')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 76ms/step
# (7060, 140)
# (7060,)
# (7060,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento morl_6 k=1', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_train_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_morl_6_k=1'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_morl_6_k=1    0.885411    0.970113     0.976771

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação morl_6 k=1', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_validation_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_morl_6_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=1    0.885411    0.970113     0.976771
# 1  validation_morl_6_k=1    0.459796    0.802945     0.842582

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste morl_6 k=1', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_test_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_morl_6_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=1    0.885411    0.970113     0.976771
# 1  validation_morl_6_k=1    0.459796    0.802945     0.842582
# 2        test_morl_6_k=1    0.481314    0.804077     0.830125

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/morl_6_kfold/Resultados_morl_6_k1.xlsx", index=False)

# %% [markdown]
# # k=2

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/treino2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/teste2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/validation2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino2")
VAL_DATASET = os.path.join("/content", "validation2")
TEST_DATASET = os.path.join("/content", "teste2")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 44s - loss: 5.1941 - accuracy: 0.0208
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0862s vs `on_train_batch_end` time: 0.2783s). Check your callbacks.
# 111/111 [==============================] - 9s 76ms/step
# Train - Acurácia 0:  0.15590484282073067
# Train - Acurácia 2:  0.47366185216652507
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.1564625850340136
# validation - Acurácia 2:  0.45691609977324266
# 111/111 [==============================] - 76s 589ms/step - loss: 4.2746 - accuracy: 0.1563 - val_loss: 4.7766 - val_accuracy: 0.1565
# Epoch 2/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.17544604927782498
# Train - Acurácia 2:  0.5923251203625035
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.17233560090702948
# validation - Acurácia 2:  0.5793650793650794
# 111/111 [==============================] - 59s 536ms/step - loss: 3.1022 - accuracy: 0.2984 - val_loss: 3.7104 - val_accuracy: 0.1723
# Epoch 3/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.31478334749362785
# Train - Acurácia 2:  0.6527895780232229
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.2834467120181406
# validation - Acurácia 2:  0.6349206349206349
# 111/111 [==============================] - 59s 535ms/step - loss: 2.7303 - accuracy: 0.3328 - val_loss: 2.9738 - val_accuracy: 0.2834
# Epoch 4/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.3888416879071085
# Train - Acurácia 2:  0.7601246105919003
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.35827664399092973
# validation - Acurácia 2:  0.7346938775510204
# 111/111 [==============================] - 59s 535ms/step - loss: 2.4464 - accuracy: 0.3830 - val_loss: 2.5629 - val_accuracy: 0.3583
# Epoch 5/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.37170773152081565
# Train - Acurácia 2:  0.7214670065137355
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.34467120181405897
# validation - Acurácia 2:  0.7131519274376418
# 111/111 [==============================] - 59s 534ms/step - loss: 2.2451 - accuracy: 0.4206 - val_loss: 2.7355 - val_accuracy: 0.3447
# Epoch 6/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.45298782214670064
# Train - Acurácia 2:  0.8523081280090626
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.41383219954648526
# validation - Acurácia 2:  0.8140589569160998
# 111/111 [==============================] - 59s 535ms/step - loss: 2.0850 - accuracy: 0.4503 - val_loss: 2.2458 - val_accuracy: 0.4138
# Epoch 7/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.4282073067119796
# Train - Acurácia 2:  0.8419711129991504
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3979591836734694
# validation - Acurácia 2:  0.8242630385487528
# 111/111 [==============================] - 59s 534ms/step - loss: 1.9087 - accuracy: 0.4843 - val_loss: 2.3591 - val_accuracy: 0.3980
# Epoch 8/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.2870291702067403
# Train - Acurácia 2:  0.6639762107051826
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.2687074829931973
# validation - Acurácia 2:  0.645124716553288
# 111/111 [==============================] - 59s 535ms/step - loss: 1.8412 - accuracy: 0.4919 - val_loss: 3.5462 - val_accuracy: 0.2687
# Epoch 9/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.451005380911923
# Train - Acurácia 2:  0.8118096856414614
# 14/14 [==============================] - 1s 83ms/step
# Validation - Acurácia 0:  0.40476190476190477
# validation - Acurácia 2:  0.7925170068027211
# 111/111 [==============================] - 61s 551ms/step - loss: 1.7543 - accuracy: 0.5132 - val_loss: 2.3396 - val_accuracy: 0.4048
# Epoch 10/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5488530161427357
# Train - Acurácia 2:  0.9007363353157746
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 59s 534ms/step - loss: 1.6667 - accuracy: 0.5258 - val_loss: 1.9841 - val_accuracy: 0.4909
# Epoch 11/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5741999433588219
# Train - Acurácia 2:  0.9113565562163694
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8684807256235828
# 111/111 [==============================] - 59s 535ms/step - loss: 1.5787 - accuracy: 0.5443 - val_loss: 1.9482 - val_accuracy: 0.5011
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5713678844519966
# Train - Acurácia 2:  0.9185783064287737
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4433106575963719
# validation - Acurácia 2:  0.8662131519274376
# 111/111 [==============================] - 59s 535ms/step - loss: 1.5084 - accuracy: 0.5651 - val_loss: 2.0588 - val_accuracy: 0.4433
# Epoch 13/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5858113848768054
# Train - Acurácia 2:  0.9222599830076466
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 533ms/step - loss: 1.4170 - accuracy: 0.5738 - val_loss: 1.9244 - val_accuracy: 0.4830
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6165392240158595
# Train - Acurácia 2:  0.937553101104503
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46938775510204084
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 59s 535ms/step - loss: 1.3424 - accuracy: 0.5927 - val_loss: 2.0150 - val_accuracy: 0.4694
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5969980175587652
# Train - Acurácia 2:  0.9444916454262249
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.40589569160997735
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 59s 533ms/step - loss: 1.2823 - accuracy: 0.6105 - val_loss: 2.1924 - val_accuracy: 0.4059
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6479750778816199
# Train - Acurácia 2:  0.9440668365902011
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 59s 535ms/step - loss: 1.1748 - accuracy: 0.6403 - val_loss: 2.0937 - val_accuracy: 0.4717
# Epoch 17/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5100538091192297
# Train - Acurácia 2:  0.8711413197394505
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3888888888888889
# validation - Acurácia 2:  0.8117913832199547
# 111/111 [==============================] - 59s 534ms/step - loss: 1.1569 - accuracy: 0.6434 - val_loss: 2.6115 - val_accuracy: 0.3889
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7003681676578872
# Train - Acurácia 2:  0.9410931747380346
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 534ms/step - loss: 1.0403 - accuracy: 0.6709 - val_loss: 2.1362 - val_accuracy: 0.4773
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7274143302180686
# Train - Acurácia 2:  0.9620504106485415
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 533ms/step - loss: 0.9755 - accuracy: 0.6920 - val_loss: 2.1306 - val_accuracy: 0.4841
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7323704333050127
# Train - Acurácia 2:  0.9512885868026055
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 59s 534ms/step - loss: 0.9063 - accuracy: 0.7182 - val_loss: 2.3255 - val_accuracy: 0.4717
# Epoch 21/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7686207873123762
# Train - Acurácia 2:  0.9580855281789861
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 533ms/step - loss: 0.8460 - accuracy: 0.7331 - val_loss: 2.2780 - val_accuracy: 0.4762
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8028887000849617
# Train - Acurácia 2:  0.9713962050410648
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 59s 534ms/step - loss: 0.7824 - accuracy: 0.7538 - val_loss: 2.2253 - val_accuracy: 0.5023
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7901444350042481
# Train - Acurácia 2:  0.9553950722175021
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8616780045351474
# 111/111 [==============================] - 59s 533ms/step - loss: 0.6963 - accuracy: 0.7808 - val_loss: 2.3979 - val_accuracy: 0.4796
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8038799207023506
# Train - Acurácia 2:  0.9684225431888983
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.445578231292517
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 59s 533ms/step - loss: 0.6478 - accuracy: 0.7960 - val_loss: 2.4637 - val_accuracy: 0.4456
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8305012744265081
# Train - Acurácia 2:  0.9726706315491362
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8605442176870748
# 111/111 [==============================] - 59s 534ms/step - loss: 0.5793 - accuracy: 0.8190 - val_loss: 2.5432 - val_accuracy: 0.4728
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8381478334749363
# Train - Acurácia 2:  0.9675729255168507
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.43537414965986393
# validation - Acurácia 2:  0.8571428571428571
# 111/111 [==============================] - 59s 536ms/step - loss: 0.5395 - accuracy: 0.8304 - val_loss: 2.7481 - val_accuracy: 0.4354
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8106768620787312
# Train - Acurácia 2:  0.9599263664684226
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.43197278911564624
# validation - Acurácia 2:  0.8492063492063492
# 111/111 [==============================] - 59s 532ms/step - loss: 0.4950 - accuracy: 0.8444 - val_loss: 2.8085 - val_accuracy: 0.4320
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8511753044463325
# Train - Acurácia 2:  0.9713962050410648
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4897 - accuracy: 0.8417 - val_loss: 2.6147 - val_accuracy: 0.4796
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8911073350325687
# Train - Acurácia 2:  0.9848484848484849
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 532ms/step - loss: 0.4460 - accuracy: 0.8567 - val_loss: 2.5655 - val_accuracy: 0.4807
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.897196261682243
# Train - Acurácia 2:  0.9856981025205325
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4065 - accuracy: 0.8707 - val_loss: 2.7707 - val_accuracy: 0.4660
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9041348060039649
# Train - Acurácia 2:  0.9842820730671198
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 531ms/step - loss: 0.3740 - accuracy: 0.8849 - val_loss: 2.6813 - val_accuracy: 0.4887
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8123760974228263
# Train - Acurácia 2:  0.9636080430472954
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4002267573696145
# validation - Acurácia 2:  0.8458049886621315
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3604 - accuracy: 0.8845 - val_loss: 3.2007 - val_accuracy: 0.4002
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9163126593033135
# Train - Acurácia 2:  0.9875389408099688
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3514 - accuracy: 0.8888 - val_loss: 2.8081 - val_accuracy: 0.4807
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.90470121778533
# Train - Acurácia 2:  0.9842820730671198
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3281 - accuracy: 0.8897 - val_loss: 2.8473 - val_accuracy: 0.4955
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9161710563579722
# Train - Acurácia 2:  0.9912206173888417
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.86281179138322
# 111/111 [==============================] - 59s 532ms/step - loss: 0.3066 - accuracy: 0.8983 - val_loss: 3.0132 - val_accuracy: 0.4932
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.91928632115548
# Train - Acurácia 2:  0.9890965732087228
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.8537414965986394
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2911 - accuracy: 0.9046 - val_loss: 3.0595 - val_accuracy: 0.4683
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9287737184933447
# Train - Acurácia 2:  0.9927782497875955
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2726 - accuracy: 0.9077 - val_loss: 2.9394 - val_accuracy: 0.4864
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9037099971679411
# Train - Acurácia 2:  0.9875389408099688
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.463718820861678
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2764 - accuracy: 0.9067 - val_loss: 2.9400 - val_accuracy: 0.4637
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9086661002548853
# Train - Acurácia 2:  0.9861229113565562
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2688 - accuracy: 0.9068 - val_loss: 3.0669 - val_accuracy: 0.4660
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9232512036250354
# Train - Acurácia 2:  0.9917870291702068
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46938775510204084
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2613 - accuracy: 0.9133 - val_loss: 3.0285 - val_accuracy: 0.4694
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9124893797790994
# Train - Acurácia 2:  0.983857264231096
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8650793650793651
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2737 - accuracy: 0.9073 - val_loss: 3.2153 - val_accuracy: 0.4660
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9327386009629001
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2489 - accuracy: 0.9153 - val_loss: 3.0759 - val_accuracy: 0.5136
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9307561597281223
# Train - Acurácia 2:  0.9943358821863495
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2469 - accuracy: 0.9126 - val_loss: 3.0309 - val_accuracy: 0.5057
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9317473803455112
# Train - Acurácia 2:  0.9939110733503257
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4546485260770975
# validation - Acurácia 2:  0.8526077097505669
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2415 - accuracy: 0.9139 - val_loss: 3.2741 - val_accuracy: 0.4546
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8830359671481167
# Train - Acurácia 2:  0.9839988671764373
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4523809523809524
# validation - Acurácia 2:  0.8616780045351474
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2437 - accuracy: 0.9116 - val_loss: 3.1911 - val_accuracy: 0.4524
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9209855564995751
# Train - Acurácia 2:  0.9873973378646276
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2669 - accuracy: 0.9026 - val_loss: 3.3136 - val_accuracy: 0.4853
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9318889832908525
# Train - Acurácia 2:  0.9934862645143019
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2415 - accuracy: 0.9098 - val_loss: 3.1572 - val_accuracy: 0.5125
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9358538657604079
# Train - Acurácia 2:  0.9936278674596432
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.481859410430839
# validation - Acurácia 2:  0.8684807256235828
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2369 - accuracy: 0.9123 - val_loss: 3.2980 - val_accuracy: 0.4819
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.937553101104503
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 59s 534ms/step - loss: 0.2241 - accuracy: 0.9173 - val_loss: 3.1487 - val_accuracy: 0.4841
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9384027187765506
# Train - Acurácia 2:  0.9960351175304446
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5204081632653061
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2000 - accuracy: 0.9225 - val_loss: 3.1948 - val_accuracy: 0.5204
# CPU times: user 52min 29s, sys: 1min 29s, total: 53min 59s
# Wall time: 49min 33s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'2')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k2'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k2',acc)
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_'+'k2',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k2')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k2')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 76ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento morl_6 k=2', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_train_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_morl_6_k=2'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_morl_6_k=2    0.938403    0.995752     0.996035

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 75ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação morl_6 k=2', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_validation_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_morl_6_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=2    0.938403    0.995752     0.996035
# 1  validation_morl_6_k=2    0.520408    0.845805     0.883220

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste morl_6 k=2', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_test_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_morl_6_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=2    0.938403    0.995752     0.996035
# 1  validation_morl_6_k=2    0.520408    0.845805     0.883220
# 2        test_morl_6_k=2    0.534014    0.853741     0.884354

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/morl_6_kfold/Resultados_morl_6_k2.xlsx", index=False)

# %% [markdown]
# # k=3

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/treino3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/teste3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/validation3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino3")
VAL_DATASET = os.path.join("/content", "validation3")
TEST_DATASET = os.path.join("/content", "teste3")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 44s - loss: 5.2031 - accuracy: 0.0156
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0851s vs `on_train_batch_end` time: 0.2829s). Check your callbacks.
# 111/111 [==============================] - 9s 76ms/step
# Train - Acurácia 0:  0.23463608043047296
# Train - Acurácia 2:  0.49022939677145283
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.23922902494331066
# validation - Acurácia 2:  0.5034013605442177
# 111/111 [==============================] - 76s 591ms/step - loss: 3.8981 - accuracy: 0.2154 - val_loss: 4.0574 - val_accuracy: 0.2392
# Epoch 2/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.24341546304163125
# Train - Acurácia 2:  0.4984423676012461
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.2528344671201814
# validation - Acurácia 2:  0.5045351473922902
# 111/111 [==============================] - 60s 539ms/step - loss: 2.8661 - accuracy: 0.3328 - val_loss: 4.1556 - val_accuracy: 0.2528
# Epoch 3/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.32143868592466723
# Train - Acurácia 2:  0.6359388275276125
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.2981859410430839
# validation - Acurácia 2:  0.63718820861678
# 111/111 [==============================] - 59s 537ms/step - loss: 2.4601 - accuracy: 0.3941 - val_loss: 3.2980 - val_accuracy: 0.2982
# Epoch 4/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.4501557632398754
# Train - Acurácia 2:  0.8099688473520249
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.39909297052154197
# validation - Acurácia 2:  0.800453514739229
# 111/111 [==============================] - 59s 536ms/step - loss: 2.2437 - accuracy: 0.4255 - val_loss: 2.3429 - val_accuracy: 0.3991
# Epoch 5/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.3462192013593883
# Train - Acurácia 2:  0.6665250637213254
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3299319727891156
# validation - Acurácia 2:  0.6666666666666666
# 111/111 [==============================] - 59s 537ms/step - loss: 2.1049 - accuracy: 0.4503 - val_loss: 3.1851 - val_accuracy: 0.3299
# Epoch 6/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.48895497026338147
# Train - Acurácia 2:  0.8694420843953554
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.445578231292517
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 59s 537ms/step - loss: 1.9478 - accuracy: 0.4809 - val_loss: 2.1203 - val_accuracy: 0.4456
# Epoch 7/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.470404984423676
# Train - Acurácia 2:  0.8677428490512603
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4308390022675737
# validation - Acurácia 2:  0.8560090702947846
# 111/111 [==============================] - 59s 536ms/step - loss: 1.8648 - accuracy: 0.4922 - val_loss: 2.0882 - val_accuracy: 0.4308
# Epoch 8/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.42126876239025773
# Train - Acurácia 2:  0.8525913338997451
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3786848072562358
# validation - Acurácia 2:  0.8412698412698413
# 111/111 [==============================] - 59s 536ms/step - loss: 1.7681 - accuracy: 0.5088 - val_loss: 2.2911 - val_accuracy: 0.3787
# Epoch 9/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5508354573775135
# Train - Acurácia 2:  0.9131973945058057
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 59s 534ms/step - loss: 1.6629 - accuracy: 0.5252 - val_loss: 1.9162 - val_accuracy: 0.4841
# Epoch 10/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5584820164259416
# Train - Acurácia 2:  0.9191447182101388
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 535ms/step - loss: 1.5730 - accuracy: 0.5472 - val_loss: 1.9218 - val_accuracy: 0.4683
# Epoch 11/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.551685075049561
# Train - Acurácia 2:  0.9129141886151232
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4421768707482993
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 535ms/step - loss: 1.5109 - accuracy: 0.5538 - val_loss: 1.9587 - val_accuracy: 0.4422
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5900594732370433
# Train - Acurácia 2:  0.9376947040498442
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 535ms/step - loss: 1.4293 - accuracy: 0.5739 - val_loss: 1.8624 - val_accuracy: 0.4875
# Epoch 13/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5451713395638629
# Train - Acurácia 2:  0.897196261682243
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.42630385487528344
# validation - Acurácia 2:  0.8537414965986394
# 111/111 [==============================] - 59s 534ms/step - loss: 1.3690 - accuracy: 0.5834 - val_loss: 2.1593 - val_accuracy: 0.4263
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6430189747946757
# Train - Acurácia 2:  0.9457660719342962
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 534ms/step - loss: 1.2845 - accuracy: 0.6042 - val_loss: 1.8797 - val_accuracy: 0.4932
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6719059756442934
# Train - Acurácia 2:  0.9548286604361371
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 534ms/step - loss: 1.2004 - accuracy: 0.6301 - val_loss: 1.8691 - val_accuracy: 0.4887
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6850750495610308
# Train - Acurácia 2:  0.9657320872274143
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.9070294784580499
# 111/111 [==============================] - 59s 534ms/step - loss: 1.1279 - accuracy: 0.6483 - val_loss: 1.9169 - val_accuracy: 0.4660
# Epoch 17/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7118380062305296
# Train - Acurácia 2:  0.9619088077032002
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 533ms/step - loss: 1.0206 - accuracy: 0.6804 - val_loss: 1.9104 - val_accuracy: 0.4977
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7080147267063155
# Train - Acurácia 2:  0.9644576607193429
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 534ms/step - loss: 0.9502 - accuracy: 0.6964 - val_loss: 2.1678 - val_accuracy: 0.4660
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7550269045596149
# Train - Acurácia 2:  0.969838572642311
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 59s 533ms/step - loss: 0.8683 - accuracy: 0.7212 - val_loss: 2.0614 - val_accuracy: 0.5045
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7560181251770037
# Train - Acurácia 2:  0.9641744548286605
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 59s 534ms/step - loss: 0.8001 - accuracy: 0.7461 - val_loss: 2.2171 - val_accuracy: 0.4830
# Epoch 21/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7638062871707731
# Train - Acurácia 2:  0.9688473520249221
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 59s 534ms/step - loss: 0.7616 - accuracy: 0.7508 - val_loss: 2.2510 - val_accuracy: 0.5011
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8184650240725007
# Train - Acurácia 2:  0.9790427640894931
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 59s 535ms/step - loss: 0.6853 - accuracy: 0.7744 - val_loss: 2.1861 - val_accuracy: 0.5136
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7977909940526763
# Train - Acurácia 2:  0.9743698668932314
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 59s 533ms/step - loss: 0.5938 - accuracy: 0.8094 - val_loss: 2.4349 - val_accuracy: 0.4728
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.841263098272444
# Train - Acurácia 2:  0.9774851316907391
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8662131519274376
# 111/111 [==============================] - 59s 533ms/step - loss: 0.5432 - accuracy: 0.8248 - val_loss: 2.3179 - val_accuracy: 0.4955
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8564146134239592
# Train - Acurácia 2:  0.9756442934013028
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4743 - accuracy: 0.8465 - val_loss: 2.5091 - val_accuracy: 0.4841
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8845935995468706
# Train - Acurácia 2:  0.9847068819031436
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4305 - accuracy: 0.8594 - val_loss: 2.4010 - val_accuracy: 0.5113
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8619371282922684
# Train - Acurácia 2:  0.9866893231379212
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 534ms/step - loss: 0.4531 - accuracy: 0.8532 - val_loss: 2.6235 - val_accuracy: 0.4921
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8889832908524498
# Train - Acurácia 2:  0.9903709997167941
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3935 - accuracy: 0.8733 - val_loss: 2.5160 - val_accuracy: 0.4966
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8717077315208156
# Train - Acurácia 2:  0.9841404701217785
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3642 - accuracy: 0.8805 - val_loss: 2.6842 - val_accuracy: 0.4717
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9134806003964883
# Train - Acurácia 2:  0.9929198527329368
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 534ms/step - loss: 0.3370 - accuracy: 0.8920 - val_loss: 2.5934 - val_accuracy: 0.5079
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9199943358821864
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3079 - accuracy: 0.8951 - val_loss: 2.6938 - val_accuracy: 0.5091
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.907391673746814
# Train - Acurácia 2:  0.9909374114981592
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 534ms/step - loss: 0.3011 - accuracy: 0.8993 - val_loss: 2.7110 - val_accuracy: 0.5068
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8656188048711413
# Train - Acurácia 2:  0.9764939110733504
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3051 - accuracy: 0.8980 - val_loss: 3.0238 - val_accuracy: 0.4728
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9116397621070518
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 534ms/step - loss: 0.2854 - accuracy: 0.8983 - val_loss: 2.8418 - val_accuracy: 0.5011
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9140470121778533
# Train - Acurácia 2:  0.9900877938261116
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2783 - accuracy: 0.9033 - val_loss: 2.7651 - val_accuracy: 0.5113
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8990370999716795
# Train - Acurácia 2:  0.9893797790994052
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2620 - accuracy: 0.9097 - val_loss: 2.7435 - val_accuracy: 0.5023
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.908524497309544
# Train - Acurácia 2:  0.98654772019258
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 59s 534ms/step - loss: 0.2506 - accuracy: 0.9149 - val_loss: 2.8837 - val_accuracy: 0.4841
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9088077032002265
# Train - Acurácia 2:  0.988671764372699
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8571428571428571
# 111/111 [==============================] - 59s 534ms/step - loss: 0.2491 - accuracy: 0.9138 - val_loss: 2.9420 - val_accuracy: 0.4785
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.90583404134806
# Train - Acurácia 2:  0.9879637496459927
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2566 - accuracy: 0.9106 - val_loss: 2.9281 - val_accuracy: 0.5000
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9221183800623053
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2485 - accuracy: 0.9129 - val_loss: 2.9238 - val_accuracy: 0.5193
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8868592466723307
# Train - Acurácia 2:  0.9786179552534693
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 59s 535ms/step - loss: 0.2205 - accuracy: 0.9170 - val_loss: 2.8515 - val_accuracy: 0.4841
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.933305012744265
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 59s 534ms/step - loss: 0.2368 - accuracy: 0.9145 - val_loss: 2.7255 - val_accuracy: 0.5045
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9359954687057491
# Train - Acurácia 2:  0.9967431322571509
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2208 - accuracy: 0.9186 - val_loss: 2.9147 - val_accuracy: 0.5068
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9386859246672331
# Train - Acurácia 2:  0.9985839705465873
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 533ms/step - loss: 0.1946 - accuracy: 0.9274 - val_loss: 2.9658 - val_accuracy: 0.5113
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9212687623902577
# Train - Acurácia 2:  0.9950438969130558
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2076 - accuracy: 0.9203 - val_loss: 2.9343 - val_accuracy: 0.5034
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9357122628150666
# Train - Acurácia 2:  0.9967431322571509
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 534ms/step - loss: 0.2019 - accuracy: 0.9213 - val_loss: 2.9812 - val_accuracy: 0.4989
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9299065420560748
# Train - Acurácia 2:  0.9949022939677146
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 59s 533ms/step - loss: 0.1918 - accuracy: 0.9238 - val_loss: 3.0574 - val_accuracy: 0.4989
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9289153214386859
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2091 - accuracy: 0.9194 - val_loss: 3.1735 - val_accuracy: 0.4977
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9201359388275276
# Train - Acurácia 2:  0.991362220334183
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2270 - accuracy: 0.9146 - val_loss: 3.2129 - val_accuracy: 0.4887
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9307561597281223
# Train - Acurácia 2:  0.9949022939677146
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2407 - accuracy: 0.9082 - val_loss: 2.8785 - val_accuracy: 0.5091
# CPU times: user 52min 10s, sys: 1min 19s, total: 53min 30s
# Wall time: 49min 35s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'3')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k3'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k3',acc)
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_'+'k3',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k3')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k3')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 76ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento morl_6 k=3', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_train_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_morl_6_k=3'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_morl_6_k=3    0.930756    0.993061     0.994902

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação morl_6 k=3', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_validation_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_morl_6_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=3    0.930756    0.993061     0.994902
# 1  validation_morl_6_k=3    0.509070    0.848073     0.887755

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste morl_6 k=3', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_test_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_morl_6_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=3    0.930756    0.993061     0.994902
# 1  validation_morl_6_k=3    0.509070    0.848073     0.887755
# 2        test_morl_6_k=3    0.505669    0.846939     0.875283

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/morl_6_kfold/Resultados_morl_6_k3.xlsx", index=False)

# %% [markdown]
# # k=4

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/treino4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/teste4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/validation4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino4")
VAL_DATASET = os.path.join("/content", "validation4")
TEST_DATASET = os.path.join("/content", "teste4")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 44s - loss: 5.1090 - accuracy: 0.0104
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0857s vs `on_train_batch_end` time: 0.2815s). Check your callbacks.
# 111/111 [==============================] - 9s 76ms/step
# Train - Acurácia 0:  0.16425941659586518
# Train - Acurácia 2:  0.47521948456527896
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.17573696145124718
# validation - Acurácia 2:  0.48072562358276644
# 111/111 [==============================] - 76s 589ms/step - loss: 3.7552 - accuracy: 0.2233 - val_loss: 6.0299 - val_accuracy: 0.1757
# Epoch 2/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.27301047861795524
# Train - Acurácia 2:  0.6267346360804305
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.30385487528344673
# validation - Acurácia 2:  0.6462585034013606
# 111/111 [==============================] - 59s 534ms/step - loss: 2.7538 - accuracy: 0.3442 - val_loss: 3.6932 - val_accuracy: 0.3039
# Epoch 3/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4113565562163693
# Train - Acurácia 2:  0.7738600962900029
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.40249433106575966
# validation - Acurácia 2:  0.7585034013605442
# 111/111 [==============================] - 59s 533ms/step - loss: 2.4371 - accuracy: 0.3867 - val_loss: 2.4426 - val_accuracy: 0.4025
# Epoch 4/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.43457943925233644
# Train - Acurácia 2:  0.8026054941942793
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.43197278911564624
# validation - Acurácia 2:  0.7834467120181405
# 111/111 [==============================] - 59s 534ms/step - loss: 2.2387 - accuracy: 0.4160 - val_loss: 2.2591 - val_accuracy: 0.4320
# Epoch 5/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.454262248654772
# Train - Acurácia 2:  0.8334749362786746
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.8151927437641724
# 111/111 [==============================] - 59s 533ms/step - loss: 2.0562 - accuracy: 0.4531 - val_loss: 2.1951 - val_accuracy: 0.4683
# Epoch 6/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.319173038799207
# Train - Acurácia 2:  0.6849334466156896
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.34467120181405897
# validation - Acurácia 2:  0.68140589569161
# 111/111 [==============================] - 59s 534ms/step - loss: 1.9485 - accuracy: 0.4664 - val_loss: 2.9708 - val_accuracy: 0.3447
# Epoch 7/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4746530727839139
# Train - Acurácia 2:  0.8499008779382611
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.43197278911564624
# validation - Acurácia 2:  0.8310657596371882
# 111/111 [==============================] - 59s 532ms/step - loss: 1.8793 - accuracy: 0.4747 - val_loss: 2.1639 - val_accuracy: 0.4320
# Epoch 8/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.44307561597281225
# Train - Acurácia 2:  0.8596714811668082
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.409297052154195
# validation - Acurácia 2:  0.8390022675736961
# 111/111 [==============================] - 59s 532ms/step - loss: 1.7419 - accuracy: 0.5076 - val_loss: 2.1841 - val_accuracy: 0.4093
# Epoch 9/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5210988388558482
# Train - Acurácia 2:  0.8991787029170206
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4614512471655329
# validation - Acurácia 2:  0.8662131519274376
# 111/111 [==============================] - 59s 532ms/step - loss: 1.6467 - accuracy: 0.5227 - val_loss: 1.9493 - val_accuracy: 0.4615
# Epoch 10/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4694137638062872
# Train - Acurácia 2:  0.7973661852166525
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4217687074829932
# validation - Acurácia 2:  0.7551020408163265
# 111/111 [==============================] - 59s 534ms/step - loss: 1.5607 - accuracy: 0.5439 - val_loss: 2.4465 - val_accuracy: 0.4218
# Epoch 11/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5734919286321155
# Train - Acurácia 2:  0.9209855564995751
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 59s 533ms/step - loss: 1.4768 - accuracy: 0.5575 - val_loss: 1.9650 - val_accuracy: 0.4977
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5935995468705749
# Train - Acurácia 2:  0.9245256301331067
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 59s 532ms/step - loss: 1.3924 - accuracy: 0.5776 - val_loss: 1.9753 - val_accuracy: 0.4751
# Epoch 13/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6457094307561597
# Train - Acurácia 2:  0.9532710280373832
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 59s 533ms/step - loss: 1.3083 - accuracy: 0.5978 - val_loss: 1.8019 - val_accuracy: 0.4955
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5843953554233928
# Train - Acurácia 2:  0.9191447182101388
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4614512471655329
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 535ms/step - loss: 1.2311 - accuracy: 0.6184 - val_loss: 2.0051 - val_accuracy: 0.4615
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6801189464740867
# Train - Acurácia 2:  0.956952704616256
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.528344671201814
# validation - Acurácia 2:  0.9058956916099773
# 111/111 [==============================] - 59s 535ms/step - loss: 1.1249 - accuracy: 0.6490 - val_loss: 1.8698 - val_accuracy: 0.5283
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7128292268479184
# Train - Acurácia 2:  0.9718210138770886
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 59s 533ms/step - loss: 1.0297 - accuracy: 0.6686 - val_loss: 1.9183 - val_accuracy: 0.5057
# Epoch 17/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7448314924950439
# Train - Acurácia 2:  0.9705465873690172
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 59s 533ms/step - loss: 0.9556 - accuracy: 0.6941 - val_loss: 1.8560 - val_accuracy: 0.5181
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7344944774851316
# Train - Acurácia 2:  0.9627584253752478
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5204081632653061
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 532ms/step - loss: 0.9084 - accuracy: 0.7036 - val_loss: 2.0158 - val_accuracy: 0.5204
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6973945058057207
# Train - Acurácia 2:  0.9296233361653923
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8571428571428571
# 111/111 [==============================] - 59s 532ms/step - loss: 0.8025 - accuracy: 0.7424 - val_loss: 2.3356 - val_accuracy: 0.4887
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7907108467856131
# Train - Acurácia 2:  0.9699801755876523
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 59s 533ms/step - loss: 0.7156 - accuracy: 0.7649 - val_loss: 2.2410 - val_accuracy: 0.4853
# Epoch 21/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8153497592749929
# Train - Acurácia 2:  0.9790427640894931
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 59s 532ms/step - loss: 0.6566 - accuracy: 0.7859 - val_loss: 2.1472 - val_accuracy: 0.5136
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7925516850750496
# Train - Acurácia 2:  0.9701217785329935
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 59s 533ms/step - loss: 0.6131 - accuracy: 0.8039 - val_loss: 2.4239 - val_accuracy: 0.4875
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8096856414613424
# Train - Acurácia 2:  0.9532710280373832
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8526077097505669
# 111/111 [==============================] - 59s 532ms/step - loss: 0.5443 - accuracy: 0.8281 - val_loss: 2.5358 - val_accuracy: 0.4966
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8405550835457377
# Train - Acurácia 2:  0.9801755876522231
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 532ms/step - loss: 0.4991 - accuracy: 0.8381 - val_loss: 2.4506 - val_accuracy: 0.5136
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8592466723307844
# Train - Acurácia 2:  0.9835740583404134
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 59s 533ms/step - loss: 0.4852 - accuracy: 0.8401 - val_loss: 2.3837 - val_accuracy: 0.5193
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8717077315208156
# Train - Acurácia 2:  0.985981308411215
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 532ms/step - loss: 0.4277 - accuracy: 0.8638 - val_loss: 2.5154 - val_accuracy: 0.5136
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8751062022090059
# Train - Acurácia 2:  0.9844236760124611
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 532ms/step - loss: 0.3863 - accuracy: 0.8713 - val_loss: 2.4769 - val_accuracy: 0.5136
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8755310110450297
# Train - Acurácia 2:  0.9875389408099688
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3685 - accuracy: 0.8777 - val_loss: 2.4961 - val_accuracy: 0.4898
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8777966581704899
# Train - Acurácia 2:  0.9804587935429057
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 59s 532ms/step - loss: 0.3559 - accuracy: 0.8849 - val_loss: 2.7602 - val_accuracy: 0.5079
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9049844236760125
# Train - Acurácia 2:  0.992495043896913
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3124 - accuracy: 0.8992 - val_loss: 2.5913 - val_accuracy: 0.5057
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9182951005380912
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5226757369614512
# validation - Acurácia 2:  0.9058956916099773
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3034 - accuracy: 0.8997 - val_loss: 2.5369 - val_accuracy: 0.5227
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9056924384027187
# Train - Acurácia 2:  0.9872557349192863
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2948 - accuracy: 0.9031 - val_loss: 2.7045 - val_accuracy: 0.5147
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.916595865193996
# Train - Acurácia 2:  0.9929198527329368
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2806 - accuracy: 0.9070 - val_loss: 2.7577 - val_accuracy: 0.5181
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9120645709430756
# Train - Acurácia 2:  0.9943358821863495
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5102040816326531
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2637 - accuracy: 0.9108 - val_loss: 2.6970 - val_accuracy: 0.5102
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9252336448598131
# Train - Acurácia 2:  0.9966015293118097
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5226757369614512
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2511 - accuracy: 0.9128 - val_loss: 2.7563 - val_accuracy: 0.5227
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9208439535542339
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5238095238095238
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2342 - accuracy: 0.9138 - val_loss: 2.7324 - val_accuracy: 0.5238
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8841687907108468
# Train - Acurácia 2:  0.9822996318323421
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4546485260770975
# validation - Acurácia 2:  0.854875283446712
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2425 - accuracy: 0.9148 - val_loss: 2.8960 - val_accuracy: 0.4546
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9260832625318607
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2420 - accuracy: 0.9115 - val_loss: 2.9664 - val_accuracy: 0.4977
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8602378929481733
# Train - Acurácia 2:  0.9657320872274143
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.826530612244898
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2656 - accuracy: 0.9056 - val_loss: 3.2641 - val_accuracy: 0.4717
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.916595865193996
# Train - Acurácia 2:  0.991362220334183
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2614 - accuracy: 0.9044 - val_loss: 2.8255 - val_accuracy: 0.4932
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8615123194562447
# Train - Acurácia 2:  0.9766355140186916
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2317 - accuracy: 0.9145 - val_loss: 2.8772 - val_accuracy: 0.4717
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9290569243840272
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2303 - accuracy: 0.9150 - val_loss: 2.7947 - val_accuracy: 0.5193
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9291985273293685
# Train - Acurácia 2:  0.9950438969130558
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5249433106575964
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2311 - accuracy: 0.9139 - val_loss: 2.8374 - val_accuracy: 0.5249
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8617955253469273
# Train - Acurácia 2:  0.9746530727839139
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.45691609977324266
# validation - Acurácia 2:  0.8514739229024944
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2518 - accuracy: 0.9109 - val_loss: 2.9923 - val_accuracy: 0.4569
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9131973945058057
# Train - Acurácia 2:  0.9876805437553101
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8594104308390023
# 111/111 [==============================] - 60s 540ms/step - loss: 0.2750 - accuracy: 0.9017 - val_loss: 2.8676 - val_accuracy: 0.5113
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9253752478051543
# Train - Acurácia 2:  0.9934862645143019
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2128 - accuracy: 0.9169 - val_loss: 2.9338 - val_accuracy: 0.5045
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9260832625318607
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2217 - accuracy: 0.9167 - val_loss: 2.8405 - val_accuracy: 0.5181
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9119229679977343
# Train - Acurácia 2:  0.9917870291702068
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2134 - accuracy: 0.9170 - val_loss: 3.0526 - val_accuracy: 0.4943
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.918719909374115
# Train - Acurácia 2:  0.9920702350608893
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8684807256235828
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2081 - accuracy: 0.9201 - val_loss: 3.0528 - val_accuracy: 0.4898
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9352874539790428
# Train - Acurácia 2:  0.9967431322571509
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 532ms/step - loss: 0.1961 - accuracy: 0.9230 - val_loss: 2.8979 - val_accuracy: 0.5193
# CPU times: user 51min 57s, sys: 1min 22s, total: 53min 20s
# Wall time: 50min 24s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'4')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k4'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k4',acc)
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_'+'k4',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k4')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k4')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 76ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento morl_6 k=4', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_train_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_morl_6_k=4'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_morl_6_k=4    0.935287     0.99646     0.996743

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação morl_6 k=4', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_validation_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_morl_6_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=4    0.935287    0.996460     0.996743
# 1  validation_morl_6_k=4    0.519274    0.860544     0.888889

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste morl_6 k=4', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_test_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_morl_6_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=4    0.935287    0.996460     0.996743
# 1  validation_morl_6_k=4    0.519274    0.860544     0.888889
# 2        test_morl_6_k=4    0.511338    0.818594     0.860544

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/morl_6_kfold/Resultados_morl_6_k4.xlsx", index=False)

# %% [markdown]
# # k=5

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/treino5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/teste5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_morl_6_review_split/validation5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino5")
VAL_DATASET = os.path.join("/content", "validation5")
TEST_DATASET = os.path.join("/content", "teste5")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 42s - loss: 5.1372 - accuracy: 0.0208
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0810s vs `on_train_batch_end` time: 0.2681s). Check your callbacks.
# 111/111 [==============================] - 9s 76ms/step
# Train - Acurácia 0:  0.16326819597847636
# Train - Acurácia 2:  0.5117530444633248
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.1564625850340136
# validation - Acurácia 2:  0.4909297052154195
# 111/111 [==============================] - 74s 573ms/step - loss: 4.3118 - accuracy: 0.1483 - val_loss: 4.1683 - val_accuracy: 0.1565
# Epoch 2/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.24199943358821863
# Train - Acurácia 2:  0.5741999433588219
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.2222222222222222
# validation - Acurácia 2:  0.5544217687074829
# 111/111 [==============================] - 59s 536ms/step - loss: 3.0687 - accuracy: 0.2985 - val_loss: 3.6447 - val_accuracy: 0.2222
# Epoch 3/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.26224865477201925
# Train - Acurácia 2:  0.6148399886717644
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.24036281179138322
# validation - Acurácia 2:  0.6031746031746031
# 111/111 [==============================] - 60s 537ms/step - loss: 2.6176 - accuracy: 0.3549 - val_loss: 3.3399 - val_accuracy: 0.2404
# Epoch 4/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.3094024355706599
# Train - Acurácia 2:  0.7710280373831776
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.2947845804988662
# validation - Acurácia 2:  0.7528344671201814
# 111/111 [==============================] - 59s 534ms/step - loss: 2.3770 - accuracy: 0.3873 - val_loss: 2.7519 - val_accuracy: 0.2948
# Epoch 5/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.39308977626734637
# Train - Acurácia 2:  0.8149249504389692
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.36507936507936506
# validation - Acurácia 2:  0.808390022675737
# 111/111 [==============================] - 59s 534ms/step - loss: 2.1621 - accuracy: 0.4199 - val_loss: 2.4677 - val_accuracy: 0.3651
# Epoch 6/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.3799207023506089
# Train - Acurácia 2:  0.8187482299631832
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.35147392290249435
# validation - Acurácia 2:  0.800453514739229
# 111/111 [==============================] - 59s 534ms/step - loss: 2.0196 - accuracy: 0.4487 - val_loss: 2.6490 - val_accuracy: 0.3515
# Epoch 7/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.47111299915038235
# Train - Acurácia 2:  0.8833191730387993
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4217687074829932
# validation - Acurácia 2:  0.854875283446712
# 111/111 [==============================] - 59s 533ms/step - loss: 1.9144 - accuracy: 0.4652 - val_loss: 2.2345 - val_accuracy: 0.4218
# Epoch 8/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4532710280373832
# Train - Acurácia 2:  0.8398470688190315
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4070294784580499
# validation - Acurácia 2:  0.81859410430839
# 111/111 [==============================] - 59s 534ms/step - loss: 1.8361 - accuracy: 0.4854 - val_loss: 2.3200 - val_accuracy: 0.4070
# Epoch 9/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4425092041914472
# Train - Acurácia 2:  0.8448031719059756
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3934240362811791
# validation - Acurácia 2:  0.8310657596371882
# 111/111 [==============================] - 59s 534ms/step - loss: 1.7425 - accuracy: 0.5041 - val_loss: 2.2735 - val_accuracy: 0.3934
# Epoch 10/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5404984423676013
# Train - Acurácia 2:  0.9130557915604645
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 59s 534ms/step - loss: 1.6552 - accuracy: 0.5181 - val_loss: 2.0274 - val_accuracy: 0.4580
# Epoch 11/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5548003398470688
# Train - Acurácia 2:  0.9232512036250354
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 533ms/step - loss: 1.5948 - accuracy: 0.5290 - val_loss: 1.9431 - val_accuracy: 0.4909
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.46799773435287456
# Train - Acurácia 2:  0.9109317473803455
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3888888888888889
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 533ms/step - loss: 1.5575 - accuracy: 0.5365 - val_loss: 2.2187 - val_accuracy: 0.3889
# Epoch 13/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5889266496743132
# Train - Acurácia 2:  0.9260832625318607
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 59s 534ms/step - loss: 1.4477 - accuracy: 0.5673 - val_loss: 2.0200 - val_accuracy: 0.4728
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.613565562163693
# Train - Acurácia 2:  0.9401019541206457
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 533ms/step - loss: 1.3887 - accuracy: 0.5766 - val_loss: 1.9388 - val_accuracy: 0.4853
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6182384593599547
# Train - Acurácia 2:  0.9491645426224865
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 59s 533ms/step - loss: 1.3388 - accuracy: 0.5892 - val_loss: 1.9792 - val_accuracy: 0.4796
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6222033418295101
# Train - Acurácia 2:  0.9553950722175021
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 59s 533ms/step - loss: 1.2759 - accuracy: 0.6049 - val_loss: 1.9633 - val_accuracy: 0.4683
# Epoch 17/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6186632681959785
# Train - Acurácia 2:  0.9535542339280657
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4342403628117914
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 533ms/step - loss: 1.1829 - accuracy: 0.6331 - val_loss: 2.0896 - val_accuracy: 0.4342
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6079014443500425
# Train - Acurácia 2:  0.9409515717926933
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4387755102040816
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 532ms/step - loss: 1.1463 - accuracy: 0.6422 - val_loss: 2.1229 - val_accuracy: 0.4388
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6049277824978759
# Train - Acurácia 2:  0.9442084395355423
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.41836734693877553
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 533ms/step - loss: 1.0732 - accuracy: 0.6572 - val_loss: 2.1857 - val_accuracy: 0.4184
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7177853299348627
# Train - Acurácia 2:  0.9630416312659303
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 532ms/step - loss: 0.9939 - accuracy: 0.6841 - val_loss: 2.1190 - val_accuracy: 0.4898
# Epoch 21/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7361937128292269
# Train - Acurácia 2:  0.967148116680827
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 533ms/step - loss: 0.9692 - accuracy: 0.6933 - val_loss: 2.1834 - val_accuracy: 0.4830
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7551685075049561
# Train - Acurácia 2:  0.9672897196261683
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 532ms/step - loss: 0.8757 - accuracy: 0.7192 - val_loss: 2.1821 - val_accuracy: 0.4807
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7500708014726706
# Train - Acurácia 2:  0.9706881903143585
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 59s 532ms/step - loss: 0.8203 - accuracy: 0.7396 - val_loss: 2.2428 - val_accuracy: 0.4796
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7470971396205041
# Train - Acurácia 2:  0.9651656754460493
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 59s 532ms/step - loss: 0.7570 - accuracy: 0.7547 - val_loss: 2.2244 - val_accuracy: 0.4830
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8146417445482866
# Train - Acurácia 2:  0.9760691022373266
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 533ms/step - loss: 0.6998 - accuracy: 0.7717 - val_loss: 2.3071 - val_accuracy: 0.4943
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7996318323421128
# Train - Acurácia 2:  0.9689889549702634
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 532ms/step - loss: 0.6553 - accuracy: 0.7860 - val_loss: 2.3861 - val_accuracy: 0.4773
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8394222599830077
# Train - Acurácia 2:  0.9797507788161994
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 532ms/step - loss: 0.6316 - accuracy: 0.7960 - val_loss: 2.3630 - val_accuracy: 0.4966
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8370150099122061
# Train - Acurácia 2:  0.9715378079864061
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 59s 533ms/step - loss: 0.5976 - accuracy: 0.8057 - val_loss: 2.4268 - val_accuracy: 0.4875
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.818040215236477
# Train - Acurácia 2:  0.9774851316907391
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4387755102040816
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 533ms/step - loss: 0.5285 - accuracy: 0.8243 - val_loss: 2.6134 - val_accuracy: 0.4388
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8685924667233078
# Train - Acurácia 2:  0.9835740583404134
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 531ms/step - loss: 0.4906 - accuracy: 0.8423 - val_loss: 2.5612 - val_accuracy: 0.4796
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8520249221183801
# Train - Acurácia 2:  0.9821580288870009
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 532ms/step - loss: 0.4582 - accuracy: 0.8488 - val_loss: 2.6158 - val_accuracy: 0.4751
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8860096290002832
# Train - Acurácia 2:  0.9842820730671198
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 59s 531ms/step - loss: 0.4238 - accuracy: 0.8622 - val_loss: 2.5977 - val_accuracy: 0.4807
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8868592466723307
# Train - Acurácia 2:  0.9868309260832625
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4557823129251701
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 532ms/step - loss: 0.4048 - accuracy: 0.8668 - val_loss: 2.6202 - val_accuracy: 0.4558
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8949306145567828
# Train - Acurácia 2:  0.9889549702633815
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 59s 531ms/step - loss: 0.3557 - accuracy: 0.8850 - val_loss: 2.6191 - val_accuracy: 0.5068
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8865760407816483
# Train - Acurácia 2:  0.9818748229963183
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 532ms/step - loss: 0.3422 - accuracy: 0.8917 - val_loss: 2.7816 - val_accuracy: 0.4762
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9146134239592183
# Train - Acurácia 2:  0.9895213820447465
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 532ms/step - loss: 0.3318 - accuracy: 0.8922 - val_loss: 2.8099 - val_accuracy: 0.4830
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8973378646275842
# Train - Acurácia 2:  0.9879637496459927
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4512471655328798
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 533ms/step - loss: 0.3076 - accuracy: 0.8976 - val_loss: 2.8233 - val_accuracy: 0.4512
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9191447182101388
# Train - Acurácia 2:  0.9912206173888417
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 531ms/step - loss: 0.3064 - accuracy: 0.8972 - val_loss: 2.7291 - val_accuracy: 0.5000
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.923534409515718
# Train - Acurácia 2:  0.9926366468422543
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.9070294784580499
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2810 - accuracy: 0.9061 - val_loss: 2.7259 - val_accuracy: 0.4909
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.921976777116964
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2808 - accuracy: 0.9073 - val_loss: 2.8092 - val_accuracy: 0.4660
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9055508354573775
# Train - Acurácia 2:  0.991928632115548
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.45691609977324266
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2809 - accuracy: 0.9068 - val_loss: 2.9441 - val_accuracy: 0.4569
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9164542622486548
# Train - Acurácia 2:  0.9882469555366752
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 532ms/step - loss: 0.3013 - accuracy: 0.8971 - val_loss: 3.1074 - val_accuracy: 0.4909
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9212687623902577
# Train - Acurácia 2:  0.9899461908807703
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2849 - accuracy: 0.9054 - val_loss: 2.8855 - val_accuracy: 0.5011
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9222599830076466
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2620 - accuracy: 0.9099 - val_loss: 2.8720 - val_accuracy: 0.4751
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9178702917020674
# Train - Acurácia 2:  0.9893797790994052
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2599 - accuracy: 0.9133 - val_loss: 2.9760 - val_accuracy: 0.4773
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9299065420560748
# Train - Acurácia 2:  0.9917870291702068
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 532ms/step - loss: 0.2420 - accuracy: 0.9160 - val_loss: 2.8965 - val_accuracy: 0.5000
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9211271594449164
# Train - Acurácia 2:  0.9895213820447465
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.86281179138322
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2207 - accuracy: 0.9194 - val_loss: 3.0692 - val_accuracy: 0.4921
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9211271594449164
# Train - Acurácia 2:  0.9868309260832625
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47392290249433106
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2360 - accuracy: 0.9136 - val_loss: 3.1992 - val_accuracy: 0.4739
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9314641744548287
# Train - Acurácia 2:  0.9934862645143019
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2303 - accuracy: 0.9156 - val_loss: 3.0331 - val_accuracy: 0.4785
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9266496743132258
# Train - Acurácia 2:  0.9917870291702068
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2321 - accuracy: 0.9180 - val_loss: 3.0903 - val_accuracy: 0.4875
# CPU times: user 52min 6s, sys: 1min 18s, total: 53min 25s
# Wall time: 50min 24s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'5')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k5'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_'+'k5',acc)
np.save('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_'+'k5',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k5')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/morl_6_kfold/morl_6_kfold_'+'k5')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 76ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento morl_6 k=5', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_train_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_morl_6_k=5'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_morl_6_k=5     0.92665    0.990513     0.991787

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 75ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação morl_6 k=5', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_validation_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_morl_6_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=5    0.926650    0.990513     0.991787
# 1  validation_morl_6_k=5    0.487528    0.856009     0.884354

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste morl_6 k=5', '/content/drive/MyDrive/Resultados/morl_6_kfold/prev_test_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_morl_6_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_morl_6_k=5    0.926650    0.990513     0.991787
# 1  validation_morl_6_k=5    0.487528    0.856009     0.884354
# 2        test_morl_6_k=5    0.480726    0.816327     0.862812

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/morl_6_kfold/Resultados_morl_6_k5.xlsx", index=False)
