# %%
# !pip install tensorflow==2.5.0
# !pip install numpy==1.20.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
shutil.copy2("/content/drive/MyDrive/utilities.py", "/content/utilities.py")
shutil.copy2("/content/drive/MyDrive/ConvNet.py", "/content/ConvNet.py")
shutil.copy2("/content/drive/MyDrive/config.py", "/content/config.py")
# Out:
# '/content/config.py'

# %%
import ConvNet
import config
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.utils import to_categorical
from tensorflow.data import AUTOTUNE
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import argparse
import os
import numpy as np
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MultiLabelBinarizer
from IPython.display import Audio, clear_output, display
from glob import glob
import random
from utilities import acuracia0, acuracia1, acuracia2
import utilities

# %%
model = ConvNet.ConvNet

# %%
model.summary()

# %% [markdown]
# # k=1

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/treino1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/teste1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/validation1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino1")
VAL_DATASET = os.path.join("/content", "validation1")
TEST_DATASET = os.path.join("/content", "teste1")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7060, 40, 256, 1)
# (883, 40, 256, 1)
# (7060,)
# (883,)
# (883,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 42s - loss: 5.0923 - accuracy: 0.0156
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0822s vs `on_train_batch_end` time: 0.2697s). Check your callbacks.
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.1688385269121813
# Train - Acurácia 2:  0.42337110481586404
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.14609286523216308
# validation - Acurácia 2:  0.42355605889014725
# 111/111 [==============================] - 82s 587ms/step - loss: 4.2343 - accuracy: 0.1581 - val_loss: 4.5509 - val_accuracy: 0.1461
# Epoch 2/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.221671388101983
# Train - Acurácia 2:  0.5706798866855524
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.1970554926387316
# validation - Acurácia 2:  0.551528878822197
# 111/111 [==============================] - 61s 550ms/step - loss: 3.0227 - accuracy: 0.3018 - val_loss: 3.6243 - val_accuracy: 0.1971
# Epoch 3/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.3103399433427762
# Train - Acurácia 2:  0.6847025495750708
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.2718006795016987
# validation - Acurácia 2:  0.6772366930917327
# 111/111 [==============================] - 61s 547ms/step - loss: 2.6373 - accuracy: 0.3467 - val_loss: 2.9313 - val_accuracy: 0.2718
# Epoch 4/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.22521246458923513
# Train - Acurácia 2:  0.668413597733711
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.21404303510758776
# validation - Acurácia 2:  0.6602491506228766
# 111/111 [==============================] - 60s 546ms/step - loss: 2.4086 - accuracy: 0.3822 - val_loss: 3.3090 - val_accuracy: 0.2140
# Epoch 5/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.31501416430594903
# Train - Acurácia 2:  0.678328611898017
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.3035107587768969
# validation - Acurácia 2:  0.6591166477916195
# 111/111 [==============================] - 61s 549ms/step - loss: 2.2203 - accuracy: 0.4198 - val_loss: 3.0258 - val_accuracy: 0.3035
# Epoch 6/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.3856940509915014
# Train - Acurácia 2:  0.7923512747875354
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.3465458663646659
# validation - Acurácia 2:  0.7916194790486977
# 111/111 [==============================] - 60s 546ms/step - loss: 2.0893 - accuracy: 0.4462 - val_loss: 2.5937 - val_accuracy: 0.3465
# Epoch 7/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.41898016997167137
# Train - Acurácia 2:  0.848300283286119
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.36126840317100795
# validation - Acurácia 2:  0.8323895809739524
# 111/111 [==============================] - 60s 546ms/step - loss: 1.9847 - accuracy: 0.4643 - val_loss: 2.3102 - val_accuracy: 0.3613
# Epoch 8/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4767705382436261
# Train - Acurácia 2:  0.8490084985835694
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4144960362400906
# validation - Acurácia 2:  0.8471121177802945
# 111/111 [==============================] - 60s 546ms/step - loss: 1.8752 - accuracy: 0.4846 - val_loss: 2.1841 - val_accuracy: 0.4145
# Epoch 9/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.5371104815864023
# Train - Acurácia 2:  0.911614730878187
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.45866364665911663
# validation - Acurácia 2:  0.8958097395243488
# 111/111 [==============================] - 60s 546ms/step - loss: 1.7995 - accuracy: 0.5006 - val_loss: 1.9596 - val_accuracy: 0.4587
# Epoch 10/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5212464589235127
# Train - Acurácia 2:  0.8994334277620396
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.44847112117780297
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 60s 545ms/step - loss: 1.7121 - accuracy: 0.5191 - val_loss: 1.9558 - val_accuracy: 0.4485
# Epoch 11/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5165722379603399
# Train - Acurácia 2:  0.8963172804532578
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.44847112117780297
# validation - Acurácia 2:  0.883352208380521
# 111/111 [==============================] - 60s 545ms/step - loss: 1.6458 - accuracy: 0.5272 - val_loss: 1.9662 - val_accuracy: 0.4485
# Epoch 12/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5712464589235128
# Train - Acurácia 2:  0.9229461756373938
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.464326160815402
# validation - Acurácia 2:  0.8822197055492639
# 111/111 [==============================] - 60s 544ms/step - loss: 1.5859 - accuracy: 0.5385 - val_loss: 1.8717 - val_accuracy: 0.4643
# Epoch 13/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5810198300283286
# Train - Acurácia 2:  0.93342776203966
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4711211778029445
# validation - Acurácia 2:  0.9026047565118913
# 111/111 [==============================] - 60s 546ms/step - loss: 1.5405 - accuracy: 0.5472 - val_loss: 1.8052 - val_accuracy: 0.4711
# Epoch 14/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5946175637393768
# Train - Acurácia 2:  0.9344192634560906
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48357870894677235
# validation - Acurácia 2:  0.89920724801812
# 111/111 [==============================] - 60s 545ms/step - loss: 1.4912 - accuracy: 0.5592 - val_loss: 1.8583 - val_accuracy: 0.4836
# Epoch 15/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5984419263456091
# Train - Acurácia 2:  0.9359773371104816
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.4733861834654587
# validation - Acurácia 2:  0.8969422423556059
# 111/111 [==============================] - 61s 547ms/step - loss: 1.4072 - accuracy: 0.5717 - val_loss: 1.8844 - val_accuracy: 0.4734
# Epoch 16/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5947592067988668
# Train - Acurácia 2:  0.9178470254957507
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4711211778029445
# validation - Acurácia 2:  0.8731596828992072
# 111/111 [==============================] - 60s 546ms/step - loss: 1.3542 - accuracy: 0.5914 - val_loss: 1.9638 - val_accuracy: 0.4711
# Epoch 17/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5711048158640226
# Train - Acurácia 2:  0.9021246458923513
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.43714609286523215
# validation - Acurácia 2:  0.8437146092865232
# 111/111 [==============================] - 60s 546ms/step - loss: 1.2788 - accuracy: 0.6064 - val_loss: 2.0937 - val_accuracy: 0.4371
# Epoch 18/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.623229461756374
# Train - Acurácia 2:  0.945042492917847
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.46885617214043035
# validation - Acurácia 2:  0.8890147225368064
# 111/111 [==============================] - 60s 544ms/step - loss: 1.2352 - accuracy: 0.6197 - val_loss: 1.9167 - val_accuracy: 0.4689
# Epoch 19/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6745042492917847
# Train - Acurácia 2:  0.9575070821529745
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48357870894677235
# validation - Acurácia 2:  0.9026047565118913
# 111/111 [==============================] - 61s 546ms/step - loss: 1.1884 - accuracy: 0.6263 - val_loss: 1.9064 - val_accuracy: 0.4836
# Epoch 20/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.6750708215297451
# Train - Acurácia 2:  0.9601983002832861
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49263873159682897
# validation - Acurácia 2:  0.9105322763306908
# 111/111 [==============================] - 61s 547ms/step - loss: 1.1215 - accuracy: 0.6484 - val_loss: 1.8681 - val_accuracy: 0.4926
# Epoch 21/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6664305949008499
# Train - Acurácia 2:  0.9460339943342776
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.45300113250283125
# validation - Acurácia 2:  0.8890147225368064
# 111/111 [==============================] - 60s 545ms/step - loss: 1.0422 - accuracy: 0.6703 - val_loss: 2.0436 - val_accuracy: 0.4530
# Epoch 22/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6426345609065156
# Train - Acurácia 2:  0.9382436260623229
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4405436013590034
# validation - Acurácia 2:  0.8663646659116648
# 111/111 [==============================] - 60s 544ms/step - loss: 0.9806 - accuracy: 0.6875 - val_loss: 2.1400 - val_accuracy: 0.4405
# Epoch 23/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7216713881019831
# Train - Acurácia 2:  0.9635977337110482
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47904869762174407
# validation - Acurácia 2:  0.8980747451868629
# 111/111 [==============================] - 60s 545ms/step - loss: 0.9580 - accuracy: 0.6984 - val_loss: 2.0315 - val_accuracy: 0.4790
# Epoch 24/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.7008498583569405
# Train - Acurácia 2:  0.9512747875354107
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.45186862967157415
# validation - Acurácia 2:  0.8799546998867497
# 111/111 [==============================] - 61s 546ms/step - loss: 0.8630 - accuracy: 0.7170 - val_loss: 2.1494 - val_accuracy: 0.4519
# Epoch 25/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7361189801699717
# Train - Acurácia 2:  0.9694050991501416
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4552661381653454
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 61s 547ms/step - loss: 0.8442 - accuracy: 0.7296 - val_loss: 2.2437 - val_accuracy: 0.4553
# Epoch 26/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.734985835694051
# Train - Acurácia 2:  0.96657223796034
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.47904869762174407
# validation - Acurácia 2:  0.9014722536806342
# 111/111 [==============================] - 60s 544ms/step - loss: 0.7758 - accuracy: 0.7465 - val_loss: 2.2925 - val_accuracy: 0.4790
# Epoch 27/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.795042492917847
# Train - Acurácia 2:  0.9736543909348442
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.45866364665911663
# validation - Acurácia 2:  0.8935447338618346
# 111/111 [==============================] - 60s 546ms/step - loss: 0.7429 - accuracy: 0.7622 - val_loss: 2.2750 - val_accuracy: 0.4587
# Epoch 28/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7944759206798867
# Train - Acurácia 2:  0.9678470254957507
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48357870894677235
# validation - Acurácia 2:  0.8776896942242356
# 111/111 [==============================] - 60s 546ms/step - loss: 0.6771 - accuracy: 0.7823 - val_loss: 2.4297 - val_accuracy: 0.4836
# Epoch 29/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8457507082152974
# Train - Acurácia 2:  0.9838526912181303
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49263873159682897
# validation - Acurácia 2:  0.8980747451868629
# 111/111 [==============================] - 60s 545ms/step - loss: 0.6130 - accuracy: 0.8033 - val_loss: 2.2943 - val_accuracy: 0.4926
# Epoch 30/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8328611898016998
# Train - Acurácia 2:  0.9756373937677054
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4869762174405436
# validation - Acurácia 2:  0.883352208380521
# 111/111 [==============================] - 60s 545ms/step - loss: 0.5793 - accuracy: 0.8118 - val_loss: 2.4162 - val_accuracy: 0.4870
# Epoch 31/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8590651558073654
# Train - Acurácia 2:  0.9815864022662889
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4881087202718007
# validation - Acurácia 2:  0.8924122310305775
# 111/111 [==============================] - 60s 545ms/step - loss: 0.5758 - accuracy: 0.8190 - val_loss: 2.4404 - val_accuracy: 0.4881
# Epoch 32/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8703966005665722
# Train - Acurácia 2:  0.9852691218130312
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48584371460928655
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 61s 546ms/step - loss: 0.5144 - accuracy: 0.8387 - val_loss: 2.4676 - val_accuracy: 0.4858
# Epoch 33/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8529745042492918
# Train - Acurácia 2:  0.978186968838527
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5005662514156285
# validation - Acurácia 2:  0.8878822197055493
# 111/111 [==============================] - 60s 545ms/step - loss: 0.4822 - accuracy: 0.8463 - val_loss: 2.4879 - val_accuracy: 0.5006
# Epoch 34/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8405099150141643
# Train - Acurácia 2:  0.9759206798866855
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.46885617214043035
# validation - Acurácia 2:  0.8890147225368064
# 111/111 [==============================] - 60s 544ms/step - loss: 0.4385 - accuracy: 0.8646 - val_loss: 2.7254 - val_accuracy: 0.4689
# Epoch 35/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8930594900849859
# Train - Acurácia 2:  0.9847025495750709
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5005662514156285
# validation - Acurácia 2:  0.8890147225368064
# 111/111 [==============================] - 60s 543ms/step - loss: 0.4257 - accuracy: 0.8642 - val_loss: 2.4910 - val_accuracy: 0.5006
# Epoch 36/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9032577903682719
# Train - Acurácia 2:  0.9896600566572238
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5118912797281994
# validation - Acurácia 2:  0.89920724801812
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3854 - accuracy: 0.8768 - val_loss: 2.4889 - val_accuracy: 0.5119
# Epoch 37/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8971671388101983
# Train - Acurácia 2:  0.988243626062323
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49943374858437145
# validation - Acurácia 2:  0.9014722536806342
# 111/111 [==============================] - 60s 543ms/step - loss: 0.3628 - accuracy: 0.8809 - val_loss: 2.6047 - val_accuracy: 0.4994
# Epoch 38/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8995750708215298
# Train - Acurácia 2:  0.9889518413597733
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5198187995469988
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3787 - accuracy: 0.8797 - val_loss: 2.7030 - val_accuracy: 0.5198
# Epoch 39/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8777620396600566
# Train - Acurácia 2:  0.9889518413597733
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4507361268403171
# validation - Acurácia 2:  0.8890147225368064
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3645 - accuracy: 0.8816 - val_loss: 2.9762 - val_accuracy: 0.4507
# Epoch 40/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9090651558073655
# Train - Acurácia 2:  0.9896600566572238
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5198187995469988
# validation - Acurácia 2:  0.8969422423556059
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3326 - accuracy: 0.8902 - val_loss: 2.7153 - val_accuracy: 0.5198
# Epoch 41/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9198300283286119
# Train - Acurácia 2:  0.9930594900849858
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4971687429218573
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3326 - accuracy: 0.8942 - val_loss: 2.8424 - val_accuracy: 0.4972
# Epoch 42/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9174220963172804
# Train - Acurácia 2:  0.9939093484419264
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5130237825594564
# validation - Acurácia 2:  0.8935447338618346
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3006 - accuracy: 0.9021 - val_loss: 2.7543 - val_accuracy: 0.5130
# Epoch 43/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9308781869688385
# Train - Acurácia 2:  0.9930594900849858
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5050962627406569
# validation - Acurácia 2:  0.9014722536806342
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2888 - accuracy: 0.9044 - val_loss: 2.6561 - val_accuracy: 0.5051
# Epoch 44/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9094900849858357
# Train - Acurácia 2:  0.9902266288951841
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4869762174405436
# validation - Acurácia 2:  0.8946772366930917
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2908 - accuracy: 0.9040 - val_loss: 2.8679 - val_accuracy: 0.4870
# Epoch 45/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.921529745042493
# Train - Acurácia 2:  0.9919263456090651
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49150622876557193
# validation - Acurácia 2:  0.8878822197055493
# 111/111 [==============================] - 60s 545ms/step - loss: 0.3053 - accuracy: 0.8994 - val_loss: 2.8527 - val_accuracy: 0.4915
# Epoch 46/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8944759206798867
# Train - Acurácia 2:  0.9885269121813031
# 14/14 [==============================] - 1s 82ms/step
# Validation - Acurácia 0:  0.4665911664779162
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 62s 561ms/step - loss: 0.2612 - accuracy: 0.9143 - val_loss: 3.1515 - val_accuracy: 0.4666
# Epoch 47/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9211048158640227
# Train - Acurácia 2:  0.9915014164305949
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5096262740656852
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 61s 547ms/step - loss: 0.2924 - accuracy: 0.9044 - val_loss: 2.8556 - val_accuracy: 0.5096
# Epoch 48/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9194050991501417
# Train - Acurácia 2:  0.9902266288951841
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4960362400906002
# validation - Acurácia 2:  0.8844847112117781
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2672 - accuracy: 0.9076 - val_loss: 3.1409 - val_accuracy: 0.4960
# Epoch 49/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9382436260623229
# Train - Acurácia 2:  0.9950424929178471
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5028312570781427
# validation - Acurácia 2:  0.9071347678369196
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2408 - accuracy: 0.9160 - val_loss: 2.8543 - val_accuracy: 0.5028
# Epoch 50/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.9373937677053824
# Train - Acurácia 2:  0.9943342776203966
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5028312570781427
# validation - Acurácia 2:  0.8969422423556059
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2201 - accuracy: 0.9215 - val_loss: 2.8736 - val_accuracy: 0.5028
# CPU times: user 53min 23s, sys: 1min 37s, total: 55min
# Wall time: 50min 43s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'1')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k1'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k1',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_'+'k1',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k1')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k1')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 9s 78ms/step
# (7060, 140)
# (7060,)
# (7060,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_6 k=1', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_train_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_6_k=1'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_6_k=1    0.937394    0.994051     0.994334

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 78ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_6 k=1', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_validation_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_6_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=1    0.937394    0.994051     0.994334
# 1  validation_mexh_6_k=1    0.502831    0.858437     0.896942

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 78ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_6 k=1', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_test_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_6_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=1    0.937394    0.994051     0.994334
# 1  validation_mexh_6_k=1    0.502831    0.858437     0.896942
# 2        test_mexh_6_k=1    0.546999    0.847112     0.879955

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_6_kfold/Resultados_mexh_6_k1.xlsx", index=False)

# %% [markdown]
# # k=2

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/treino2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/teste2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/validation2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino2")
VAL_DATASET = os.path.join("/content", "validation2")
TEST_DATASET = os.path.join("/content", "teste2")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 46s - loss: 5.2173 - accuracy: 0.0104
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0890s vs `on_train_batch_end` time: 0.2945s). Check your callbacks.
# 111/111 [==============================] - 9s 77ms/step
# Train - Acurácia 0:  0.09756442934013028
# Train - Acurácia 2:  0.40201076182384593
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.1054421768707483
# validation - Acurácia 2:  0.4126984126984127
# 111/111 [==============================] - 78s 603ms/step - loss: 4.2195 - accuracy: 0.1545 - val_loss: 7.8637 - val_accuracy: 0.1054
# Epoch 2/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.25049561030869444
# Train - Acurácia 2:  0.6384876805437553
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.2732426303854875
# validation - Acurácia 2:  0.6281179138321995
# 111/111 [==============================] - 61s 548ms/step - loss: 2.9127 - accuracy: 0.3243 - val_loss: 3.6667 - val_accuracy: 0.2732
# Epoch 3/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.3746813933729822
# Train - Acurácia 2:  0.7711696403285189
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.35714285714285715
# validation - Acurácia 2:  0.7551020408163265
# 111/111 [==============================] - 61s 547ms/step - loss: 2.5175 - accuracy: 0.3801 - val_loss: 2.6818 - val_accuracy: 0.3571
# Epoch 4/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.3967714528462192
# Train - Acurácia 2:  0.7942509204191447
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.3798185941043084
# validation - Acurácia 2:  0.7743764172335601
# 111/111 [==============================] - 61s 548ms/step - loss: 2.2822 - accuracy: 0.4156 - val_loss: 2.4503 - val_accuracy: 0.3798
# Epoch 5/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.2936845086377797
# Train - Acurácia 2:  0.6588785046728972
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.2675736961451247
# validation - Acurácia 2:  0.6315192743764172
# 111/111 [==============================] - 61s 547ms/step - loss: 2.0868 - accuracy: 0.4422 - val_loss: 3.2961 - val_accuracy: 0.2676
# Epoch 6/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.43811951288586803
# Train - Acurácia 2:  0.8528745397904276
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.3945578231292517
# validation - Acurácia 2:  0.8061224489795918
# 111/111 [==============================] - 61s 547ms/step - loss: 1.9856 - accuracy: 0.4691 - val_loss: 2.3130 - val_accuracy: 0.3946
# Epoch 7/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.47677711696403285
# Train - Acurácia 2:  0.8661852166525064
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.42630385487528344
# validation - Acurácia 2:  0.8378684807256236
# 111/111 [==============================] - 61s 548ms/step - loss: 1.8757 - accuracy: 0.4843 - val_loss: 2.1456 - val_accuracy: 0.4263
# Epoch 8/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.491928632115548
# Train - Acurácia 2:  0.8847352024922118
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.427437641723356
# validation - Acurácia 2:  0.8503401360544217
# 111/111 [==============================] - 60s 546ms/step - loss: 1.7793 - accuracy: 0.5007 - val_loss: 2.1469 - val_accuracy: 0.4274
# Epoch 9/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5351175304446333
# Train - Acurácia 2:  0.9086661002548853
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.463718820861678
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 545ms/step - loss: 1.7103 - accuracy: 0.5101 - val_loss: 2.0300 - val_accuracy: 0.4637
# Epoch 10/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5387992070235061
# Train - Acurácia 2:  0.910648541489663
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4478458049886621
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 60s 545ms/step - loss: 1.6488 - accuracy: 0.5285 - val_loss: 2.0337 - val_accuracy: 0.4478
# Epoch 11/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5604644576607194
# Train - Acurácia 2:  0.9250920419144718
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 61s 546ms/step - loss: 1.5843 - accuracy: 0.5387 - val_loss: 1.9430 - val_accuracy: 0.4796
# Epoch 12/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5849617672047579
# Train - Acurácia 2:  0.9338714245256301
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.9024943310657596
# 111/111 [==============================] - 60s 546ms/step - loss: 1.5298 - accuracy: 0.5480 - val_loss: 1.8661 - val_accuracy: 0.5034
# Epoch 13/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5981308411214953
# Train - Acurácia 2:  0.9340130274709714
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 61s 546ms/step - loss: 1.4594 - accuracy: 0.5681 - val_loss: 1.9169 - val_accuracy: 0.4898
# Epoch 14/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6060606060606061
# Train - Acurácia 2:  0.9376947040498442
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 545ms/step - loss: 1.3995 - accuracy: 0.5766 - val_loss: 1.9532 - val_accuracy: 0.4841
# Epoch 15/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.614131973945058
# Train - Acurácia 2:  0.9342962333616539
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 60s 546ms/step - loss: 1.3348 - accuracy: 0.5944 - val_loss: 1.8678 - val_accuracy: 0.4966
# Epoch 16/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6163976210705183
# Train - Acurácia 2:  0.9410931747380346
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 545ms/step - loss: 1.2617 - accuracy: 0.6105 - val_loss: 2.0000 - val_accuracy: 0.4717
# Epoch 17/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6261682242990654
# Train - Acurácia 2:  0.9478901161144152
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.9058956916099773
# 111/111 [==============================] - 60s 546ms/step - loss: 1.2159 - accuracy: 0.6219 - val_loss: 2.0249 - val_accuracy: 0.4773
# Epoch 18/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6563296516567545
# Train - Acurácia 2:  0.9552534692721608
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 60s 545ms/step - loss: 1.1642 - accuracy: 0.6364 - val_loss: 1.9676 - val_accuracy: 0.5045
# Epoch 19/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.677570093457944
# Train - Acurácia 2:  0.9589351458510337
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5102040816326531
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 60s 544ms/step - loss: 1.0738 - accuracy: 0.6620 - val_loss: 1.9365 - val_accuracy: 0.5102
# Epoch 20/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.699660152931181
# Train - Acurácia 2:  0.9568111016709148
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 545ms/step - loss: 1.0304 - accuracy: 0.6685 - val_loss: 2.0572 - val_accuracy: 0.4955
# Epoch 21/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7203341829510054
# Train - Acurácia 2:  0.965024072500708
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 60s 546ms/step - loss: 0.9840 - accuracy: 0.6815 - val_loss: 2.0325 - val_accuracy: 0.4977
# Epoch 22/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7444066836590201
# Train - Acurácia 2:  0.9705465873690172
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 61s 547ms/step - loss: 0.8953 - accuracy: 0.7093 - val_loss: 2.0761 - val_accuracy: 0.5000
# Epoch 23/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7604078164825828
# Train - Acurácia 2:  0.9653072783913905
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 544ms/step - loss: 0.8370 - accuracy: 0.7305 - val_loss: 2.1560 - val_accuracy: 0.4932
# Epoch 24/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7594165958651939
# Train - Acurácia 2:  0.9726706315491362
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 60s 546ms/step - loss: 0.7846 - accuracy: 0.7431 - val_loss: 2.1840 - val_accuracy: 0.5079
# Epoch 25/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.786321155480034
# Train - Acurácia 2:  0.9692721608609459
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 60s 546ms/step - loss: 0.7312 - accuracy: 0.7600 - val_loss: 2.2456 - val_accuracy: 0.5034
# Epoch 26/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7938261115831209
# Train - Acurácia 2:  0.9645992636646842
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 545ms/step - loss: 0.6682 - accuracy: 0.7787 - val_loss: 2.3610 - val_accuracy: 0.5057
# Epoch 27/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8201642594165959
# Train - Acurácia 2:  0.9750778816199377
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 544ms/step - loss: 0.6100 - accuracy: 0.8064 - val_loss: 2.2952 - val_accuracy: 0.5079
# Epoch 28/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8394222599830077
# Train - Acurácia 2:  0.9806003964882469
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.9036281179138322
# 111/111 [==============================] - 60s 544ms/step - loss: 0.5488 - accuracy: 0.8173 - val_loss: 2.4214 - val_accuracy: 0.5091
# Epoch 29/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8535825545171339
# Train - Acurácia 2:  0.9842820730671198
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 60s 545ms/step - loss: 0.4910 - accuracy: 0.8437 - val_loss: 2.4128 - val_accuracy: 0.5045
# Epoch 30/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8813367318040215
# Train - Acurácia 2:  0.9878221467006514
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 545ms/step - loss: 0.4665 - accuracy: 0.8506 - val_loss: 2.4388 - val_accuracy: 0.4943
# Epoch 31/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8862928348909658
# Train - Acurácia 2:  0.9869725290286038
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.9036281179138322
# 111/111 [==============================] - 60s 545ms/step - loss: 0.4467 - accuracy: 0.8549 - val_loss: 2.3738 - val_accuracy: 0.5181
# Epoch 32/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8840271877655055
# Train - Acurácia 2:  0.9851316907391674
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 60s 545ms/step - loss: 0.4270 - accuracy: 0.8624 - val_loss: 2.4796 - val_accuracy: 0.5068
# Epoch 33/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8653355989804588
# Train - Acurácia 2:  0.9772019258000566
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 545ms/step - loss: 0.3903 - accuracy: 0.8710 - val_loss: 2.6699 - val_accuracy: 0.5079
# Epoch 34/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8970546587369017
# Train - Acurácia 2:  0.9903709997167941
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 546ms/step - loss: 0.3670 - accuracy: 0.8789 - val_loss: 2.6835 - val_accuracy: 0.4966
# Epoch 35/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9055508354573775
# Train - Acurácia 2:  0.989804587935429
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3746 - accuracy: 0.8794 - val_loss: 2.6811 - val_accuracy: 0.5045
# Epoch 36/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8884168790710847
# Train - Acurácia 2:  0.9813084112149533
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 60s 545ms/step - loss: 0.3209 - accuracy: 0.8932 - val_loss: 2.7127 - val_accuracy: 0.5034
# Epoch 37/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9225431888983291
# Train - Acurácia 2:  0.9934862645143019
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.9024943310657596
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3182 - accuracy: 0.8959 - val_loss: 2.6988 - val_accuracy: 0.5091
# Epoch 38/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9170206740300199
# Train - Acurácia 2:  0.9912206173888417
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2839 - accuracy: 0.9065 - val_loss: 3.0328 - val_accuracy: 0.4841
# Epoch 39/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8988954970263382
# Train - Acurácia 2:  0.9822996318323421
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5170068027210885
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3166 - accuracy: 0.8927 - val_loss: 2.8075 - val_accuracy: 0.5170
# Epoch 40/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9124893797790994
# Train - Acurácia 2:  0.9896629849900878
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3140 - accuracy: 0.8937 - val_loss: 2.8163 - val_accuracy: 0.5091
# Epoch 41/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9308977626734636
# Train - Acurácia 2:  0.9937694704049844
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2911 - accuracy: 0.9037 - val_loss: 2.7255 - val_accuracy: 0.5113
# Epoch 42/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8575474369866893
# Train - Acurácia 2:  0.9534126309827244
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4467120181405896
# validation - Acurácia 2:  0.8378684807256236
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2527 - accuracy: 0.9129 - val_loss: 3.0738 - val_accuracy: 0.4467
# Epoch 43/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9222599830076466
# Train - Acurácia 2:  0.9905126026621354
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2496 - accuracy: 0.9156 - val_loss: 3.0436 - val_accuracy: 0.4875
# Epoch 44/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9369866893231379
# Train - Acurácia 2:  0.9954687057490795
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2321 - accuracy: 0.9174 - val_loss: 2.9119 - val_accuracy: 0.5057
# Epoch 45/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9136222033418295
# Train - Acurácia 2:  0.9890965732087228
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2350 - accuracy: 0.9149 - val_loss: 3.0283 - val_accuracy: 0.4796
# Epoch 46/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9300481450014161
# Train - Acurácia 2:  0.9939110733503257
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2409 - accuracy: 0.9125 - val_loss: 3.0928 - val_accuracy: 0.5000
# Epoch 47/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9314641744548287
# Train - Acurácia 2:  0.9950438969130558
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2316 - accuracy: 0.9186 - val_loss: 3.1229 - val_accuracy: 0.4853
# Epoch 48/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9258000566411781
# Train - Acurácia 2:  0.9915038232795242
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8650793650793651
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2265 - accuracy: 0.9174 - val_loss: 3.2495 - val_accuracy: 0.4807
# Epoch 49/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9324553950722175
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2195 - accuracy: 0.9207 - val_loss: 3.2929 - val_accuracy: 0.4875
# Epoch 50/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9327386009629001
# Train - Acurácia 2:  0.9963183234211271
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2194 - accuracy: 0.9204 - val_loss: 3.2162 - val_accuracy: 0.4898
# CPU times: user 53min 25s, sys: 1min 35s, total: 55min
# Wall time: 50min 38s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'2')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k2'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k2',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_'+'k2',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k2')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k2')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 9s 78ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_6 k=2', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_train_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_6_k=2'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_6_k=2    0.932739    0.995185     0.996318

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 78ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_6 k=2', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_validation_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_6_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=2    0.932739    0.995185     0.996318
# 1  validation_mexh_6_k=2    0.489796    0.862812     0.891156

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 78ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_6 k=2', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_test_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_6_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=2    0.932739    0.995185     0.996318
# 1  validation_mexh_6_k=2    0.489796    0.862812     0.891156
# 2        test_mexh_6_k=2    0.506803    0.851474     0.882086

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_6_kfold/Resultados_mexh_6_k2.xlsx", index=False)

# %% [markdown]
# # k=3

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/treino3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/teste3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/validation3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino3")
VAL_DATASET = os.path.join("/content", "validation3")
TEST_DATASET = os.path.join("/content", "teste3")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])
# Out:
# [[[ 0.81371945]
#   [ 0.2981047 ]
#   [ 0.2981047 ]
#   ...
#   [-0.41086558]
#   [-0.47531742]
#   [-0.6042211 ]]
#
#  [[ 0.8781713 ]
#   [ 0.36255655]
#   [ 0.2981047 ]
#   ...
#   [-0.53976923]
#   [-0.6042211 ]
#   [-0.7331248 ]]
#
#  [[ 0.94262314]
#   [ 0.4270084 ]
#   [ 0.36255655]
#   ...
#   [-0.41086558]
#   [-0.53976923]
#   [-0.6042211 ]]
#
#  ...
#
#  [[-0.7331248 ]
#   [-0.7331248 ]
#   [-0.7331248 ]
#   ...
#   [-0.7331248 ]
#   [-0.7331248 ]
#   [-0.7331248 ]]
#
#  [[-0.7331248 ]
#   [-0.7331248 ]
#   [-0.7331248 ]
#   ...
#   [-0.7331248 ]
#   [-0.7331248 ]
#   [-0.7331248 ]]
#
#  [[-0.7331248 ]
#   [-0.7331248 ]
#   [-0.7331248 ]
#   ...
#   [-0.7331248 ]
#   [-0.7331248 ]
#   [-0.7331248 ]]]

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 46s - loss: 5.1264 - accuracy: 0.0260
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0920s vs `on_train_batch_end` time: 0.2927s). Check your callbacks.
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.09388275276125743
# Train - Acurácia 2:  0.3143585386576041
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.08049886621315193
# validation - Acurácia 2:  0.30045351473922904
# 111/111 [==============================] - 78s 604ms/step - loss: 3.9304 - accuracy: 0.2134 - val_loss: 8.1837 - val_accuracy: 0.0805
# Epoch 2/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.2751345227980742
# Train - Acurácia 2:  0.5579156046445766
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.264172335600907
# validation - Acurácia 2:  0.5578231292517006
# 111/111 [==============================] - 61s 548ms/step - loss: 2.8317 - accuracy: 0.3469 - val_loss: 3.6642 - val_accuracy: 0.2642
# Epoch 3/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.42070235060889266
# Train - Acurácia 2:  0.8047295383743982
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.4013605442176871
# validation - Acurácia 2:  0.8106575963718821
# 111/111 [==============================] - 60s 545ms/step - loss: 2.4340 - accuracy: 0.4012 - val_loss: 2.3688 - val_accuracy: 0.4014
# Epoch 4/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.45227980741999435
# Train - Acurácia 2:  0.8588218634947606
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.41496598639455784
# validation - Acurácia 2:  0.8594104308390023
# 111/111 [==============================] - 61s 547ms/step - loss: 2.1841 - accuracy: 0.4398 - val_loss: 2.1912 - val_accuracy: 0.4150
# Epoch 5/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.49447748513169076
# Train - Acurácia 2:  0.8881336731804022
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4399092970521542
# validation - Acurácia 2:  0.8514739229024944
# 111/111 [==============================] - 61s 547ms/step - loss: 2.0096 - accuracy: 0.4653 - val_loss: 2.0858 - val_accuracy: 0.4399
# Epoch 6/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.49603511753044466
# Train - Acurácia 2:  0.8725573491928632
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.43197278911564624
# validation - Acurácia 2:  0.8503401360544217
# 111/111 [==============================] - 61s 546ms/step - loss: 1.9001 - accuracy: 0.4833 - val_loss: 2.0646 - val_accuracy: 0.4320
# Epoch 7/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5392240158595298
# Train - Acurácia 2:  0.9184367034834324
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 545ms/step - loss: 1.7731 - accuracy: 0.5072 - val_loss: 1.9084 - val_accuracy: 0.4603
# Epoch 8/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4777683375814217
# Train - Acurácia 2:  0.8875672613990371
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.41723356009070295
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 60s 545ms/step - loss: 1.6944 - accuracy: 0.5195 - val_loss: 2.1180 - val_accuracy: 0.4172
# Epoch 9/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.5733503256867742
# Train - Acurácia 2:  0.9300481450014161
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 61s 547ms/step - loss: 1.6257 - accuracy: 0.5365 - val_loss: 1.8237 - val_accuracy: 0.5079
# Epoch 10/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.536108751062022
# Train - Acurácia 2:  0.9335882186349476
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.46825396825396826
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 546ms/step - loss: 1.5238 - accuracy: 0.5515 - val_loss: 1.9217 - val_accuracy: 0.4683
# Epoch 11/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5977060322854716
# Train - Acurácia 2:  0.9351458510337015
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 60s 546ms/step - loss: 1.4774 - accuracy: 0.5556 - val_loss: 1.8290 - val_accuracy: 0.4955
# Epoch 12/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.5681110167091475
# Train - Acurácia 2:  0.9318889832908525
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.4546485260770975
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 60s 545ms/step - loss: 1.3957 - accuracy: 0.5828 - val_loss: 1.9658 - val_accuracy: 0.4546
# Epoch 13/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.610875106202209
# Train - Acurácia 2:  0.9440668365902011
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 61s 546ms/step - loss: 1.3332 - accuracy: 0.5903 - val_loss: 1.8637 - val_accuracy: 0.4932
# Epoch 14/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6087510620220901
# Train - Acurácia 2:  0.9337298215802888
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.45691609977324266
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 60s 546ms/step - loss: 1.2473 - accuracy: 0.6212 - val_loss: 1.9810 - val_accuracy: 0.4569
# Epoch 15/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6547720192580005
# Train - Acurácia 2:  0.9437836306995185
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 61s 546ms/step - loss: 1.2001 - accuracy: 0.6236 - val_loss: 1.9523 - val_accuracy: 0.5068
# Epoch 16/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6707731520815633
# Train - Acurácia 2:  0.9583687340696686
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.46258503401360546
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 545ms/step - loss: 1.1205 - accuracy: 0.6487 - val_loss: 1.9946 - val_accuracy: 0.4626
# Epoch 17/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6873406966864911
# Train - Acurácia 2:  0.9576607193429624
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 60s 546ms/step - loss: 1.0450 - accuracy: 0.6699 - val_loss: 2.0231 - val_accuracy: 0.4864
# Epoch 18/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7342112715944492
# Train - Acurácia 2:  0.967148116680827
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 60s 545ms/step - loss: 0.9289 - accuracy: 0.7007 - val_loss: 1.9347 - val_accuracy: 0.4955
# Epoch 19/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.7159444916454262
# Train - Acurácia 2:  0.954262248654772
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 546ms/step - loss: 0.8740 - accuracy: 0.7169 - val_loss: 2.2450 - val_accuracy: 0.4603
# Epoch 20/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.7632398753894081
# Train - Acurácia 2:  0.9740866610025488
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 545ms/step - loss: 0.8091 - accuracy: 0.7359 - val_loss: 2.2015 - val_accuracy: 0.4864
# Epoch 21/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.802463891248938
# Train - Acurácia 2:  0.9774851316907391
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 546ms/step - loss: 0.7334 - accuracy: 0.7601 - val_loss: 2.1182 - val_accuracy: 0.5045
# Epoch 22/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8290852449730954
# Train - Acurácia 2:  0.9828660436137072
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 60s 545ms/step - loss: 0.6618 - accuracy: 0.7877 - val_loss: 2.1232 - val_accuracy: 0.5091
# Epoch 23/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.838006230529595
# Train - Acurácia 2:  0.9790427640894931
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 545ms/step - loss: 0.6297 - accuracy: 0.7951 - val_loss: 2.2861 - val_accuracy: 0.5045
# Epoch 24/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.8521665250637214
# Train - Acurácia 2:  0.9845652789578023
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 60s 544ms/step - loss: 0.5475 - accuracy: 0.8236 - val_loss: 2.3224 - val_accuracy: 0.4762
# Epoch 25/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.8535825545171339
# Train - Acurácia 2:  0.9831492495043896
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 60s 545ms/step - loss: 0.4970 - accuracy: 0.8421 - val_loss: 2.4045 - val_accuracy: 0.4966
# Epoch 26/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8738317757009346
# Train - Acurácia 2:  0.9851316907391674
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47052154195011336
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 60s 544ms/step - loss: 0.4583 - accuracy: 0.8564 - val_loss: 2.6032 - val_accuracy: 0.4705
# Epoch 27/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8988954970263382
# Train - Acurácia 2:  0.9906542056074766
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 545ms/step - loss: 0.4105 - accuracy: 0.8685 - val_loss: 2.3958 - val_accuracy: 0.4955
# Epoch 28/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8916737468139337
# Train - Acurácia 2:  0.9896629849900878
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 60s 545ms/step - loss: 0.3961 - accuracy: 0.8704 - val_loss: 2.5449 - val_accuracy: 0.4807
# Epoch 29/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8960634381195128
# Train - Acurácia 2:  0.9927782497875955
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3757 - accuracy: 0.8774 - val_loss: 2.7936 - val_accuracy: 0.4785
# Epoch 30/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.90583404134806
# Train - Acurácia 2:  0.994052676295667
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3508 - accuracy: 0.8816 - val_loss: 2.5976 - val_accuracy: 0.4909
# Epoch 31/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9030019824412348
# Train - Acurácia 2:  0.9872557349192863
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3106 - accuracy: 0.8982 - val_loss: 2.6009 - val_accuracy: 0.5011
# Epoch 32/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9042764089493062
# Train - Acurácia 2:  0.9912206173888417
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3467 - accuracy: 0.8825 - val_loss: 2.6419 - val_accuracy: 0.4909
# Epoch 33/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9190031152647975
# Train - Acurácia 2:  0.988671764372699
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3154 - accuracy: 0.8917 - val_loss: 2.6775 - val_accuracy: 0.5011
# Epoch 34/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9199943358821864
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2903 - accuracy: 0.9040 - val_loss: 2.7518 - val_accuracy: 0.5011
# Epoch 35/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9282073067119796
# Train - Acurácia 2:  0.9960351175304446
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2828 - accuracy: 0.9026 - val_loss: 2.6997 - val_accuracy: 0.5011
# Epoch 36/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9355706598697253
# Train - Acurácia 2:  0.9981591617105636
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2615 - accuracy: 0.9094 - val_loss: 2.7517 - val_accuracy: 0.4887
# Epoch 37/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9283489096573209
# Train - Acurácia 2:  0.9980175587652224
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2420 - accuracy: 0.9153 - val_loss: 2.7562 - val_accuracy: 0.5125
# Epoch 38/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.926791277258567
# Train - Acurácia 2:  0.9939110733503257
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2240 - accuracy: 0.9216 - val_loss: 2.9007 - val_accuracy: 0.4887
# Epoch 39/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9310393656188048
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2411 - accuracy: 0.9176 - val_loss: 2.9414 - val_accuracy: 0.4898
# Epoch 40/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9284905126026621
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2383 - accuracy: 0.9152 - val_loss: 2.9407 - val_accuracy: 0.4773
# Epoch 41/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9299065420560748
# Train - Acurácia 2:  0.9943358821863495
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8684807256235828
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2078 - accuracy: 0.9240 - val_loss: 2.9109 - val_accuracy: 0.4830
# Epoch 42/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9355706598697253
# Train - Acurácia 2:  0.9957519116397621
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2212 - accuracy: 0.9159 - val_loss: 2.9370 - val_accuracy: 0.5079
# Epoch 43/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9310393656188048
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2384 - accuracy: 0.9122 - val_loss: 2.8550 - val_accuracy: 0.5068
# Epoch 44/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.9249504389691305
# Train - Acurácia 2:  0.994052676295667
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 60s 545ms/step - loss: 0.2129 - accuracy: 0.9191 - val_loss: 2.9547 - val_accuracy: 0.5113
# Epoch 45/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9359954687057491
# Train - Acurácia 2:  0.9930614556782781
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5204081632653061
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2195 - accuracy: 0.9186 - val_loss: 3.0067 - val_accuracy: 0.5204
# Epoch 46/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9300481450014161
# Train - Acurácia 2:  0.9939110733503257
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2212 - accuracy: 0.9206 - val_loss: 2.9066 - val_accuracy: 0.5113
# Epoch 47/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9313225715094874
# Train - Acurácia 2:  0.9960351175304446
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8718820861678005
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2285 - accuracy: 0.9138 - val_loss: 3.0784 - val_accuracy: 0.5136
# Epoch 48/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9100821297082979
# Train - Acurácia 2:  0.98654772019258
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2198 - accuracy: 0.9197 - val_loss: 2.9198 - val_accuracy: 0.4955
# Epoch 49/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9374114981591617
# Train - Acurácia 2:  0.9981591617105636
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 60s 544ms/step - loss: 0.1954 - accuracy: 0.9279 - val_loss: 3.1236 - val_accuracy: 0.4955
# Epoch 50/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9258000566411781
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 60s 544ms/step - loss: 0.1990 - accuracy: 0.9262 - val_loss: 3.1070 - val_accuracy: 0.4841
# CPU times: user 53min 29s, sys: 1min 24s, total: 54min 53s
# Wall time: 51min 24s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'3')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k3'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k3',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_'+'k3',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k3')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k3')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-b4e42dfbaaa4> in <module>
# ----> 1 model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k3')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204         if isinstance(filepath_str, str):
#     205           if not tf.io.gfile.exists(filepath_str):
# --> 206             raise IOError(f'No file or directory found at {filepath_str}')
#     207
#     208           if tf.io.gfile.isdir(filepath_str):
#
# OSError: No file or directory found at /content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_k3

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 73ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_6 k=3', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_train_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_6_k=3'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_6_k=3      0.9258    0.992495     0.993345

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 72ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_6 k=3', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_validation_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_6_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=3    0.925800    0.992495     0.993345
# 1  validation_mexh_6_k=3    0.484127    0.845805     0.873016

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 81ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_6 k=3', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_test_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_6_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=3    0.925800    0.992495     0.993345
# 1  validation_mexh_6_k=3    0.484127    0.845805     0.873016
# 2        test_mexh_6_k=3    0.513605    0.857143     0.882086

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_6_kfold/Resultados_mexh_6_k3.xlsx", index=False)

# %% [markdown]
# # k=4

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/treino4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/teste4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/validation4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino4")
VAL_DATASET = os.path.join("/content", "validation4")
TEST_DATASET = os.path.join("/content", "teste4")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 42s - loss: 5.2232 - accuracy: 0.0104
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0834s vs `on_train_batch_end` time: 0.2675s). Check your callbacks.
# 111/111 [==============================] - 9s 75ms/step
# Train - Acurácia 0:  0.20475785896346643
# Train - Acurácia 2:  0.4566694987255735
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.22675736961451248
# validation - Acurácia 2:  0.4671201814058957
# 111/111 [==============================] - 74s 570ms/step - loss: 3.9189 - accuracy: 0.2007 - val_loss: 4.4330 - val_accuracy: 0.2268
# Epoch 2/50
# 111/111 [==============================] - 8s 77ms/step
# Train - Acurácia 0:  0.29949022939677145
# Train - Acurácia 2:  0.6450014160294534
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.30612244897959184
# validation - Acurácia 2:  0.6530612244897959
# 111/111 [==============================] - 59s 532ms/step - loss: 2.8185 - accuracy: 0.3440 - val_loss: 2.8997 - val_accuracy: 0.3061
# Epoch 3/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.2832058906825262
# Train - Acurácia 2:  0.6408949306145568
# 14/14 [==============================] - 1s 82ms/step
# Validation - Acurácia 0:  0.30839002267573695
# validation - Acurácia 2:  0.6530612244897959
# 111/111 [==============================] - 61s 555ms/step - loss: 2.4628 - accuracy: 0.3898 - val_loss: 2.9578 - val_accuracy: 0.3084
# Epoch 4/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4148966298499009
# Train - Acurácia 2:  0.7757009345794392
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4308390022675737
# validation - Acurácia 2:  0.7857142857142857
# 111/111 [==============================] - 60s 544ms/step - loss: 2.2514 - accuracy: 0.4259 - val_loss: 2.3562 - val_accuracy: 0.4308
# Epoch 5/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4643160577740017
# Train - Acurácia 2:  0.8576890399320306
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.45351473922902497
# validation - Acurácia 2:  0.8458049886621315
# 111/111 [==============================] - 61s 546ms/step - loss: 2.0757 - accuracy: 0.4514 - val_loss: 2.0349 - val_accuracy: 0.4535
# Epoch 6/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5
# Train - Acurácia 2:  0.8574058340413481
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.854875283446712
# 111/111 [==============================] - 60s 545ms/step - loss: 1.9322 - accuracy: 0.4722 - val_loss: 2.0058 - val_accuracy: 0.4943
# Epoch 7/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4837156612857547
# Train - Acurácia 2:  0.87892948173322
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47052154195011336
# validation - Acurácia 2:  0.8480725623582767
# 111/111 [==============================] - 60s 545ms/step - loss: 1.8289 - accuracy: 0.4905 - val_loss: 2.0715 - val_accuracy: 0.4705
# Epoch 8/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.49787595581988103
# Train - Acurácia 2:  0.8620787312376097
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4875283446712018
# validation - Acurácia 2:  0.8480725623582767
# 111/111 [==============================] - 60s 545ms/step - loss: 1.7587 - accuracy: 0.5075 - val_loss: 2.0420 - val_accuracy: 0.4875
# Epoch 9/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5460209572359105
# Train - Acurácia 2:  0.9092325120362503
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 544ms/step - loss: 1.6684 - accuracy: 0.5224 - val_loss: 1.9053 - val_accuracy: 0.4989
# Epoch 10/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5630133106768621
# Train - Acurácia 2:  0.9170206740300199
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 60s 544ms/step - loss: 1.5695 - accuracy: 0.5367 - val_loss: 1.8338 - val_accuracy: 0.5113
# Epoch 11/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5514018691588785
# Train - Acurácia 2:  0.9137638062871708
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8684807256235828
# 111/111 [==============================] - 60s 546ms/step - loss: 1.4988 - accuracy: 0.5566 - val_loss: 1.9153 - val_accuracy: 0.5000
# Epoch 12/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6163976210705183
# Train - Acurácia 2:  0.9447748513169074
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5340136054421769
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 545ms/step - loss: 1.4038 - accuracy: 0.5763 - val_loss: 1.7780 - val_accuracy: 0.5340
# Epoch 13/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5911922967997735
# Train - Acurácia 2:  0.9401019541206457
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 60s 545ms/step - loss: 1.3442 - accuracy: 0.5935 - val_loss: 1.9454 - val_accuracy: 0.5045
# Epoch 14/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6391956952704616
# Train - Acurácia 2:  0.9501557632398754
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5158730158730159
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 60s 544ms/step - loss: 1.2586 - accuracy: 0.6129 - val_loss: 1.8483 - val_accuracy: 0.5159
# Epoch 15/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6406117247238743
# Train - Acurácia 2:  0.9364202775417728
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 546ms/step - loss: 1.1723 - accuracy: 0.6328 - val_loss: 1.9419 - val_accuracy: 0.5000
# Epoch 16/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6850750495610308
# Train - Acurácia 2:  0.9585103370150099
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5487528344671202
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 545ms/step - loss: 1.1169 - accuracy: 0.6476 - val_loss: 1.8531 - val_accuracy: 0.5488
# Epoch 17/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6934296233361654
# Train - Acurácia 2:  0.9597847635230813
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 60s 544ms/step - loss: 1.0283 - accuracy: 0.6773 - val_loss: 1.9350 - val_accuracy: 0.5125
# Epoch 18/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7199093741149816
# Train - Acurácia 2:  0.9685641461342396
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 60s 545ms/step - loss: 0.9292 - accuracy: 0.6999 - val_loss: 1.9839 - val_accuracy: 0.4909
# Epoch 19/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7604078164825828
# Train - Acurácia 2:  0.9696969696969697
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5215419501133787
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 545ms/step - loss: 0.8696 - accuracy: 0.7208 - val_loss: 2.0787 - val_accuracy: 0.5215
# Epoch 20/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7717360521098839
# Train - Acurácia 2:  0.9672897196261683
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 60s 544ms/step - loss: 0.7922 - accuracy: 0.7411 - val_loss: 2.1077 - val_accuracy: 0.5034
# Epoch 21/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7911356556216369
# Train - Acurácia 2:  0.9688473520249221
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5102040816326531
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 544ms/step - loss: 0.7324 - accuracy: 0.7635 - val_loss: 2.0892 - val_accuracy: 0.5102
# Epoch 22/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8227131124327386
# Train - Acurácia 2:  0.9800339847068819
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5306122448979592
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 60s 544ms/step - loss: 0.6627 - accuracy: 0.7835 - val_loss: 2.1613 - val_accuracy: 0.5306
# Epoch 23/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8483432455395072
# Train - Acurácia 2:  0.9780515434721042
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5204081632653061
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 544ms/step - loss: 0.6065 - accuracy: 0.8054 - val_loss: 2.2440 - val_accuracy: 0.5204
# Epoch 24/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8520249221183801
# Train - Acurácia 2:  0.9855564995751912
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 60s 543ms/step - loss: 0.5238 - accuracy: 0.8328 - val_loss: 2.2493 - val_accuracy: 0.4909
# Epoch 25/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8762390257717361
# Train - Acurácia 2:  0.9855564995751912
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 543ms/step - loss: 0.4847 - accuracy: 0.8457 - val_loss: 2.3756 - val_accuracy: 0.5023
# Epoch 26/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8823279524214104
# Train - Acurácia 2:  0.987114131973945
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 60s 543ms/step - loss: 0.4607 - accuracy: 0.8510 - val_loss: 2.4080 - val_accuracy: 0.4989
# Epoch 27/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8967714528462192
# Train - Acurácia 2:  0.9893797790994052
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 60s 544ms/step - loss: 0.4525 - accuracy: 0.8527 - val_loss: 2.3989 - val_accuracy: 0.5045
# Epoch 28/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.892948173322005
# Train - Acurácia 2:  0.9855564995751912
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3936 - accuracy: 0.8711 - val_loss: 2.5524 - val_accuracy: 0.5091
# Epoch 29/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9209855564995751
# Train - Acurácia 2:  0.9939110733503257
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3697 - accuracy: 0.8811 - val_loss: 2.4488 - val_accuracy: 0.5147
# Epoch 30/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9146134239592183
# Train - Acurácia 2:  0.9929198527329368
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 60s 543ms/step - loss: 0.3408 - accuracy: 0.8846 - val_loss: 2.5889 - val_accuracy: 0.4977
# Epoch 31/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9141886151231946
# Train - Acurácia 2:  0.988671764372699
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3224 - accuracy: 0.8938 - val_loss: 2.5770 - val_accuracy: 0.5125
# Epoch 32/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9195695270461626
# Train - Acurácia 2:  0.9934862645143019
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2961 - accuracy: 0.8986 - val_loss: 2.6271 - val_accuracy: 0.5147
# Epoch 33/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9241008212970829
# Train - Acurácia 2:  0.9929198527329368
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5294784580498866
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2665 - accuracy: 0.9140 - val_loss: 2.5690 - val_accuracy: 0.5295
# Epoch 34/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9304729538374398
# Train - Acurácia 2:  0.9975927499291986
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5430839002267573
# validation - Acurácia 2:  0.9070294784580499
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2543 - accuracy: 0.9139 - val_loss: 2.5641 - val_accuracy: 0.5431
# Epoch 35/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9180118946474086
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5476190476190477
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2415 - accuracy: 0.9153 - val_loss: 2.6550 - val_accuracy: 0.5476
# Epoch 36/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.916029453412631
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.8605442176870748
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2483 - accuracy: 0.9129 - val_loss: 2.7652 - val_accuracy: 0.5034
# Epoch 37/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9105069385443217
# Train - Acurácia 2:  0.9927782497875955
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5317460317460317
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2808 - accuracy: 0.9037 - val_loss: 2.7466 - val_accuracy: 0.5317
# Epoch 38/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.935429056924384
# Train - Acurácia 2:  0.9981591617105636
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5249433106575964
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2564 - accuracy: 0.9122 - val_loss: 2.6046 - val_accuracy: 0.5249
# Epoch 39/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.934862645143019
# Train - Acurácia 2:  0.9974511469838573
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5430839002267573
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2343 - accuracy: 0.9157 - val_loss: 2.6573 - val_accuracy: 0.5431
# Epoch 40/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9324553950722175
# Train - Acurácia 2:  0.9971679410931747
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2242 - accuracy: 0.9196 - val_loss: 2.7621 - val_accuracy: 0.5193
# Epoch 41/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9331634097989239
# Train - Acurácia 2:  0.9977343528745398
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5408163265306123
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2288 - accuracy: 0.9169 - val_loss: 2.8244 - val_accuracy: 0.5408
# Epoch 42/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9205607476635514
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5317460317460317
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2565 - accuracy: 0.9087 - val_loss: 2.7613 - val_accuracy: 0.5317
# Epoch 43/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.926224865477202
# Train - Acurácia 2:  0.9954687057490795
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5351473922902494
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2433 - accuracy: 0.9074 - val_loss: 2.7961 - val_accuracy: 0.5351
# Epoch 44/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9232512036250354
# Train - Acurácia 2:  0.9937694704049844
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2201 - accuracy: 0.9177 - val_loss: 2.9570 - val_accuracy: 0.5091
# Epoch 45/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9371282922684792
# Train - Acurácia 2:  0.9967431322571509
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5374149659863946
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2027 - accuracy: 0.9276 - val_loss: 2.7862 - val_accuracy: 0.5374
# Epoch 46/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8946474086661003
# Train - Acurácia 2:  0.9787595581988106
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5226757369614512
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2023 - accuracy: 0.9216 - val_loss: 3.0860 - val_accuracy: 0.5227
# Epoch 47/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9368450863777966
# Train - Acurácia 2:  0.9977343528745398
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5226757369614512
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2111 - accuracy: 0.9233 - val_loss: 2.8108 - val_accuracy: 0.5227
# Epoch 48/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9352874539790428
# Train - Acurácia 2:  0.9960351175304446
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2033 - accuracy: 0.9233 - val_loss: 2.8153 - val_accuracy: 0.5125
# Epoch 49/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8976210705182668
# Train - Acurácia 2:  0.9798923817615406
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2158 - accuracy: 0.9169 - val_loss: 3.1819 - val_accuracy: 0.5068
# Epoch 50/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9350042480883602
# Train - Acurácia 2:  0.9968847352024922
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2021 - accuracy: 0.9176 - val_loss: 3.0074 - val_accuracy: 0.5125
# CPU times: user 53min 15s, sys: 1min 27s, total: 54min 42s
# Wall time: 50min 25s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'4')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k4'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k4',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_'+'k4',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k4')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k4')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 9s 78ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_6 k=4', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_train_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_6_k=4'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_6_k=4    0.935004    0.996177     0.996885

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 77ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_6 k=4', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_validation_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_6_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=4    0.935004    0.996177     0.996885
# 1  validation_mexh_6_k=4    0.512472    0.857143     0.879819

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 78ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_6 k=4', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_test_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_6_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=4    0.935004    0.996177     0.996885
# 1  validation_mexh_6_k=4    0.512472    0.857143     0.879819
# 2        test_mexh_6_k=4    0.522676    0.844671     0.886621

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_6_kfold/Resultados_mexh_6_k4.xlsx", index=False)

# %% [markdown]
# # k=5

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/treino5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/teste5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_6_review_split/validation5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino5")
VAL_DATASET = os.path.join("/content", "validation5")
TEST_DATASET = os.path.join("/content", "teste5")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 45s - loss: 5.1429 - accuracy: 0.0052
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0873s vs `on_train_batch_end` time: 0.2872s). Check your callbacks.
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.13820447465307278
# Train - Acurácia 2:  0.3888416879071085
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.1473922902494331
# validation - Acurácia 2:  0.37528344671201813
# 111/111 [==============================] - 78s 604ms/step - loss: 4.0750 - accuracy: 0.1788 - val_loss: 7.4681 - val_accuracy: 0.1474
# Epoch 2/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.2881619937694704
# Train - Acurácia 2:  0.6489662984990088
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.2698412698412698
# validation - Acurácia 2:  0.6190476190476191
# 111/111 [==============================] - 60s 546ms/step - loss: 2.9064 - accuracy: 0.3268 - val_loss: 3.3535 - val_accuracy: 0.2698
# Epoch 3/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.3828943642027754
# Train - Acurácia 2:  0.7503540073633531
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.35374149659863946
# validation - Acurácia 2:  0.7267573696145124
# 111/111 [==============================] - 61s 547ms/step - loss: 2.5089 - accuracy: 0.3905 - val_loss: 2.6822 - val_accuracy: 0.3537
# Epoch 4/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4117813650523931
# Train - Acurácia 2:  0.7813650523930897
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.38095238095238093
# validation - Acurácia 2:  0.7619047619047619
# 111/111 [==============================] - 60s 545ms/step - loss: 2.2615 - accuracy: 0.4169 - val_loss: 2.5301 - val_accuracy: 0.3810
# Epoch 5/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.43415463041631264
# Train - Acurácia 2:  0.8314924950438969
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.40476190476190477
# validation - Acurácia 2:  0.8231292517006803
# 111/111 [==============================] - 60s 544ms/step - loss: 2.0694 - accuracy: 0.4527 - val_loss: 2.3074 - val_accuracy: 0.4048
# Epoch 6/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.4746530727839139
# Train - Acurácia 2:  0.8513169073916738
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.42630385487528344
# validation - Acurácia 2:  0.8310657596371882
# 111/111 [==============================] - 60s 544ms/step - loss: 1.9641 - accuracy: 0.4642 - val_loss: 2.1850 - val_accuracy: 0.4263
# Epoch 7/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.505947323704333
# Train - Acurácia 2:  0.8979042764089493
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4410430839002268
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 60s 543ms/step - loss: 1.8808 - accuracy: 0.4772 - val_loss: 2.0951 - val_accuracy: 0.4410
# Epoch 8/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.44774851316907394
# Train - Acurácia 2:  0.8286604361370716
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.40589569160997735
# validation - Acurácia 2:  0.8231292517006803
# 111/111 [==============================] - 60s 544ms/step - loss: 1.7858 - accuracy: 0.5024 - val_loss: 2.3806 - val_accuracy: 0.4059
# Epoch 9/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5135938827527613
# Train - Acurácia 2:  0.8770886434437837
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8458049886621315
# 111/111 [==============================] - 60s 543ms/step - loss: 1.7021 - accuracy: 0.5195 - val_loss: 2.0548 - val_accuracy: 0.4603
# Epoch 10/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5032568677428491
# Train - Acurácia 2:  0.878363069951855
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.4501133786848073
# validation - Acurácia 2:  0.8458049886621315
# 111/111 [==============================] - 60s 544ms/step - loss: 1.6276 - accuracy: 0.5234 - val_loss: 2.1385 - val_accuracy: 0.4501
# Epoch 11/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5719342962333617
# Train - Acurácia 2:  0.9270744831492495
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47392290249433106
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 545ms/step - loss: 1.5318 - accuracy: 0.5470 - val_loss: 1.9373 - val_accuracy: 0.4739
# Epoch 12/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5822713112432739
# Train - Acurácia 2:  0.9259416595865194
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 544ms/step - loss: 1.4767 - accuracy: 0.5590 - val_loss: 1.9251 - val_accuracy: 0.4773
# Epoch 13/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5802888700084962
# Train - Acurácia 2:  0.907958085528179
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.45918367346938777
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 544ms/step - loss: 1.4256 - accuracy: 0.5670 - val_loss: 2.0416 - val_accuracy: 0.4592
# Epoch 14/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6282922684791844
# Train - Acurácia 2:  0.9491645426224865
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.9081632653061225
# 111/111 [==============================] - 60s 544ms/step - loss: 1.3417 - accuracy: 0.5882 - val_loss: 1.9111 - val_accuracy: 0.5000
# Epoch 15/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6154064004531294
# Train - Acurácia 2:  0.9208439535542339
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47052154195011336
# validation - Acurácia 2:  0.8673469387755102
# 111/111 [==============================] - 60s 545ms/step - loss: 1.2793 - accuracy: 0.6068 - val_loss: 2.0389 - val_accuracy: 0.4705
# Epoch 16/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.638346077598414
# Train - Acurácia 2:  0.9412347776833758
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 544ms/step - loss: 1.2101 - accuracy: 0.6231 - val_loss: 2.0167 - val_accuracy: 0.4796
# Epoch 17/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.5954403851600113
# Train - Acurácia 2:  0.908524497309544
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.42517006802721086
# validation - Acurácia 2:  0.8514739229024944
# 111/111 [==============================] - 60s 543ms/step - loss: 1.1473 - accuracy: 0.6389 - val_loss: 2.2514 - val_accuracy: 0.4252
# Epoch 18/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.6492495043896913
# Train - Acurácia 2:  0.9249504389691305
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.8469387755102041
# 111/111 [==============================] - 60s 544ms/step - loss: 1.0851 - accuracy: 0.6583 - val_loss: 2.2767 - val_accuracy: 0.4580
# Epoch 19/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7129708297932597
# Train - Acurácia 2:  0.9616256018125177
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.463718820861678
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 60s 545ms/step - loss: 1.0147 - accuracy: 0.6801 - val_loss: 2.0581 - val_accuracy: 0.4637
# Epoch 20/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.72982158028887
# Train - Acurácia 2:  0.9644576607193429
# 14/14 [==============================] - 1s 79ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 60s 543ms/step - loss: 0.9104 - accuracy: 0.7084 - val_loss: 2.0991 - val_accuracy: 0.4762
# Epoch 21/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7618238459359955
# Train - Acurácia 2:  0.968280940243557
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 543ms/step - loss: 0.8719 - accuracy: 0.7171 - val_loss: 2.0809 - val_accuracy: 0.4660
# Epoch 22/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7966581704899461
# Train - Acurácia 2:  0.9774851316907391
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 60s 543ms/step - loss: 0.8121 - accuracy: 0.7402 - val_loss: 2.1377 - val_accuracy: 0.4841
# Epoch 23/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.7912772585669782
# Train - Acurácia 2:  0.9729538374398188
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4478458049886621
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 60s 545ms/step - loss: 0.7535 - accuracy: 0.7600 - val_loss: 2.3080 - val_accuracy: 0.4478
# Epoch 24/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.787453979042764
# Train - Acurácia 2:  0.9733786462758426
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 543ms/step - loss: 0.6755 - accuracy: 0.7791 - val_loss: 2.3372 - val_accuracy: 0.4773
# Epoch 25/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.840696686491079
# Train - Acurácia 2:  0.9756442934013028
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47392290249433106
# validation - Acurácia 2:  0.9058956916099773
# 111/111 [==============================] - 60s 543ms/step - loss: 0.6143 - accuracy: 0.8020 - val_loss: 2.2904 - val_accuracy: 0.4739
# Epoch 26/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8491928632115548
# Train - Acurácia 2:  0.9790427640894931
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 60s 543ms/step - loss: 0.5846 - accuracy: 0.8064 - val_loss: 2.4522 - val_accuracy: 0.4887
# Epoch 27/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8497592749929198
# Train - Acurácia 2:  0.9830076465590484
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 60s 544ms/step - loss: 0.5266 - accuracy: 0.8311 - val_loss: 2.5059 - val_accuracy: 0.4762
# Epoch 28/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8683092608326253
# Train - Acurácia 2:  0.9817332200509771
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 60s 543ms/step - loss: 0.5102 - accuracy: 0.8342 - val_loss: 2.5040 - val_accuracy: 0.4853
# Epoch 29/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8667516284338714
# Train - Acurácia 2:  0.9773435287453979
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 60s 543ms/step - loss: 0.4496 - accuracy: 0.8539 - val_loss: 2.6394 - val_accuracy: 0.4717
# Epoch 30/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8817615406400453
# Train - Acurácia 2:  0.9878221467006514
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4603174603174603
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 60s 543ms/step - loss: 0.4226 - accuracy: 0.8622 - val_loss: 2.6303 - val_accuracy: 0.4603
# Epoch 31/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9003115264797508
# Train - Acurácia 2:  0.9922118380062306
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.9172335600907029
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3991 - accuracy: 0.8721 - val_loss: 2.6163 - val_accuracy: 0.4762
# Epoch 32/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.8969130557915604
# Train - Acurácia 2:  0.9885301614273577
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 60s 543ms/step - loss: 0.3727 - accuracy: 0.8744 - val_loss: 2.7051 - val_accuracy: 0.4853
# Epoch 33/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9003115264797508
# Train - Acurácia 2:  0.9888133673180403
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.481859410430839
# validation - Acurácia 2:  0.9024943310657596
# 111/111 [==============================] - 60s 543ms/step - loss: 0.3712 - accuracy: 0.8740 - val_loss: 2.7248 - val_accuracy: 0.4819
# Epoch 34/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9093741149815916
# Train - Acurácia 2:  0.9902293967714528
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.9058956916099773
# 111/111 [==============================] - 60s 543ms/step - loss: 0.3264 - accuracy: 0.8924 - val_loss: 2.8471 - val_accuracy: 0.4955
# Epoch 35/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9222599830076466
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.909297052154195
# 111/111 [==============================] - 60s 544ms/step - loss: 0.3032 - accuracy: 0.8985 - val_loss: 2.7055 - val_accuracy: 0.4921
# Epoch 36/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9007363353157746
# Train - Acurácia 2:  0.9882469555366752
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2771 - accuracy: 0.9060 - val_loss: 2.9036 - val_accuracy: 0.4864
# Epoch 37/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9177286887567261
# Train - Acurácia 2:  0.9923534409515717
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4671201814058957
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2728 - accuracy: 0.9106 - val_loss: 2.8426 - val_accuracy: 0.4671
# Epoch 38/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9245256301331067
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.9081632653061225
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2596 - accuracy: 0.9139 - val_loss: 2.8338 - val_accuracy: 0.4977
# Epoch 39/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9229679977343529
# Train - Acurácia 2:  0.9926366468422543
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2715 - accuracy: 0.9067 - val_loss: 2.9275 - val_accuracy: 0.4728
# Epoch 40/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9243840271877655
# Train - Acurácia 2:  0.9936278674596432
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2440 - accuracy: 0.9157 - val_loss: 3.0360 - val_accuracy: 0.4921
# Epoch 41/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9296233361653923
# Train - Acurácia 2:  0.9956103086944208
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.9070294784580499
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2488 - accuracy: 0.9145 - val_loss: 2.9397 - val_accuracy: 0.4830
# Epoch 42/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9199943358821864
# Train - Acurácia 2:  0.9930614556782781
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.9024943310657596
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2665 - accuracy: 0.9077 - val_loss: 2.9302 - val_accuracy: 0.4796
# Epoch 43/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9238176154064005
# Train - Acurácia 2:  0.991928632115548
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2629 - accuracy: 0.9037 - val_loss: 3.0108 - val_accuracy: 0.5000
# Epoch 44/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9130557915604645
# Train - Acurácia 2:  0.9910790144435004
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.46938775510204084
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2963 - accuracy: 0.8969 - val_loss: 3.1664 - val_accuracy: 0.4694
# Epoch 45/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9205607476635514
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2532 - accuracy: 0.9088 - val_loss: 3.1263 - val_accuracy: 0.4796
# Epoch 46/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9328802039082413
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 60s 542ms/step - loss: 0.2342 - accuracy: 0.9165 - val_loss: 3.0295 - val_accuracy: 0.4932
# Epoch 47/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9299065420560748
# Train - Acurácia 2:  0.9944774851316908
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 544ms/step - loss: 0.2116 - accuracy: 0.9193 - val_loss: 3.0568 - val_accuracy: 0.4898
# Epoch 48/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9277824978759558
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2122 - accuracy: 0.9211 - val_loss: 3.2885 - val_accuracy: 0.4864
# Epoch 49/50
# 111/111 [==============================] - 9s 78ms/step
# Train - Acurácia 0:  0.9296233361653923
# Train - Acurácia 2:  0.9927782497875955
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2235 - accuracy: 0.9172 - val_loss: 3.1834 - val_accuracy: 0.4898
# Epoch 50/50
# 111/111 [==============================] - 9s 79ms/step
# Train - Acurácia 0:  0.9284905126026621
# Train - Acurácia 2:  0.9907958085528179
# 14/14 [==============================] - 1s 78ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 60s 543ms/step - loss: 0.2008 - accuracy: 0.9231 - val_loss: 3.2132 - val_accuracy: 0.4751
# CPU times: user 53min 14s, sys: 1min 28s, total: 54min 43s
# Wall time: 50min 28s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'5')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k5'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_'+'k5',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_'+'k5',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k5')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k5')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 9s 78ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_6 k=5', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_train_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_6_k=5'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#         Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_6_k=5    0.928491    0.989663     0.990796

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 78ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_6 k=5', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_validation_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_6_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=5    0.928491    0.989663     0.990796
# 1  validation_mexh_6_k=5    0.475057    0.848073     0.887755

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 78ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_6 k=5', '/content/drive/MyDrive/Resultados/mexh_6_kfold/prev_test_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_6_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#              Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_6_k=5    0.928491    0.989663     0.990796
# 1  validation_mexh_6_k=5    0.475057    0.848073     0.887755
# 2        test_mexh_6_k=5    0.490930    0.817460     0.844671

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_6_kfold/Resultados_mexh_6_k5.xlsx", index=False)
