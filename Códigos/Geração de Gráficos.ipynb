# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from google.colab import drive
drive.mount('/content/drive')
# import bottleneck as bn
# Out:
# Mounted at /content/drive

# %%
# !pip install bottleneck
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 355 kB 11.4 MB/s
# ...

# %% [markdown]
# ### mexh_4

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/val_acc2_k5.npy')

# %%
wavelet = 'mexh_4'
resultados = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Mexh_4 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/mexh_4_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### mexh_6

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_k5.npy')

# %%
wavelet = 'mexh_6'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Mexh_6 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/mexh_6_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### mexh_40

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_k5.npy')

# %%
wavelet = 'mexh_40'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Mexh_40 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/mexh_40_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### morl_4

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/val_acc2_k5.npy')

# %%
wavelet = 'morl_4'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Morl_4 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/morl_4_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### morl_6

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_k5.npy')

# %%
wavelet = 'morl_6'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Morl_6 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/morl_6_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### morl_40

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/val_acc2_k5.npy')

# %%
wavelet = 'morl_40'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Morl_40 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/morl_40_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### shan_4

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/val_acc2_k5.npy')

# %%
wavelet = 'shan_4'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Shan_4 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/shan_4_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### shan_6

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_k5.npy')

# %%
wavelet = 'shan_6'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Shan_6 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/shan_6_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### shan_40

# %%
train_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/acc2_k1.npy')
validation_acc2_k1 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/val_acc2_k1.npy')

train_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/acc2_k2.npy')
validation_acc2_k2 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/val_acc2_k2.npy')

train_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/acc2_k3.npy')
validation_acc2_k3 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/val_acc2_k3.npy')

train_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/acc2_k4.npy')
validation_acc2_k4 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/val_acc2_k4.npy')

train_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/acc2_k5.npy')
validation_acc2_k5 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/val_acc2_k5.npy')

# %%
wavelet = 'shan_40'
newline = pd.DataFrame([[wavelet, np.amax(validation_acc2_k1), np.amax(validation_acc2_k2), np.amax(validation_acc2_k3), np.amax(validation_acc2_k4), np.amax(validation_acc2_k5)]], columns=['Experimento/valor val max','k1', 'k2', 'k3', 'k4', 'k5'])

resultados = resultados.append(newline, ignore_index=True)

resultados.to_excel("/content/drive/MyDrive/Resultados/Gráficos_Gerais/maior_valor_acc2_validation.xlsx", index=False)

# %%
epochs   = range(len(train_acc2_k1)) # Get number of epochs

plt.figure(figsize=(15,10))
plt.plot(epochs, train_acc2_k1, label='Treinamento - Acurácia 2 - k1', color='royalblue')
plt.plot(epochs, validation_acc2_k1, label='Validação - Acurácia 2 - k1', color='royalblue', linestyle='--')
plt.plot(epochs, train_acc2_k2, label='Treinamento - Acurácia 2 - k2', color='crimson')
plt.plot(epochs, validation_acc2_k2, label='Validação - Acurácia 2 - k2', color='crimson', linestyle='--')
plt.plot(epochs, train_acc2_k3, label='Treinamento - Acurácia 2 - k3', color='palegreen')
plt.plot(epochs, validation_acc2_k3, label='Validação - Acurácia 2 - k3', color='palegreen', linestyle='--')
plt.plot(epochs, train_acc2_k4, label='Treinamento - Acurácia 2 - k4', color='sandybrown')
plt.plot(epochs, validation_acc2_k4, label='Validação - Acurácia 2 - k4', color='sandybrown', linestyle='--')
plt.plot(epochs, train_acc2_k5, label='Treinamento - Acurácia 2 - k5', color='darkcyan')
plt.plot(epochs, validation_acc2_k5, label='Validação - Acurácia 2 - k5', color='darkcyan', linestyle='--')
plt.title ('Shan_40 - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/shan_40_kfold.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### Comparativo

# %%
mexh_4_train_acc2 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/acc2_k1.npy')
mexh_4_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/mexh_4_kfold/val_acc2_k1.npy')

mexh_6_train_acc2 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/acc2_k5.npy')
mexh_6_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/mexh_6_kfold/val_acc2_k5.npy')

mexh_40_train_acc2 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_k4.npy')
mexh_40_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_k4.npy')

morl_4_train_acc2 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/acc2_k4.npy')
morl_4_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/morl_4_kfold/val_acc2_k4.npy')

morl_6_train_acc2 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/acc2_k5.npy')
morl_6_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/morl_6_kfold/val_acc2_k5.npy')

morl_40_train_acc2 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/acc2_k4.npy')
morl_40_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/morl_40_kfold/val_acc2_k4.npy')

shan_4_train_acc2 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/acc2_k1.npy')
shan_4_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/shan_4_kfold/val_acc2_k1.npy')

shan_6_train_acc2 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/acc2_k1.npy')
shan_6_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/shan_6_kfold/val_acc2_k1.npy')

shan_40_train_acc2 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/acc2_k1.npy')
shan_40_validation_acc2 = np.load('/content/drive/MyDrive/Resultados/shan_40_kfold/val_acc2_k1.npy')

# %%
epochs   = range(len(mexh_4_train_acc2)) # Get number of epochs

plt.figure(figsize=(15,12))
plt.plot(epochs, mexh_4_train_acc2, label='Mexh 4 - Treinamento - Acurácia 2', color='red')
plt.plot(epochs, mexh_4_validation_acc2, label='Mexh 4 - Validação - Acurácia 2', color='red', linestyle='--')
plt.plot(epochs, mexh_6_train_acc2, label='Mexh 6 - Treinamento - Acurácia 2', color='rosybrown')
plt.plot(epochs, mexh_6_validation_acc2, label='Mexh 6 - Validação - Acurácia 2', color='rosybrown', linestyle='--')
plt.plot(epochs, mexh_40_train_acc2, label='Mexh 40 - Treinamento - Acurácia 2', color='firebrick')
plt.plot(epochs, mexh_40_validation_acc2, label='Mexh 40 - Validação - Acurácia 2', color='firebrick', linestyle='--')

plt.plot(epochs, morl_4_train_acc2, label='Morl 4 - Treinamento - Acurácia 2', color='darkgreen')
plt.plot(epochs, morl_4_validation_acc2, label='Morl 4 - Validação - Acurácia 2', color='darkgreen', linestyle='--')
plt.plot(epochs, morl_6_train_acc2, label='Morl 6 - Treinamento - Acurácia 2', color='palegreen')
plt.plot(epochs, morl_6_validation_acc2, label='Morl 6 - Validação - Acurácia 2', color='palegreen', linestyle='--')
plt.plot(epochs, morl_40_train_acc2, label='Morl 40 - Treinamento - Acurácia 2', color='lime')
plt.plot(epochs, morl_40_validation_acc2, label='Morl 40 - Validação - Acurácia 2', color='lime', linestyle='--')

plt.plot(epochs, shan_4_train_acc2, label='Shan 4 - Treinamento - Acurácia 2', color='navy')
plt.plot(epochs, shan_4_validation_acc2, label='Shan 4 - Validação - Acurácia 2', color='navy', linestyle='--')
plt.plot(epochs, shan_6_train_acc2, label='Shan 6 - Treinamento - Acurácia 2', color='royalblue')
plt.plot(epochs, shan_6_validation_acc2, label='Shan 6 - Validação - Acurácia 2', color='royalblue', linestyle='--')
plt.plot(epochs, shan_40_train_acc2, label='Shan 40 - Treinamento - Acurácia 2', color='paleturquoise')
plt.plot(epochs, shan_40_validation_acc2, label='Shan 40 - Validação - Acurácia 2', color='paleturquoise', linestyle='--')

plt.title ('Comparativo entre Funções Wavelet - Acurácia 2 - Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/comparativo_wavelets.pdf', format='pdf')
plt.show()

# %%
epochs   = range(len(mexh_4_train_acc2)) # Get number of epochs

plt.figure(figsize=(17,8))

mexh_4_validation_acc2 = bn.move_mean(mexh_4_validation_acc2, window=10, min_count=1)
plt.plot(epochs, mexh_4_validation_acc2, label='Mexh 4 - Validação - Acurácia 2', color='red', linestyle='--')

mexh_6_validation_acc2 = bn.move_mean(mexh_6_validation_acc2, window=10, min_count=1)
plt.plot(epochs, mexh_6_validation_acc2, label='Mexh 6 - Validação - Acurácia 2', color='rosybrown', linestyle='--')

mexh_40_validation_acc2 = bn.move_mean(mexh_40_validation_acc2, window=10, min_count=1)
plt.plot(epochs, mexh_40_validation_acc2, label='Mexh 40 - Validação - Acurácia 2', color='firebrick', linestyle='--')


morl_4_validation_acc2 = bn.move_mean(morl_4_validation_acc2, window=10, min_count=1)
plt.plot(epochs, morl_4_validation_acc2, label='Morl 4 - Validação - Acurácia 2', color='darkgreen', linestyle='--')

morl_6_validation_acc2 = bn.move_mean(morl_6_validation_acc2, window=10, min_count=1)
plt.plot(epochs, morl_6_validation_acc2, label='Morl 6 - Validação - Acurácia 2', color='palegreen', linestyle='--')

morl_40_validation_acc2 = bn.move_mean(morl_40_validation_acc2, window=10, min_count=1)
plt.plot(epochs, morl_40_validation_acc2, label='Morl 40 - Validação - Acurácia 2', color='lime', linestyle='--')


shan_4_validation_acc2 = bn.move_mean(shan_4_validation_acc2, window=10, min_count=1)
plt.plot(epochs, shan_4_validation_acc2, label='Shan 4 - Validação - Acurácia 2', color='navy', linestyle='--')

shan_6_validation_acc2 = bn.move_mean(shan_6_validation_acc2, window=10, min_count=1)
plt.plot(epochs, shan_6_validation_acc2, label='Shan 6 - Validação - Acurácia 2', color='royalblue', linestyle='--')

shan_40_validation_acc2 = bn.move_mean(shan_40_validation_acc2, window=10, min_count=1)
plt.plot(epochs, shan_40_validation_acc2, label='Shan 40 - Validação - Acurácia 2', color='paleturquoise', linestyle='--')

plt.title ('Comparativo entre Funções Wavelet - Média Móvel Acurácia 2 - Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/comparativo_wavelets_media_movel_validação.pdf', format='pdf')
plt.show()

# %% [markdown]
# Gráfico para Artigo CBIC 2023

# %%
epochs   = range(len(mexh_4_train_acc2)) # Get number of epochs

plt.figure(figsize=(5,4))
#plt.plot(epochs, mexh_4_train_acc2, label='Mexh 4 - Treinamento - Acurácia 2', color='red')
#plt.plot(epochs, mexh_4_validation_acc2, label='Mexh 4 - Validação - Acurácia 2', color='red', linestyle='--')
#plt.plot(epochs, mexh_6_train_acc2, label='Mexh 6 - Treinamento - Acurácia 2', color='rosybrown')
#plt.plot(epochs, mexh_6_validation_acc2, label='Mexh 6 - Validação - Acurácia 2', color='rosybrown', linestyle='--')
#plt.plot(epochs, mexh_40_train_acc2, label='Mexh 40 - Treinamento - Acurácia 2', color='firebrick')
#plt.plot(epochs, mexh_40_validation_acc2, label='Mexh 40 - Validação - Acurácia 2', color='firebrick', linestyle='--')

#plt.plot(epochs, morl_4_train_acc2, label='Morl 4 - Treinamento - Acurácia 2', color='darkgreen')
#plt.plot(epochs, morl_4_validation_acc2, label='Morl 4 - Validação - Acurácia 2', color='darkgreen', linestyle='--')
plt.plot(epochs, morl_6_train_acc2, label='Morl 6 - Training - Accuracy 2', color='blue')
plt.plot(epochs, morl_6_validation_acc2, label='Morl 6 - Validation - Accuracy 2', color='blue', linestyle='--')
plt.plot(epochs, morl_40_train_acc2, label='Morl 40 - Training - Accuracy 2', color='red')
plt.plot(epochs, morl_40_validation_acc2, label='Morl 40 - Validation - Accuracy 2', color='red', linestyle='--')

#plt.plot(epochs, shan_4_train_acc2, label='Shan 4 - Treinamento - Acurácia 2', color='navy')
#plt.plot(epochs, shan_4_validation_acc2, label='Shan 4 - Validação - Acurácia 2', color='navy', linestyle='--')
#plt.plot(epochs, shan_6_train_acc2, label='Shan 6 - Treinamento - Acurácia 2', color='royalblue')
#plt.plot(epochs, shan_6_validation_acc2, label='Shan 6 - Validação - Acurácia 2', color='royalblue', linestyle='--')
#plt.plot(epochs, shan_40_train_acc2, label='Shan 40 - Treinamento - Acurácia 2', color='blue')
#plt.plot(epochs, shan_40_validation_acc2, label='Shan 40 - Validação - Acurácia 2', color='blue', linestyle='--')

plt.grid()
plt.title ('Accuracy 2 - Training and Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy 2')
plt.ylim([0.7,plt.ylim()[1]])
plt.legend()
#plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/morl40_morl6_cbic2023.pdf', format='pdf')
plt.savefig('/content/drive/MyDrive/Resultados/Gráficos_Gerais/morl40_morl6_ieee2023.pdf', format='pdf')
plt.show()
