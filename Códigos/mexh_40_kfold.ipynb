# %%
# !pip install tensorflow==2.5.0
# !pip install numpy==1.20.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
shutil.copy2("/content/drive/MyDrive/utilities.py", "/content/utilities.py")
shutil.copy2("/content/drive/MyDrive/ConvNet.py", "/content/ConvNet.py")
shutil.copy2("/content/drive/MyDrive/config.py", "/content/config.py")
# Out:
# '/content/config.py'

# %%
import ConvNet
import config
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.utils import to_categorical
from tensorflow.data import AUTOTUNE
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import argparse
import os
import numpy as np
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MultiLabelBinarizer
from IPython.display import Audio, clear_output, display
from glob import glob
import random
from utilities import acuracia0, acuracia1, acuracia2
import utilities

# %%
model = ConvNet.ConvNet

# %%
model.summary()

# %% [markdown]
# # k=1

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/treino1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/teste1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/validation1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino1")
VAL_DATASET = os.path.join("/content", "validation1")
TEST_DATASET = os.path.join("/content", "teste1")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7060, 40, 256, 1)
# (883, 40, 256, 1)
# (7060,)
# (883,)
# (883,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 43s - loss: 5.0245 - accuracy: 0.0365
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0981s vs `on_train_batch_end` time: 0.2614s). Check your callbacks.
# 111/111 [==============================] - 10s 91ms/step
# Train - Acurácia 0:  0.27492917847025494
# Train - Acurácia 2:  0.5892351274787535
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.24235560588901472
# validation - Acurácia 2:  0.565118912797282
# 111/111 [==============================] - 83s 602ms/step - loss: 3.7309 - accuracy: 0.2435 - val_loss: 3.7331 - val_accuracy: 0.2424
# Epoch 2/50
# 111/111 [==============================] - 11s 96ms/step
# Train - Acurácia 0:  0.35410764872521244
# Train - Acurácia 2:  0.7070821529745043
# 14/14 [==============================] - 1s 95ms/step
# Validation - Acurácia 0:  0.3250283125707814
# validation - Acurácia 2:  0.6885617214043035
# 111/111 [==============================] - 64s 579ms/step - loss: 2.8453 - accuracy: 0.3450 - val_loss: 2.9843 - val_accuracy: 0.3250
# Epoch 3/50
# 111/111 [==============================] - 10s 94ms/step
# Train - Acurácia 0:  0.3822946175637394
# Train - Acurácia 2:  0.7371104815864022
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.33861834654586637
# validation - Acurácia 2:  0.7157417893544734
# 111/111 [==============================] - 65s 584ms/step - loss: 2.4885 - accuracy: 0.4016 - val_loss: 3.0232 - val_accuracy: 0.3386
# Epoch 4/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.4509915014164306
# Train - Acurácia 2:  0.8107648725212464
# 14/14 [==============================] - 1s 95ms/step
# Validation - Acurácia 0:  0.40656851642129105
# validation - Acurácia 2:  0.796149490373726
# 111/111 [==============================] - 65s 584ms/step - loss: 2.2532 - accuracy: 0.4271 - val_loss: 2.3829 - val_accuracy: 0.4066
# Epoch 5/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.4577903682719547
# Train - Acurácia 2:  0.8362606232294617
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.41676104190260477
# validation - Acurácia 2:  0.8142695356738392
# 111/111 [==============================] - 65s 583ms/step - loss: 2.1019 - accuracy: 0.4456 - val_loss: 2.2966 - val_accuracy: 0.4168
# Epoch 6/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.48923512747875353
# Train - Acurácia 2:  0.8754957507082153
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4269535673839185
# validation - Acurácia 2:  0.840317100792752
# 111/111 [==============================] - 65s 583ms/step - loss: 1.9505 - accuracy: 0.4758 - val_loss: 2.1754 - val_accuracy: 0.4270
# Epoch 7/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.5337110481586402
# Train - Acurácia 2:  0.8946175637393767
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4563986409966025
# validation - Acurácia 2:  0.8573046432616082
# 111/111 [==============================] - 65s 583ms/step - loss: 1.8122 - accuracy: 0.5001 - val_loss: 2.0042 - val_accuracy: 0.4564
# Epoch 8/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.53328611898017
# Train - Acurácia 2:  0.8978753541076487
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.45186862967157415
# validation - Acurácia 2:  0.8629671574178935
# 111/111 [==============================] - 65s 583ms/step - loss: 1.7466 - accuracy: 0.5112 - val_loss: 2.0425 - val_accuracy: 0.4519
# Epoch 9/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.5638810198300284
# Train - Acurácia 2:  0.9069405099150142
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4575311438278596
# validation - Acurácia 2:  0.8640996602491506
# 111/111 [==============================] - 65s 582ms/step - loss: 1.6499 - accuracy: 0.5275 - val_loss: 1.9631 - val_accuracy: 0.4575
# Epoch 10/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.5824362606232295
# Train - Acurácia 2:  0.9246458923512748
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.46998867497168745
# validation - Acurácia 2:  0.8799546998867497
# 111/111 [==============================] - 65s 582ms/step - loss: 1.5638 - accuracy: 0.5511 - val_loss: 1.9319 - val_accuracy: 0.4700
# Epoch 11/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.5492917847025496
# Train - Acurácia 2:  0.8977337110481587
# 14/14 [==============================] - 1s 95ms/step
# Validation - Acurácia 0:  0.44620611551528877
# validation - Acurácia 2:  0.8482446206115515
# 111/111 [==============================] - 65s 583ms/step - loss: 1.4682 - accuracy: 0.5684 - val_loss: 2.0149 - val_accuracy: 0.4462
# Epoch 12/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.6097733711048159
# Train - Acurácia 2:  0.9106232294617563
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.47904869762174407
# validation - Acurácia 2:  0.8686296715741789
# 111/111 [==============================] - 65s 584ms/step - loss: 1.3911 - accuracy: 0.5822 - val_loss: 1.9813 - val_accuracy: 0.4790
# Epoch 13/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.6580736543909348
# Train - Acurácia 2:  0.9490084985835694
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.49490373725934317
# validation - Acurácia 2:  0.8935447338618346
# 111/111 [==============================] - 64s 582ms/step - loss: 1.3050 - accuracy: 0.6064 - val_loss: 1.8542 - val_accuracy: 0.4949
# Epoch 14/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.6694050991501417
# Train - Acurácia 2:  0.9490084985835694
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4801812004530011
# validation - Acurácia 2:  0.8708946772366931
# 111/111 [==============================] - 65s 583ms/step - loss: 1.1835 - accuracy: 0.6276 - val_loss: 1.9519 - val_accuracy: 0.4802
# Epoch 15/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.7179886685552408
# Train - Acurácia 2:  0.9664305949008498
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.49150622876557193
# validation - Acurácia 2:  0.89920724801812
# 111/111 [==============================] - 65s 583ms/step - loss: 1.0957 - accuracy: 0.6564 - val_loss: 1.9083 - val_accuracy: 0.4915
# Epoch 16/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.7127478753541077
# Train - Acurácia 2:  0.9456090651558073
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4813137032842582
# validation - Acurácia 2:  0.869762174405436
# 111/111 [==============================] - 64s 582ms/step - loss: 1.0030 - accuracy: 0.6850 - val_loss: 2.1341 - val_accuracy: 0.4813
# Epoch 17/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.7644475920679886
# Train - Acurácia 2:  0.9725212464589235
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4824462061155153
# validation - Acurácia 2:  0.8946772366930917
# 111/111 [==============================] - 64s 582ms/step - loss: 0.8916 - accuracy: 0.7184 - val_loss: 2.0006 - val_accuracy: 0.4824
# Epoch 18/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.7909348441926346
# Train - Acurácia 2:  0.9730878186968839
# 14/14 [==============================] - 1s 95ms/step
# Validation - Acurácia 0:  0.4869762174405436
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 64s 582ms/step - loss: 0.7948 - accuracy: 0.7492 - val_loss: 2.1580 - val_accuracy: 0.4870
# Epoch 19/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.8273371104815864
# Train - Acurácia 2:  0.9773371104815864
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5016987542468856
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 65s 583ms/step - loss: 0.7332 - accuracy: 0.7623 - val_loss: 2.1436 - val_accuracy: 0.5017
# Epoch 20/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.8556657223796034
# Train - Acurácia 2:  0.9848441926345609
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4881087202718007
# validation - Acurácia 2:  0.8878822197055493
# 111/111 [==============================] - 64s 581ms/step - loss: 0.6491 - accuracy: 0.7901 - val_loss: 2.2519 - val_accuracy: 0.4881
# Epoch 21/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.8742209631728045
# Train - Acurácia 2:  0.9859773371104816
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5084937712344281
# validation - Acurácia 2:  0.883352208380521
# 111/111 [==============================] - 64s 581ms/step - loss: 0.5866 - accuracy: 0.8166 - val_loss: 2.2530 - val_accuracy: 0.5085
# Epoch 22/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.8814447592067989
# Train - Acurácia 2:  0.9917847025495751
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4881087202718007
# validation - Acurácia 2:  0.8799546998867497
# 111/111 [==============================] - 65s 583ms/step - loss: 0.4981 - accuracy: 0.8445 - val_loss: 2.3765 - val_accuracy: 0.4881
# Epoch 23/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.8937677053824362
# Train - Acurácia 2:  0.9886685552407932
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4813137032842582
# validation - Acurácia 2:  0.8822197055492639
# 111/111 [==============================] - 64s 582ms/step - loss: 0.4464 - accuracy: 0.8603 - val_loss: 2.4103 - val_accuracy: 0.4813
# Epoch 24/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.8988668555240793
# Train - Acurácia 2:  0.9917847025495751
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5175537938844847
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 64s 581ms/step - loss: 0.4193 - accuracy: 0.8660 - val_loss: 2.3731 - val_accuracy: 0.5176
# Epoch 25/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9145892351274788
# Train - Acurácia 2:  0.9930594900849858
# 14/14 [==============================] - 1s 95ms/step
# Validation - Acurácia 0:  0.48584371460928655
# validation - Acurácia 2:  0.8754246885617214
# 111/111 [==============================] - 64s 581ms/step - loss: 0.3807 - accuracy: 0.8783 - val_loss: 2.5210 - val_accuracy: 0.4858
# Epoch 26/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9123229461756374
# Train - Acurácia 2:  0.9946175637393768
# 14/14 [==============================] - 1s 95ms/step
# Validation - Acurácia 0:  0.5141562853907135
# validation - Acurácia 2:  0.8901472253680635
# 111/111 [==============================] - 64s 581ms/step - loss: 0.3663 - accuracy: 0.8827 - val_loss: 2.4786 - val_accuracy: 0.5142
# Epoch 27/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9186968838526912
# Train - Acurácia 2:  0.9940509915014164
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.507361268403171
# validation - Acurácia 2:  0.8844847112117781
# 111/111 [==============================] - 65s 583ms/step - loss: 0.3340 - accuracy: 0.8912 - val_loss: 2.5930 - val_accuracy: 0.5074
# Epoch 28/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9252124645892351
# Train - Acurácia 2:  0.9956090651558074
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5096262740656852
# validation - Acurácia 2:  0.883352208380521
# 111/111 [==============================] - 64s 582ms/step - loss: 0.3248 - accuracy: 0.8942 - val_loss: 2.6224 - val_accuracy: 0.5096
# Epoch 29/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9260623229461756
# Train - Acurácia 2:  0.9944759206798867
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5152887882219706
# validation - Acurácia 2:  0.8822197055492639
# 111/111 [==============================] - 64s 581ms/step - loss: 0.3006 - accuracy: 0.8990 - val_loss: 2.6534 - val_accuracy: 0.5153
# Epoch 30/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9310198300283287
# Train - Acurácia 2:  0.9957507082152974
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5016987542468856
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2875 - accuracy: 0.9075 - val_loss: 2.6710 - val_accuracy: 0.5017
# Epoch 31/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9322946175637393
# Train - Acurácia 2:  0.9937677053824363
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4960362400906002
# validation - Acurácia 2:  0.8720271800679502
# 111/111 [==============================] - 64s 582ms/step - loss: 0.2700 - accuracy: 0.9113 - val_loss: 2.7873 - val_accuracy: 0.4960
# Epoch 32/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9382436260623229
# Train - Acurácia 2:  0.9973087818696884
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5028312570781427
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 64s 580ms/step - loss: 0.2558 - accuracy: 0.9095 - val_loss: 2.7180 - val_accuracy: 0.5028
# Epoch 33/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9409348441926345
# Train - Acurácia 2:  0.998300283286119
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5096262740656852
# validation - Acurácia 2:  0.8890147225368064
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2361 - accuracy: 0.9194 - val_loss: 2.7864 - val_accuracy: 0.5096
# Epoch 34/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.934985835694051
# Train - Acurácia 2:  0.9939093484419264
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5050962627406569
# validation - Acurácia 2:  0.8867497168742922
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2413 - accuracy: 0.9133 - val_loss: 2.7774 - val_accuracy: 0.5051
# Epoch 35/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9371104815864023
# Train - Acurácia 2:  0.9961756373937677
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5005662514156285
# validation - Acurácia 2:  0.8754246885617214
# 111/111 [==============================] - 66s 593ms/step - loss: 0.2433 - accuracy: 0.9142 - val_loss: 2.8596 - val_accuracy: 0.5006
# Epoch 36/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9375354107648726
# Train - Acurácia 2:  0.9963172804532577
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5096262740656852
# validation - Acurácia 2:  0.8663646659116648
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2378 - accuracy: 0.9125 - val_loss: 2.9270 - val_accuracy: 0.5096
# Epoch 37/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9379603399433428
# Train - Acurácia 2:  0.9960339943342776
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4983012457531144
# validation - Acurácia 2:  0.8742921857304643
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2297 - accuracy: 0.9167 - val_loss: 2.9550 - val_accuracy: 0.4983
# Epoch 38/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9342776203966006
# Train - Acurácia 2:  0.9963172804532577
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4971687429218573
# validation - Acurácia 2:  0.8731596828992072
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2407 - accuracy: 0.9142 - val_loss: 2.9506 - val_accuracy: 0.4972
# Epoch 39/50
# 111/111 [==============================] - 10s 94ms/step
# Train - Acurácia 0:  0.9364022662889518
# Train - Acurácia 2:  0.9950424929178471
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4983012457531144
# validation - Acurácia 2:  0.8754246885617214
# 111/111 [==============================] - 64s 582ms/step - loss: 0.2268 - accuracy: 0.9153 - val_loss: 3.0296 - val_accuracy: 0.4983
# Epoch 40/50
# 111/111 [==============================] - 10s 94ms/step
# Train - Acurácia 0:  0.9402266288951842
# Train - Acurácia 2:  0.996600566572238
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5107587768969423
# validation - Acurácia 2:  0.8765571913929785
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2182 - accuracy: 0.9180 - val_loss: 2.9046 - val_accuracy: 0.5108
# Epoch 41/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.939943342776204
# Train - Acurácia 2:  0.9958923512747876
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5005662514156285
# validation - Acurácia 2:  0.8686296715741789
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2163 - accuracy: 0.9152 - val_loss: 2.9827 - val_accuracy: 0.5006
# Epoch 42/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9412181303116147
# Train - Acurácia 2:  0.9974504249291785
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5096262740656852
# validation - Acurácia 2:  0.8720271800679502
# 111/111 [==============================] - 64s 580ms/step - loss: 0.2137 - accuracy: 0.9186 - val_loss: 3.0391 - val_accuracy: 0.5096
# Epoch 43/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9426345609065155
# Train - Acurácia 2:  0.9981586402266289
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5096262740656852
# validation - Acurácia 2:  0.8765571913929785
# 111/111 [==============================] - 64s 581ms/step - loss: 0.2016 - accuracy: 0.9231 - val_loss: 2.9587 - val_accuracy: 0.5096
# Epoch 44/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.941643059490085
# Train - Acurácia 2:  0.9977337110481587
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5254813137032842
# validation - Acurácia 2:  0.8776896942242356
# 111/111 [==============================] - 64s 580ms/step - loss: 0.1908 - accuracy: 0.9249 - val_loss: 3.0012 - val_accuracy: 0.5255
# Epoch 45/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9379603399433428
# Train - Acurácia 2:  0.9963172804532577
# 14/14 [==============================] - 1s 95ms/step
# Validation - Acurácia 0:  0.4983012457531144
# validation - Acurácia 2:  0.8822197055492639
# 111/111 [==============================] - 64s 580ms/step - loss: 0.2009 - accuracy: 0.9214 - val_loss: 3.0074 - val_accuracy: 0.4983
# Epoch 46/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9409348441926345
# Train - Acurácia 2:  0.9974504249291785
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5152887882219706
# validation - Acurácia 2:  0.8844847112117781
# 111/111 [==============================] - 64s 580ms/step - loss: 0.1992 - accuracy: 0.9244 - val_loss: 3.1080 - val_accuracy: 0.5153
# Epoch 47/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9430594900849858
# Train - Acurácia 2:  0.998300283286119
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5164212910532276
# validation - Acurácia 2:  0.8686296715741789
# 111/111 [==============================] - 64s 581ms/step - loss: 0.1818 - accuracy: 0.9256 - val_loss: 3.1122 - val_accuracy: 0.5164
# Epoch 48/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9453257790368272
# Train - Acurácia 2:  0.9973087818696884
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.507361268403171
# validation - Acurácia 2:  0.8765571913929785
# 111/111 [==============================] - 64s 580ms/step - loss: 0.1890 - accuracy: 0.9242 - val_loss: 3.1237 - val_accuracy: 0.5074
# Epoch 49/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9429178470254957
# Train - Acurácia 2:  0.9968838526912182
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.5130237825594564
# validation - Acurácia 2:  0.8731596828992072
# 111/111 [==============================] - 64s 580ms/step - loss: 0.1821 - accuracy: 0.9275 - val_loss: 3.1657 - val_accuracy: 0.5130
# Epoch 50/50
# 111/111 [==============================] - 10s 95ms/step
# Train - Acurácia 0:  0.9364022662889518
# Train - Acurácia 2:  0.9957507082152974
# 14/14 [==============================] - 1s 94ms/step
# Validation - Acurácia 0:  0.4881087202718007
# validation - Acurácia 2:  0.8629671574178935
# 111/111 [==============================] - 64s 580ms/step - loss: 0.1754 - accuracy: 0.9275 - val_loss: 3.2252 - val_accuracy: 0.4881
# CPU times: user 56min 2s, sys: 1min 36s, total: 57min 39s
# Wall time: 54min 1s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'1')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k1'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k1',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_'+'k1',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k1')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k1')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 10s 94ms/step
# (7060, 140)
# (7060,)
# (7060,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_40 k=1', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_train_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_40_k=1'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#          Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_40_k=1    0.936402    0.993768     0.995751

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 94ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_40 k=1', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_validation_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_40_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=1    0.936402    0.993768     0.995751
# 1  validation_mexh_40_k=1    0.488109    0.818800     0.862967

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 95ms/step
# (883, 140)
# (883, 140)
# (883,)
# (883,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_40 k=1', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_test_'+'k1'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_40_k=1'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=1    0.936402    0.993768     0.995751
# 1  validation_mexh_40_k=1    0.488109    0.818800     0.862967
# 2        test_mexh_40_k=1    0.522084    0.843715     0.875425

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_40_kfold/Resultados_mexh_40_k1.xlsx", index=False)

# %% [markdown]
# # k=2

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/treino2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/teste2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/validation2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino2")
VAL_DATASET = os.path.join("/content", "validation2")
TEST_DATASET = os.path.join("/content", "teste2")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 45s - loss: 5.1672 - accuracy: 0.0208
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1028s vs `on_train_batch_end` time: 0.2763s). Check your callbacks.
# 111/111 [==============================] - 10s 91ms/step
# Train - Acurácia 0:  0.19612007929764938
# Train - Acurácia 2:  0.4899461908807703
# 14/14 [==============================] - 1s 90ms/step
# Validation - Acurácia 0:  0.19501133786848074
# validation - Acurácia 2:  0.47732426303854875
# 111/111 [==============================] - 80s 621ms/step - loss: 4.0860 - accuracy: 0.1732 - val_loss: 4.2102 - val_accuracy: 0.1950
# Epoch 2/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.29750778816199375
# Train - Acurácia 2:  0.5981308411214953
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.2947845804988662
# validation - Acurácia 2:  0.6156462585034014
# 111/111 [==============================] - 63s 569ms/step - loss: 2.9999 - accuracy: 0.3060 - val_loss: 3.2227 - val_accuracy: 0.2948
# Epoch 3/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.3517417162276975
# Train - Acurácia 2:  0.6778532993486265
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.35147392290249435
# validation - Acurácia 2:  0.6791383219954649
# 111/111 [==============================] - 63s 568ms/step - loss: 2.6740 - accuracy: 0.3523 - val_loss: 2.8025 - val_accuracy: 0.3515
# Epoch 4/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.4093741149815916
# Train - Acurácia 2:  0.767487963749646
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4013605442176871
# validation - Acurácia 2:  0.7551020408163265
# 111/111 [==============================] - 63s 569ms/step - loss: 2.4411 - accuracy: 0.3870 - val_loss: 2.4617 - val_accuracy: 0.4014
# Epoch 5/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.4374114981591617
# Train - Acurácia 2:  0.8094024355706598
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.40249433106575966
# validation - Acurácia 2:  0.7913832199546486
# 111/111 [==============================] - 63s 567ms/step - loss: 2.2558 - accuracy: 0.4193 - val_loss: 2.4093 - val_accuracy: 0.4025
# Epoch 6/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.4854148966298499
# Train - Acurácia 2:  0.8603794958935146
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.42970521541950113
# validation - Acurácia 2:  0.8378684807256236
# 111/111 [==============================] - 63s 567ms/step - loss: 2.1079 - accuracy: 0.4490 - val_loss: 2.1871 - val_accuracy: 0.4297
# Epoch 7/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.44916454262248656
# Train - Acurácia 2:  0.8419711129991504
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.41156462585034015
# validation - Acurácia 2:  0.8140589569160998
# 111/111 [==============================] - 63s 569ms/step - loss: 1.9914 - accuracy: 0.4720 - val_loss: 2.3192 - val_accuracy: 0.4116
# Epoch 8/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.5058057207589918
# Train - Acurácia 2:  0.8919569527046163
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.42290249433106575
# validation - Acurácia 2:  0.844671201814059
# 111/111 [==============================] - 63s 567ms/step - loss: 1.8986 - accuracy: 0.4795 - val_loss: 2.1146 - val_accuracy: 0.4229
# Epoch 9/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.5312942509204192
# Train - Acurácia 2:  0.8946474086661003
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4478458049886621
# validation - Acurácia 2:  0.8503401360544217
# 111/111 [==============================] - 63s 567ms/step - loss: 1.7991 - accuracy: 0.4975 - val_loss: 2.0644 - val_accuracy: 0.4478
# Epoch 10/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.5440385160011328
# Train - Acurácia 2:  0.9114981591617105
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 63s 568ms/step - loss: 1.7197 - accuracy: 0.5144 - val_loss: 1.9987 - val_accuracy: 0.4751
# Epoch 11/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.537666383460776
# Train - Acurácia 2:  0.9044180118946474
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.4421768707482993
# validation - Acurácia 2:  0.8582766439909297
# 111/111 [==============================] - 63s 567ms/step - loss: 1.6577 - accuracy: 0.5270 - val_loss: 2.0368 - val_accuracy: 0.4422
# Epoch 12/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.554375531011045
# Train - Acurácia 2:  0.9188615123194562
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 63s 568ms/step - loss: 1.5726 - accuracy: 0.5443 - val_loss: 2.0114 - val_accuracy: 0.4580
# Epoch 13/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.5706598697252903
# Train - Acurácia 2:  0.9255168507504956
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.463718820861678
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 63s 569ms/step - loss: 1.5280 - accuracy: 0.5456 - val_loss: 1.9709 - val_accuracy: 0.4637
# Epoch 14/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.5604644576607194
# Train - Acurácia 2:  0.8922401585952988
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4580498866213152
# validation - Acurácia 2:  0.8321995464852607
# 111/111 [==============================] - 63s 568ms/step - loss: 1.4553 - accuracy: 0.5673 - val_loss: 2.1268 - val_accuracy: 0.4580
# Epoch 15/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.615689606343812
# Train - Acurácia 2:  0.9476069102237327
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.46938775510204084
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 63s 568ms/step - loss: 1.4019 - accuracy: 0.5796 - val_loss: 1.9470 - val_accuracy: 0.4694
# Epoch 16/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.6462758425375248
# Train - Acurácia 2:  0.9474653072783914
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 63s 567ms/step - loss: 1.3194 - accuracy: 0.5918 - val_loss: 1.9041 - val_accuracy: 0.4898
# Epoch 17/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.6481166808269612
# Train - Acurácia 2:  0.952138204474653
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 63s 568ms/step - loss: 1.2500 - accuracy: 0.6167 - val_loss: 1.9615 - val_accuracy: 0.4796
# Epoch 18/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.6536391956952705
# Train - Acurácia 2:  0.95964316057774
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4671201814058957
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 63s 567ms/step - loss: 1.1491 - accuracy: 0.6430 - val_loss: 2.0093 - val_accuracy: 0.4671
# Epoch 19/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.6873406966864911
# Train - Acurácia 2:  0.963891248937978
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 63s 568ms/step - loss: 1.1054 - accuracy: 0.6514 - val_loss: 2.0444 - val_accuracy: 0.4830
# Epoch 20/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.7199093741149816
# Train - Acurácia 2:  0.9565278957802322
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 63s 567ms/step - loss: 1.0339 - accuracy: 0.6715 - val_loss: 2.0967 - val_accuracy: 0.4762
# Epoch 21/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.7536108751062022
# Train - Acurácia 2:  0.9645992636646842
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.46938775510204084
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 63s 566ms/step - loss: 0.9360 - accuracy: 0.6981 - val_loss: 2.1699 - val_accuracy: 0.4694
# Epoch 22/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.7635230812800906
# Train - Acurácia 2:  0.9728122344944775
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 63s 567ms/step - loss: 0.8711 - accuracy: 0.7192 - val_loss: 2.1740 - val_accuracy: 0.4864
# Epoch 23/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.7574341546304163
# Train - Acurácia 2:  0.9688473520249221
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 63s 567ms/step - loss: 0.8183 - accuracy: 0.7359 - val_loss: 2.1894 - val_accuracy: 0.4762
# Epoch 24/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.7945341263098272
# Train - Acurácia 2:  0.9706881903143585
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 63s 567ms/step - loss: 0.7749 - accuracy: 0.7508 - val_loss: 2.3656 - val_accuracy: 0.4773
# Epoch 25/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8146417445482866
# Train - Acurácia 2:  0.9780515434721042
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 63s 566ms/step - loss: 0.7189 - accuracy: 0.7716 - val_loss: 2.2729 - val_accuracy: 0.4977
# Epoch 26/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8336165392240159
# Train - Acurácia 2:  0.9763523081280091
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 63s 566ms/step - loss: 0.6213 - accuracy: 0.8054 - val_loss: 2.3596 - val_accuracy: 0.4785
# Epoch 27/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8606627017841971
# Train - Acurácia 2:  0.983857264231096
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.47392290249433106
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 63s 566ms/step - loss: 0.5769 - accuracy: 0.8206 - val_loss: 2.3690 - val_accuracy: 0.4739
# Epoch 28/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8609459076748797
# Train - Acurácia 2:  0.9861229113565562
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 63s 566ms/step - loss: 0.5289 - accuracy: 0.8325 - val_loss: 2.4908 - val_accuracy: 0.4989
# Epoch 29/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8746813933729821
# Train - Acurácia 2:  0.9832908524497309
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 63s 566ms/step - loss: 0.4803 - accuracy: 0.8503 - val_loss: 2.5007 - val_accuracy: 0.4751
# Epoch 30/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8935145851033701
# Train - Acurácia 2:  0.9869725290286038
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.463718820861678
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 63s 566ms/step - loss: 0.4446 - accuracy: 0.8605 - val_loss: 2.5587 - val_accuracy: 0.4637
# Epoch 31/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8850184083828944
# Train - Acurácia 2:  0.9800339847068819
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 63s 565ms/step - loss: 0.4097 - accuracy: 0.8721 - val_loss: 2.5699 - val_accuracy: 0.4807
# Epoch 32/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.8970546587369017
# Train - Acurácia 2:  0.9858397054658737
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 63s 566ms/step - loss: 0.4042 - accuracy: 0.8740 - val_loss: 2.6594 - val_accuracy: 0.4796
# Epoch 33/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9134806003964883
# Train - Acurácia 2:  0.9905126026621354
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 63s 566ms/step - loss: 0.3910 - accuracy: 0.8735 - val_loss: 2.7065 - val_accuracy: 0.4977
# Epoch 34/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9109317473803455
# Train - Acurácia 2:  0.991362220334183
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 63s 566ms/step - loss: 0.3561 - accuracy: 0.8870 - val_loss: 2.5904 - val_accuracy: 0.4932
# Epoch 35/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9236760124610592
# Train - Acurácia 2:  0.991928632115548
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 63s 565ms/step - loss: 0.3461 - accuracy: 0.8935 - val_loss: 2.6106 - val_accuracy: 0.5045
# Epoch 36/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9143302180685359
# Train - Acurácia 2:  0.9899461908807703
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 63s 566ms/step - loss: 0.3157 - accuracy: 0.8995 - val_loss: 2.7531 - val_accuracy: 0.4887
# Epoch 37/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9167374681393373
# Train - Acurácia 2:  0.9933446615689606
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47165532879818595
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 63s 566ms/step - loss: 0.2945 - accuracy: 0.9023 - val_loss: 2.8062 - val_accuracy: 0.4717
# Epoch 38/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9181534975927499
# Train - Acurácia 2:  0.9899461908807703
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 63s 565ms/step - loss: 0.3106 - accuracy: 0.8978 - val_loss: 2.7168 - val_accuracy: 0.5045
# Epoch 39/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.923534409515718
# Train - Acurácia 2:  0.992495043896913
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.5079365079365079
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 63s 566ms/step - loss: 0.2977 - accuracy: 0.9005 - val_loss: 2.7993 - val_accuracy: 0.5079
# Epoch 40/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9123477768337581
# Train - Acurácia 2:  0.9896629849900878
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.47505668934240364
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 63s 565ms/step - loss: 0.3096 - accuracy: 0.8969 - val_loss: 2.9461 - val_accuracy: 0.4751
# Epoch 41/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.929481733220051
# Train - Acurácia 2:  0.9930614556782781
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 63s 566ms/step - loss: 0.2784 - accuracy: 0.9064 - val_loss: 2.9248 - val_accuracy: 0.4977
# Epoch 42/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9355706598697253
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 63s 565ms/step - loss: 0.2797 - accuracy: 0.9073 - val_loss: 2.9404 - val_accuracy: 0.5057
# Epoch 43/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9260832625318607
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 63s 565ms/step - loss: 0.2431 - accuracy: 0.9126 - val_loss: 2.8309 - val_accuracy: 0.5034
# Epoch 44/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9266496743132258
# Train - Acurácia 2:  0.9900877938261116
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 63s 566ms/step - loss: 0.2354 - accuracy: 0.9163 - val_loss: 2.9989 - val_accuracy: 0.4796
# Epoch 45/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9222599830076466
# Train - Acurácia 2:  0.9910790144435004
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 63s 566ms/step - loss: 0.2604 - accuracy: 0.9064 - val_loss: 3.0340 - val_accuracy: 0.4853
# Epoch 46/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.934862645143019
# Train - Acurácia 2:  0.9958935145851033
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 63s 566ms/step - loss: 0.2435 - accuracy: 0.9132 - val_loss: 2.9106 - val_accuracy: 0.4909
# Epoch 47/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9301897479467572
# Train - Acurácia 2:  0.9944774851316908
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 63s 565ms/step - loss: 0.2484 - accuracy: 0.9133 - val_loss: 2.9645 - val_accuracy: 0.5034
# Epoch 48/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9303313508920985
# Train - Acurácia 2:  0.9926366468422543
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 63s 565ms/step - loss: 0.2459 - accuracy: 0.9139 - val_loss: 2.9709 - val_accuracy: 0.5045
# Epoch 49/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9245256301331067
# Train - Acurácia 2:  0.9915038232795242
# 14/14 [==============================] - 1s 92ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 63s 565ms/step - loss: 0.2482 - accuracy: 0.9121 - val_loss: 3.1819 - val_accuracy: 0.4807
# Epoch 50/50
# 111/111 [==============================] - 10s 92ms/step
# Train - Acurácia 0:  0.9337298215802888
# Train - Acurácia 2:  0.9958935145851033
# 14/14 [==============================] - 1s 91ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 63s 565ms/step - loss: 0.2241 - accuracy: 0.9187 - val_loss: 3.1383 - val_accuracy: 0.5023
# CPU times: user 54min 11s, sys: 1min 28s, total: 55min 39s
# Wall time: 52min 35s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'2')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k2'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k2',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_'+'k2',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k2')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k2')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 10s 92ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_40 k=2', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_train_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_40_k=2'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#          Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_40_k=2     0.93373    0.995185     0.995894

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 92ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_40 k=2', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_validation_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_40_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=2    0.933730    0.995185     0.995894
# 1  validation_mexh_40_k=2    0.502268    0.853741     0.886621

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 92ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_40 k=2', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_test_'+'k2'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_40_k=2'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=2    0.933730    0.995185     0.995894
# 1  validation_mexh_40_k=2    0.502268    0.853741     0.886621
# 2        test_mexh_40_k=2    0.522676    0.852608     0.890023

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_40_kfold/Resultados_mexh_40_k2.xlsx", index=False)

# %% [markdown]
# # k=3

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/treino3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/teste3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/validation3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino3")
VAL_DATASET = os.path.join("/content", "validation3")
TEST_DATASET = os.path.join("/content", "teste3")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 42s - loss: 5.1579 - accuracy: 0.0156
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0807s vs `on_train_batch_end` time: 0.2668s). Check your callbacks.
# 111/111 [==============================] - 9s 76ms/step
# Train - Acurácia 0:  0.1791277258566978
# Train - Acurácia 2:  0.5261965448881337
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.18027210884353742
# validation - Acurácia 2:  0.54421768707483
# 111/111 [==============================] - 74s 572ms/step - loss: 3.8907 - accuracy: 0.2046 - val_loss: 3.9038 - val_accuracy: 0.1803
# Epoch 2/50
# 111/111 [==============================] - 8s 75ms/step
# Train - Acurácia 0:  0.2824978759558199
# Train - Acurácia 2:  0.6247521948456528
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.2619047619047619
# validation - Acurácia 2:  0.6111111111111112
# 111/111 [==============================] - 59s 534ms/step - loss: 2.9043 - accuracy: 0.3315 - val_loss: 3.3348 - val_accuracy: 0.2619
# Epoch 3/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.3963466440101954
# Train - Acurácia 2:  0.7094307561597282
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.36394557823129253
# validation - Acurácia 2:  0.6859410430839002
# 111/111 [==============================] - 59s 532ms/step - loss: 2.5613 - accuracy: 0.3757 - val_loss: 2.5556 - val_accuracy: 0.3639
# Epoch 4/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4425092041914472
# Train - Acurácia 2:  0.8001982441234777
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3888888888888889
# validation - Acurácia 2:  0.7698412698412699
# 111/111 [==============================] - 59s 531ms/step - loss: 2.3314 - accuracy: 0.4109 - val_loss: 2.2974 - val_accuracy: 0.3889
# Epoch 5/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4344378363069952
# Train - Acurácia 2:  0.7912772585669782
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4070294784580499
# validation - Acurácia 2:  0.7789115646258503
# 111/111 [==============================] - 59s 531ms/step - loss: 2.1598 - accuracy: 0.4404 - val_loss: 2.3545 - val_accuracy: 0.4070
# Epoch 6/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4743698668932314
# Train - Acurácia 2:  0.8654772019258
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4217687074829932
# validation - Acurácia 2:  0.8390022675736961
# 111/111 [==============================] - 59s 532ms/step - loss: 2.0624 - accuracy: 0.4609 - val_loss: 2.1303 - val_accuracy: 0.4218
# Epoch 7/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.47875955819881055
# Train - Acurácia 2:  0.8523081280090626
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4308390022675737
# validation - Acurácia 2:  0.8401360544217688
# 111/111 [==============================] - 59s 531ms/step - loss: 1.9390 - accuracy: 0.4778 - val_loss: 2.1272 - val_accuracy: 0.4308
# Epoch 8/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.524214103653356
# Train - Acurácia 2:  0.9038516001132824
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.8662131519274376
# 111/111 [==============================] - 59s 531ms/step - loss: 1.8423 - accuracy: 0.4990 - val_loss: 1.9100 - val_accuracy: 0.4660
# Epoch 9/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.494619088077032
# Train - Acurácia 2:  0.8768054375531011
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4489795918367347
# validation - Acurácia 2:  0.844671201814059
# 111/111 [==============================] - 59s 530ms/step - loss: 1.7951 - accuracy: 0.5059 - val_loss: 2.1149 - val_accuracy: 0.4490
# Epoch 10/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.540923251203625
# Train - Acurácia 2:  0.9139054092325121
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 531ms/step - loss: 1.7152 - accuracy: 0.5140 - val_loss: 1.8701 - val_accuracy: 0.4898
# Epoch 11/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5548003398470688
# Train - Acurácia 2:  0.9167374681393373
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.46598639455782315
# validation - Acurácia 2:  0.873015873015873
# 111/111 [==============================] - 59s 531ms/step - loss: 1.6409 - accuracy: 0.5326 - val_loss: 1.9304 - val_accuracy: 0.4660
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5679694137638063
# Train - Acurácia 2:  0.9303313508920985
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47392290249433106
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 531ms/step - loss: 1.5720 - accuracy: 0.5473 - val_loss: 1.9250 - val_accuracy: 0.4739
# Epoch 13/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5865193996035117
# Train - Acurácia 2:  0.927357689039932
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.481859410430839
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 531ms/step - loss: 1.4989 - accuracy: 0.5663 - val_loss: 1.8995 - val_accuracy: 0.4819
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6149815916171056
# Train - Acurácia 2:  0.9405267629566695
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 531ms/step - loss: 1.4188 - accuracy: 0.5837 - val_loss: 1.8099 - val_accuracy: 0.5147
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6274426508071368
# Train - Acurácia 2:  0.9422259983007647
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 531ms/step - loss: 1.3378 - accuracy: 0.5977 - val_loss: 1.8103 - val_accuracy: 0.4830
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6702067403001982
# Train - Acurácia 2:  0.9600679694137638
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5170068027210885
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 530ms/step - loss: 1.2818 - accuracy: 0.6097 - val_loss: 1.7841 - val_accuracy: 0.5170
# Epoch 17/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6636930048145001
# Train - Acurácia 2:  0.9544038516001133
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 59s 531ms/step - loss: 1.2071 - accuracy: 0.6245 - val_loss: 1.8753 - val_accuracy: 0.4932
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.703483432455395
# Train - Acurácia 2:  0.9617672047578589
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 59s 530ms/step - loss: 1.1279 - accuracy: 0.6400 - val_loss: 1.8864 - val_accuracy: 0.5113
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7036250354007363
# Train - Acurácia 2:  0.9610591900311527
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 59s 530ms/step - loss: 1.0404 - accuracy: 0.6669 - val_loss: 1.8564 - val_accuracy: 0.5068
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7293967714528462
# Train - Acurácia 2:  0.9587935429056924
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 59s 530ms/step - loss: 0.9606 - accuracy: 0.6923 - val_loss: 1.9175 - val_accuracy: 0.4943
# Epoch 21/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7602662135372416
# Train - Acurácia 2:  0.9667233078448032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 530ms/step - loss: 0.8655 - accuracy: 0.7203 - val_loss: 2.0018 - val_accuracy: 0.5068
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7612574341546304
# Train - Acurácia 2:  0.9653072783913905
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48412698412698413
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 530ms/step - loss: 0.8118 - accuracy: 0.7373 - val_loss: 2.0853 - val_accuracy: 0.4841
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7898612291135656
# Train - Acurácia 2:  0.9755026904559615
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5124716553287982
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 530ms/step - loss: 0.7492 - accuracy: 0.7583 - val_loss: 2.0576 - val_accuracy: 0.5125
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8044463324837157
# Train - Acurácia 2:  0.9740866610025488
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 59s 529ms/step - loss: 0.7032 - accuracy: 0.7702 - val_loss: 2.1403 - val_accuracy: 0.5113
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8370150099122061
# Train - Acurácia 2:  0.9807419994335882
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 530ms/step - loss: 0.6522 - accuracy: 0.7910 - val_loss: 2.1207 - val_accuracy: 0.5147
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8626451430189748
# Train - Acurácia 2:  0.982724440668366
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5102040816326531
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 531ms/step - loss: 0.5664 - accuracy: 0.8192 - val_loss: 2.1049 - val_accuracy: 0.5102
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8695836873406967
# Train - Acurácia 2:  0.9855564995751912
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 530ms/step - loss: 0.5119 - accuracy: 0.8374 - val_loss: 2.2421 - val_accuracy: 0.5068
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8868592466723307
# Train - Acurácia 2:  0.985981308411215
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5215419501133787
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 530ms/step - loss: 0.4786 - accuracy: 0.8414 - val_loss: 2.3274 - val_accuracy: 0.5215
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8969130557915604
# Train - Acurácia 2:  0.989238176154064
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5102040816326531
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 529ms/step - loss: 0.4563 - accuracy: 0.8541 - val_loss: 2.2414 - val_accuracy: 0.5102
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8997451146983857
# Train - Acurácia 2:  0.988671764372699
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 530ms/step - loss: 0.4212 - accuracy: 0.8625 - val_loss: 2.4660 - val_accuracy: 0.4989
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9010195412064571
# Train - Acurácia 2:  0.991362220334183
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 529ms/step - loss: 0.3831 - accuracy: 0.8767 - val_loss: 2.4434 - val_accuracy: 0.4898
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9123477768337581
# Train - Acurácia 2:  0.9932030586236194
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 529ms/step - loss: 0.3587 - accuracy: 0.8842 - val_loss: 2.4650 - val_accuracy: 0.5113
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9038516001132824
# Train - Acurácia 2:  0.9890965732087228
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3593 - accuracy: 0.8828 - val_loss: 2.5040 - val_accuracy: 0.5000
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9157462475219484
# Train - Acurácia 2:  0.991362220334183
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3424 - accuracy: 0.8879 - val_loss: 2.5538 - val_accuracy: 0.5091
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9150382327952421
# Train - Acurácia 2:  0.9923534409515717
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5260770975056689
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 59s 529ms/step - loss: 0.3243 - accuracy: 0.8931 - val_loss: 2.5746 - val_accuracy: 0.5261
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9284905126026621
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2954 - accuracy: 0.9022 - val_loss: 2.5765 - val_accuracy: 0.5045
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9325969980175588
# Train - Acurácia 2:  0.9961767204757859
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2712 - accuracy: 0.9089 - val_loss: 2.6507 - val_accuracy: 0.5023
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9362786745964317
# Train - Acurácia 2:  0.9964599263664684
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2635 - accuracy: 0.9098 - val_loss: 2.6423 - val_accuracy: 0.5147
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9258000566411781
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2574 - accuracy: 0.9102 - val_loss: 2.6533 - val_accuracy: 0.5011
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9341546304163126
# Train - Acurácia 2:  0.9970263381478335
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.518140589569161
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2366 - accuracy: 0.9182 - val_loss: 2.6461 - val_accuracy: 0.5181
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.91928632115548
# Train - Acurácia 2:  0.9958935145851033
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8707482993197279
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2484 - accuracy: 0.9142 - val_loss: 2.7912 - val_accuracy: 0.4807
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9355706598697253
# Train - Acurácia 2:  0.9954687057490795
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2374 - accuracy: 0.9148 - val_loss: 2.7912 - val_accuracy: 0.5113
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9310393656188048
# Train - Acurácia 2:  0.9949022939677146
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8786848072562359
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2320 - accuracy: 0.9160 - val_loss: 2.7499 - val_accuracy: 0.5147
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9367034834324554
# Train - Acurácia 2:  0.9970263381478335
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2278 - accuracy: 0.9200 - val_loss: 2.7305 - val_accuracy: 0.5068
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9238176154064005
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4954648526077097
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2266 - accuracy: 0.9138 - val_loss: 2.9653 - val_accuracy: 0.4955
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9290569243840272
# Train - Acurácia 2:  0.9954687057490795
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2362 - accuracy: 0.9163 - val_loss: 2.9319 - val_accuracy: 0.5091
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9231096006796942
# Train - Acurácia 2:  0.9929198527329368
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2529 - accuracy: 0.9074 - val_loss: 2.9448 - val_accuracy: 0.4943
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9259416595865194
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 528ms/step - loss: 0.2621 - accuracy: 0.9088 - val_loss: 3.0065 - val_accuracy: 0.4977
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9338714245256301
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5011337868480725
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2207 - accuracy: 0.9190 - val_loss: 2.7858 - val_accuracy: 0.5011
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9241008212970829
# Train - Acurácia 2:  0.9947606910223733
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4965986394557823
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2388 - accuracy: 0.9116 - val_loss: 2.9608 - val_accuracy: 0.4966
# CPU times: user 52min 14s, sys: 1min 21s, total: 53min 36s
# Wall time: 49min 12s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'3')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k3'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k3',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_'+'k3',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k3')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k3')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-b4e42dfbaaa4> in <module>
# ----> 1 model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_'+'k3')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204         if isinstance(filepath_str, str):
#     205           if not tf.io.gfile.exists(filepath_str):
# --> 206             raise IOError(f'No file or directory found at {filepath_str}')
#     207
#     208           if tf.io.gfile.isdir(filepath_str):
#
# OSError: No file or directory found at /content/drive/MyDrive/Resultados/mexh_6_kfold/mexh_6_kfold_k3

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 76ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_40 k=3', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_train_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_40_k=3'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#          Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_40_k=3    0.924101    0.991079     0.994761

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_40 k=3', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_validation_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_40_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=3    0.924101    0.991079     0.994761
# 1  validation_mexh_40_k=3    0.496599    0.862812     0.893424

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_40 k=3', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_test_'+'k3'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_40_k=3'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=3    0.924101    0.991079     0.994761
# 1  validation_mexh_40_k=3    0.496599    0.862812     0.893424
# 2        test_mexh_40_k=3    0.515873    0.856009     0.880952

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_40_kfold/Resultados_mexh_40_k3.xlsx", index=False)

# %% [markdown]
# # k=4

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/treino4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/teste4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/validation4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino4")
VAL_DATASET = os.path.join("/content", "validation4")
TEST_DATASET = os.path.join("/content", "teste4")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 42s - loss: 5.0615 - accuracy: 0.0312
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0838s vs `on_train_batch_end` time: 0.2656s). Check your callbacks.
# 111/111 [==============================] - 9s 74ms/step
# Train - Acurácia 0:  0.19173038799207023
# Train - Acurácia 2:  0.5303030303030303
# 14/14 [==============================] - 1s 74ms/step
# Validation - Acurácia 0:  0.21315192743764172
# validation - Acurácia 2:  0.528344671201814
# 111/111 [==============================] - 73s 563ms/step - loss: 3.7955 - accuracy: 0.2186 - val_loss: 4.4759 - val_accuracy: 0.2132
# Epoch 2/50
# 111/111 [==============================] - 8s 75ms/step
# Train - Acurácia 0:  0.34395355423392804
# Train - Acurácia 2:  0.6924384027187765
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.35487528344671204
# validation - Acurácia 2:  0.6746031746031746
# 111/111 [==============================] - 58s 523ms/step - loss: 2.7836 - accuracy: 0.3509 - val_loss: 2.8348 - val_accuracy: 0.3549
# Epoch 3/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4005947323704333
# Train - Acurácia 2:  0.7687623902577173
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.41496598639455784
# validation - Acurácia 2:  0.7607709750566893
# 111/111 [==============================] - 58s 528ms/step - loss: 2.4354 - accuracy: 0.4020 - val_loss: 2.4760 - val_accuracy: 0.4150
# Epoch 4/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.45284621920135937
# Train - Acurácia 2:  0.8438119512885868
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.41950113378684806
# validation - Acurácia 2:  0.8299319727891157
# 111/111 [==============================] - 59s 532ms/step - loss: 2.2118 - accuracy: 0.4330 - val_loss: 2.1769 - val_accuracy: 0.4195
# Epoch 5/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.46105919003115264
# Train - Acurácia 2:  0.8574058340413481
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4410430839002268
# validation - Acurácia 2:  0.8480725623582767
# 111/111 [==============================] - 59s 532ms/step - loss: 2.0241 - accuracy: 0.4649 - val_loss: 2.0664 - val_accuracy: 0.4410
# Epoch 6/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.48796374964599265
# Train - Acurácia 2:  0.8603794958935146
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8571428571428571
# 111/111 [==============================] - 59s 531ms/step - loss: 1.9177 - accuracy: 0.4722 - val_loss: 1.9311 - val_accuracy: 0.5057
# Epoch 7/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5257717360521099
# Train - Acurácia 2:  0.9008779382611158
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 532ms/step - loss: 1.7822 - accuracy: 0.5034 - val_loss: 1.8558 - val_accuracy: 0.4977
# Epoch 8/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5325686774284906
# Train - Acurácia 2:  0.8940809968847352
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 59s 532ms/step - loss: 1.7001 - accuracy: 0.5146 - val_loss: 1.8485 - val_accuracy: 0.5000
# Epoch 9/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5761823845935995
# Train - Acurácia 2:  0.9253752478051543
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5204081632653061
# validation - Acurácia 2:  0.8990929705215419
# 111/111 [==============================] - 59s 531ms/step - loss: 1.6231 - accuracy: 0.5265 - val_loss: 1.7723 - val_accuracy: 0.5204
# Epoch 10/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5743415463041631
# Train - Acurácia 2:  0.926791277258567
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5158730158730159
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 532ms/step - loss: 1.5441 - accuracy: 0.5490 - val_loss: 1.7657 - val_accuracy: 0.5159
# Epoch 11/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5992636646842254
# Train - Acurácia 2:  0.9318889832908525
# 14/14 [==============================] - 1s 77ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 59s 531ms/step - loss: 1.4646 - accuracy: 0.5559 - val_loss: 1.8473 - val_accuracy: 0.5147
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6200792976493911
# Train - Acurácia 2:  0.94619088077032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5034013605442177
# validation - Acurácia 2:  0.9070294784580499
# 111/111 [==============================] - 59s 531ms/step - loss: 1.3647 - accuracy: 0.5872 - val_loss: 1.8005 - val_accuracy: 0.5034
# Epoch 13/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6469838572642311
# Train - Acurácia 2:  0.9508637779665817
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 59s 531ms/step - loss: 1.2713 - accuracy: 0.6085 - val_loss: 1.7946 - val_accuracy: 0.5091
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6723307844803172
# Train - Acurácia 2:  0.9566694987255735
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.9070294784580499
# 111/111 [==============================] - 59s 533ms/step - loss: 1.1980 - accuracy: 0.6177 - val_loss: 1.8330 - val_accuracy: 0.5147
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.699660152931181
# Train - Acurácia 2:  0.9582271311243273
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.528344671201814
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 531ms/step - loss: 1.1109 - accuracy: 0.6454 - val_loss: 1.8492 - val_accuracy: 0.5283
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7442650807136788
# Train - Acurácia 2:  0.9699801755876523
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5374149659863946
# validation - Acurácia 2:  0.9047619047619048
# 111/111 [==============================] - 59s 531ms/step - loss: 1.0133 - accuracy: 0.6756 - val_loss: 1.8793 - val_accuracy: 0.5374
# Epoch 17/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.754602095723591
# Train - Acurácia 2:  0.9595015576323987
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5328798185941043
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 59s 530ms/step - loss: 0.9184 - accuracy: 0.7042 - val_loss: 2.0235 - val_accuracy: 0.5329
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7799490229396772
# Train - Acurácia 2:  0.9749362786745964
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5249433106575964
# validation - Acurácia 2:  0.9036281179138322
# 111/111 [==============================] - 59s 531ms/step - loss: 0.8404 - accuracy: 0.7227 - val_loss: 1.9645 - val_accuracy: 0.5249
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8000566411781365
# Train - Acurácia 2:  0.9719626168224299
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5158730158730159
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 532ms/step - loss: 0.7318 - accuracy: 0.7579 - val_loss: 2.1039 - val_accuracy: 0.5159
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8350325686774285
# Train - Acurácia 2:  0.9797507788161994
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5419501133786848
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 533ms/step - loss: 0.6722 - accuracy: 0.7826 - val_loss: 2.1493 - val_accuracy: 0.5420
# Epoch 21/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8272444066836591
# Train - Acurácia 2:  0.9793259699801756
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5068027210884354
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 59s 531ms/step - loss: 0.6227 - accuracy: 0.8002 - val_loss: 2.2431 - val_accuracy: 0.5068
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.861653922401586
# Train - Acurácia 2:  0.9845652789578023
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5260770975056689
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 530ms/step - loss: 0.5556 - accuracy: 0.8221 - val_loss: 2.2711 - val_accuracy: 0.5261
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8765222316624186
# Train - Acurácia 2:  0.9885301614273577
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 59s 531ms/step - loss: 0.4891 - accuracy: 0.8445 - val_loss: 2.3267 - val_accuracy: 0.5193
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8895497026338148
# Train - Acurácia 2:  0.9885301614273577
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5238095238095238
# validation - Acurácia 2:  0.8843537414965986
# 111/111 [==============================] - 59s 530ms/step - loss: 0.4313 - accuracy: 0.8643 - val_loss: 2.4159 - val_accuracy: 0.5238
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8960634381195128
# Train - Acurácia 2:  0.9909374114981592
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5147392290249433
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 531ms/step - loss: 0.4025 - accuracy: 0.8713 - val_loss: 2.5186 - val_accuracy: 0.5147
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9013027470971396
# Train - Acurácia 2:  0.9927782497875955
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5374149659863946
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3730 - accuracy: 0.8785 - val_loss: 2.4947 - val_accuracy: 0.5374
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9044180118946474
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5419501133786848
# validation - Acurácia 2:  0.9058956916099773
# 111/111 [==============================] - 59s 531ms/step - loss: 0.3475 - accuracy: 0.8857 - val_loss: 2.4873 - val_accuracy: 0.5420
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9130557915604645
# Train - Acurácia 2:  0.992495043896913
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5510204081632653
# validation - Acurácia 2:  0.9024943310657596
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3343 - accuracy: 0.8888 - val_loss: 2.4537 - val_accuracy: 0.5510
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9243840271877655
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5136054421768708
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2888 - accuracy: 0.9048 - val_loss: 2.5225 - val_accuracy: 0.5136
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.923534409515718
# Train - Acurácia 2:  0.9963183234211271
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5374149659863946
# validation - Acurácia 2:  0.9058956916099773
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2789 - accuracy: 0.9046 - val_loss: 2.6418 - val_accuracy: 0.5374
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9334466156896063
# Train - Acurácia 2:  0.9961767204757859
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5340136054421769
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 533ms/step - loss: 0.2747 - accuracy: 0.9073 - val_loss: 2.6036 - val_accuracy: 0.5340
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9250920419144718
# Train - Acurácia 2:  0.9964599263664684
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5272108843537415
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2597 - accuracy: 0.9102 - val_loss: 2.6766 - val_accuracy: 0.5272
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9323137921268763
# Train - Acurácia 2:  0.9971679410931747
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5294784580498866
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2709 - accuracy: 0.9056 - val_loss: 2.5842 - val_accuracy: 0.5295
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9331634097989239
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5328798185941043
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2627 - accuracy: 0.9053 - val_loss: 2.7118 - val_accuracy: 0.5329
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9284905126026621
# Train - Acurácia 2:  0.9964599263664684
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5306122448979592
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2702 - accuracy: 0.9060 - val_loss: 2.7237 - val_accuracy: 0.5306
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9317473803455112
# Train - Acurácia 2:  0.9974511469838573
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5260770975056689
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2480 - accuracy: 0.9114 - val_loss: 2.9361 - val_accuracy: 0.5261
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9311809685641461
# Train - Acurácia 2:  0.9968847352024922
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5192743764172335
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2419 - accuracy: 0.9149 - val_loss: 2.7976 - val_accuracy: 0.5193
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.938119512885868
# Train - Acurácia 2:  0.9987255734919286
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5340136054421769
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2326 - accuracy: 0.9139 - val_loss: 2.8470 - val_accuracy: 0.5340
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9201359388275276
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2548 - accuracy: 0.9056 - val_loss: 2.9379 - val_accuracy: 0.4977
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.933305012744265
# Train - Acurácia 2:  0.9961767204757859
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5226757369614512
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2321 - accuracy: 0.9136 - val_loss: 2.7865 - val_accuracy: 0.5227
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9369866893231379
# Train - Acurácia 2:  0.9966015293118097
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5306122448979592
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2348 - accuracy: 0.9136 - val_loss: 2.8780 - val_accuracy: 0.5306
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9399603511753044
# Train - Acurácia 2:  0.997309544038516
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5453514739229025
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2036 - accuracy: 0.9190 - val_loss: 2.8411 - val_accuracy: 0.5454
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9406683659020108
# Train - Acurácia 2:  0.9966015293118097
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5498866213151927
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2095 - accuracy: 0.9201 - val_loss: 2.8445 - val_accuracy: 0.5499
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9365618804871141
# Train - Acurácia 2:  0.9988671764372699
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5476190476190477
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 531ms/step - loss: 0.1920 - accuracy: 0.9235 - val_loss: 2.9492 - val_accuracy: 0.5476
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9436420277541773
# Train - Acurácia 2:  0.9990087793826111
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5396825396825397
# validation - Acurácia 2:  0.8922902494331065
# 111/111 [==============================] - 59s 530ms/step - loss: 0.1899 - accuracy: 0.9217 - val_loss: 2.8893 - val_accuracy: 0.5397
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9325969980175588
# Train - Acurácia 2:  0.9970263381478335
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5408163265306123
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2047 - accuracy: 0.9208 - val_loss: 2.8176 - val_accuracy: 0.5408
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9385443217218918
# Train - Acurácia 2:  0.9984423676012462
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5453514739229025
# validation - Acurácia 2:  0.9013605442176871
# 111/111 [==============================] - 59s 529ms/step - loss: 0.1984 - accuracy: 0.9201 - val_loss: 2.9102 - val_accuracy: 0.5454
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9409515717926933
# Train - Acurácia 2:  0.9987255734919286
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5430839002267573
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 529ms/step - loss: 0.1878 - accuracy: 0.9250 - val_loss: 2.8440 - val_accuracy: 0.5431
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9432172189181535
# Train - Acurácia 2:  0.9983007646559049
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5385487528344671
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 530ms/step - loss: 0.1774 - accuracy: 0.9279 - val_loss: 2.9799 - val_accuracy: 0.5385
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9430756159728122
# Train - Acurácia 2:  0.9985839705465873
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5260770975056689
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 530ms/step - loss: 0.1800 - accuracy: 0.9252 - val_loss: 3.1010 - val_accuracy: 0.5261
# CPU times: user 52min 21s, sys: 1min 24s, total: 53min 46s
# Wall time: 49min 24s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'4')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k4'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k4',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_'+'k4',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k4')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k4')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 8s 76ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_40 k=4', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_train_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_40_k=4'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#          Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_40_k=4    0.943076    0.997734     0.998584

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 75ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_40 k=4', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_validation_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_40_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=4    0.943076    0.997734     0.998584
# 1  validation_mexh_40_k=4    0.526077    0.860544     0.883220

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_40 k=4', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_test_'+'k4'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_40_k=4'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=4    0.943076    0.997734     0.998584
# 1  validation_mexh_40_k=4    0.526077    0.860544     0.883220
# 2        test_mexh_40_k=4    0.517007    0.848073     0.886621

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_40_kfold/Resultados_mexh_40_k4.xlsx", index=False)

# %% [markdown]
# # k=5

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/treino5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/teste5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Database/training_mexh_40_review_split/validation5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "treino5")
VAL_DATASET = os.path.join("/content", "validation5")
TEST_DATASET = os.path.join("/content", "teste5")
METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
classes = sorted(classes)


def make_dataset_aug(path, batch_size):
   
    def parse_image_augmented(filename,label):
        if np.random.rand()<=0.75:            
            fator = np.random.choice([0.8, 0.85, 0.9, 0.95, 1, 1.05, 1.1, 1.15, 1.2])            
            fator = fator.astype(np.float32)
            rand_value = tf.constant(fator, dtype=tf.float32)
                        
            label_real = tf.strings.split(filename, os.sep)[-2] 
            label_real = tf.strings.to_number(label_real, tf.float32)
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            tf_60 = tf.constant(60)
            tf_199 = tf.constant(199)
            tf_cond1 = tf.math.less_equal(label_aug,tf_60)
            tf_cond2 = tf.math.greater_equal(label_aug,tf_199)
            tf_cond = tf.math.logical_or(tf_cond1, tf_cond2)
            
            def f1(): return 1.0
            def f2(): return fator
            fator=tf.cond(tf_cond, f1, f2)
            rand_value = fator
            
            label_aug = tf.multiply(label_real,rand_value)      
            label_aug = tf.math.round(label_aug)
            label_aug = tf.cast(label_aug, tf.int32)
            
            label_aug = tf.as_string(label_aug)
            label_aug = tf.experimental.numpy.where((np.array(classes)==label_aug))
            label_aug = label_aug[0][0]
            label_aug = tf.cast(label_aug, dtype=tf.int32)
                      
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            #width = int(np.around(256*fator,0)) 
            width=tf.multiply(tf.constant(256, dtype=tf.float32),fator)
            image_aug = tf.image.random_crop(image,size=(40, width,1))
            image_aug = tf.image.resize(image_aug, [40,256]) #height, width)
            image_aug = tf.image.per_image_standardization(image_aug)
        else:
            image = tf.io.read_file(filename)
            image = tf.image.decode_jpeg(image, channels=3)
            image = tf.image.rgb_to_grayscale(image)
            image = tf.image.per_image_standardization(image)
            image_aug = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
            label_aug = label
        return (image_aug, label_aug)
 
    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

     #Pegar todas as classes possíveis
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)    
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices((filenames,labels))
    ds=filenames_ds.map(lambda x,y: parse_image_augmented(x,y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds

# %%
trainAugDS = make_dataset_aug(TRAIN_DATASET, config.BS)
print(trainAugDS)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_simple(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.rgb_to_grayscale(image)
        image = tf.image.per_image_standardization(image)
        image = tf.image.crop_to_bounding_box(image, 0, 108, 40, 256)
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    classes = os.listdir(METRONOMOS_DATASET) #classes de 23 a 257
    classes = sorted(classes)
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [classes.index(name.split('/')[-2]) for name in filenames]   #\Necessário abrir este laço no caso de regressão
    
    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds,classes,images_ds,labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset_simple(TRAIN_DATASET, config.BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_simple(VAL_DATASET, config.BS) #labels com valores 0 a 234
testDS, classes_te, images_test, labels_test = make_dataset_simple(TEST_DATASET, config.BS)

# %%
print(classes_t)
print(classes)
# Out:
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257


list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

list_labels_test= list(labels_test.as_numpy_iterator())
labels_test_true = []
for i in list_labels_test:
       labels_test_true.append(classes[i])
labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
images_test_ds = np.array(list_images_test)
print(labels_train_true.shape)
print(labels_validation_true.shape)
print(labels_test_true.shape)
print(trainAugDS)
print(trainDS)
print(validationDS)
print(testDS)
# Out:
# (7062, 40, 256, 1)
# (882, 40, 256, 1)
# (7062,)
# (882,)
# (882,)
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 40, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1])

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/config.BS)
validation_steps = math.ceil(num_images_val/config.BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss ='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
accuracy0_train=[]
accuracy0_validation=[]
accuracy2_train=[]
accuracy2_validation=[]
class Accuracy2(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
        arg_max_train = np.argmax(train_predictions, axis=1)
        shape_train = train_predictions.shape
        for i in range(0,shape_train[0]):
            for j in range(0,shape_train[1]):
                if (j==arg_max_train[i]):
                    train_predictions[i][j]=1
                else:
                    train_predictions[i][j]=0    
        train_predictions = mlb.inverse_transform(train_predictions)
        train_predictions = np.array(train_predictions)
        train_predictions = train_predictions.astype(int)
        train_predictions = np.reshape(train_predictions, (train_predictions.size,))
        print("Train - Acurácia 0: ",acuracia0(labels_train_true, train_predictions))
        accuracy0_train.append(acuracia0(labels_train_true, train_predictions))        
        print("Train - Acurácia 2: ",acuracia2(labels_train_true, train_predictions))
        accuracy2_train.append(acuracia2(labels_train_true, train_predictions))            
        
        validation_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
        #print(train_predictions.shape)
        arg_max_validation = np.argmax(validation_predictions, axis=1)
        #print(arg_max)
        #print(arg_max)
        shape_validation = validation_predictions.shape
        #print(shape[0])
        for i in range(0,shape_validation[0]):
            for j in range(0,shape_validation[1]):
                if (j==arg_max_validation[i]):
                    validation_predictions[i][j]=1
                else:
                    validation_predictions[i][j]=0  
        validation_predictions= mlb.inverse_transform(validation_predictions)
        validation_predictions= np.array(validation_predictions)
        validation_predictions = validation_predictions.astype(int)
        validation_predictions = np.reshape(validation_predictions, (validation_predictions.size,))
        print("Validation - Acurácia 0: ",acuracia0(labels_validation_true, validation_predictions))
        accuracy0_validation.append(acuracia0(labels_validation_true, validation_predictions))        
        print("validation - Acurácia 2: ",acuracia2(labels_validation_true, validation_predictions))
        accuracy2_validation.append(acuracia2(labels_validation_true, validation_predictions))

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS, validation_data=validationDS, epochs=50, batch_size=config.BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1, callbacks=[Accuracy2()])
# Out:
# Epoch 1/50
#   6/111 [>.............................] - ETA: 41s - loss: 5.2079 - accuracy: 0.0078
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0807s vs `on_train_batch_end` time: 0.2637s). Check your callbacks.
# 111/111 [==============================] - 9s 75ms/step
# Train - Acurácia 0:  0.24582271311243273
# Train - Acurácia 2:  0.5761823845935995
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.21768707482993196
# validation - Acurácia 2:  0.54421768707483
# 111/111 [==============================] - 74s 566ms/step - loss: 4.0250 - accuracy: 0.1781 - val_loss: 3.8679 - val_accuracy: 0.2177
# Epoch 2/50
# 111/111 [==============================] - 8s 75ms/step
# Train - Acurácia 0:  0.30203908241291416
# Train - Acurácia 2:  0.680826961200793
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.2653061224489796
# validation - Acurácia 2:  0.6337868480725624
# 111/111 [==============================] - 60s 537ms/step - loss: 2.8494 - accuracy: 0.3363 - val_loss: 3.0808 - val_accuracy: 0.2653
# Epoch 3/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.3372982158028887
# Train - Acurácia 2:  0.7428490512602662
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3253968253968254
# validation - Acurácia 2:  0.7278911564625851
# 111/111 [==============================] - 59s 531ms/step - loss: 2.5307 - accuracy: 0.3726 - val_loss: 2.8394 - val_accuracy: 0.3254
# Epoch 4/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.3786462758425375
# Train - Acurácia 2:  0.7939677145284622
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.3673469387755102
# validation - Acurácia 2:  0.7789115646258503
# 111/111 [==============================] - 59s 532ms/step - loss: 2.3069 - accuracy: 0.4073 - val_loss: 2.6461 - val_accuracy: 0.3673
# Epoch 5/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.45992636646842255
# Train - Acurácia 2:  0.8496176720475785
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4467120181405896
# validation - Acurácia 2:  0.8469387755102041
# 111/111 [==============================] - 59s 532ms/step - loss: 2.1494 - accuracy: 0.4327 - val_loss: 2.1800 - val_accuracy: 0.4467
# Epoch 6/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.4755026904559615
# Train - Acurácia 2:  0.8707165109034268
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4308390022675737
# validation - Acurácia 2:  0.844671201814059
# 111/111 [==============================] - 59s 532ms/step - loss: 2.0155 - accuracy: 0.4591 - val_loss: 2.1278 - val_accuracy: 0.4308
# Epoch 7/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.48329085244973097
# Train - Acurácia 2:  0.8861512319456245
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4444444444444444
# validation - Acurácia 2:  0.8605442176870748
# 111/111 [==============================] - 59s 532ms/step - loss: 1.9171 - accuracy: 0.4786 - val_loss: 2.0226 - val_accuracy: 0.4444
# Epoch 8/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.510761823845936
# Train - Acurácia 2:  0.8950722175021241
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4557823129251701
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 59s 531ms/step - loss: 1.8342 - accuracy: 0.4890 - val_loss: 1.9844 - val_accuracy: 0.4558
# Epoch 9/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5518266779949023
# Train - Acurácia 2:  0.9131973945058057
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 531ms/step - loss: 1.7426 - accuracy: 0.5135 - val_loss: 1.9185 - val_accuracy: 0.4921
# Epoch 10/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5634381195128859
# Train - Acurácia 2:  0.9249504389691305
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 532ms/step - loss: 1.6620 - accuracy: 0.5221 - val_loss: 1.8631 - val_accuracy: 0.5023
# Epoch 11/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5518266779949023
# Train - Acurácia 2:  0.916029453412631
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47278911564625853
# validation - Acurácia 2:  0.8764172335600907
# 111/111 [==============================] - 59s 532ms/step - loss: 1.5759 - accuracy: 0.5401 - val_loss: 1.9764 - val_accuracy: 0.4728
# Epoch 12/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.5640045312942509
# Train - Acurácia 2:  0.9048428207306712
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.46938775510204084
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 59s 532ms/step - loss: 1.5292 - accuracy: 0.5457 - val_loss: 2.0273 - val_accuracy: 0.4694
# Epoch 13/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6056357972245823
# Train - Acurácia 2:  0.938119512885868
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47392290249433106
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 531ms/step - loss: 1.4497 - accuracy: 0.5660 - val_loss: 1.8935 - val_accuracy: 0.4739
# Epoch 14/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6274426508071368
# Train - Acurácia 2:  0.9412347776833758
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 532ms/step - loss: 1.3487 - accuracy: 0.5980 - val_loss: 1.9293 - val_accuracy: 0.4830
# Epoch 15/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6326819597847635
# Train - Acurácia 2:  0.9451996601529312
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4523809523809524
# validation - Acurácia 2:  0.8866213151927438
# 111/111 [==============================] - 59s 533ms/step - loss: 1.2687 - accuracy: 0.6113 - val_loss: 1.9819 - val_accuracy: 0.4524
# Epoch 16/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.6465590484282073
# Train - Acurácia 2:  0.9624752194845653
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.9138321995464853
# 111/111 [==============================] - 59s 532ms/step - loss: 1.2032 - accuracy: 0.6235 - val_loss: 1.9946 - val_accuracy: 0.4830
# Epoch 17/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.699660152931181
# Train - Acurácia 2:  0.9556782781081846
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8956916099773242
# 111/111 [==============================] - 59s 531ms/step - loss: 1.0871 - accuracy: 0.6587 - val_loss: 1.9425 - val_accuracy: 0.4864
# Epoch 18/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7131124327386009
# Train - Acurácia 2:  0.9555366751628434
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 531ms/step - loss: 1.0304 - accuracy: 0.6737 - val_loss: 2.0111 - val_accuracy: 0.4932
# Epoch 19/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7197677711696403
# Train - Acurácia 2:  0.9538374398187482
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8888888888888888
# 111/111 [==============================] - 59s 531ms/step - loss: 0.9440 - accuracy: 0.6992 - val_loss: 2.1334 - val_accuracy: 0.4785
# Epoch 20/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7609742282639479
# Train - Acurácia 2:  0.9566694987255735
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 531ms/step - loss: 0.8642 - accuracy: 0.7247 - val_loss: 2.1179 - val_accuracy: 0.4921
# Epoch 21/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.7999150382327952
# Train - Acurácia 2:  0.9704049844236761
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4909297052154195
# validation - Acurácia 2:  0.8934240362811792
# 111/111 [==============================] - 59s 532ms/step - loss: 0.7949 - accuracy: 0.7482 - val_loss: 2.1821 - val_accuracy: 0.4909
# Epoch 22/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.820730671197961
# Train - Acurácia 2:  0.9794675729255169
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48299319727891155
# validation - Acurácia 2:  0.9002267573696145
# 111/111 [==============================] - 59s 531ms/step - loss: 0.7060 - accuracy: 0.7768 - val_loss: 2.2507 - val_accuracy: 0.4830
# Epoch 23/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8324837156612858
# Train - Acurácia 2:  0.9769187199093741
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47619047619047616
# validation - Acurácia 2:  0.8968253968253969
# 111/111 [==============================] - 59s 531ms/step - loss: 0.6292 - accuracy: 0.7984 - val_loss: 2.2982 - val_accuracy: 0.4762
# Epoch 24/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8382894364202775
# Train - Acurácia 2:  0.9813084112149533
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47052154195011336
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 531ms/step - loss: 0.5905 - accuracy: 0.8142 - val_loss: 2.4526 - val_accuracy: 0.4705
# Epoch 25/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.861653922401586
# Train - Acurácia 2:  0.9822996318323421
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4852607709750567
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 530ms/step - loss: 0.5573 - accuracy: 0.8267 - val_loss: 2.3773 - val_accuracy: 0.4853
# Epoch 26/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8530161427357689
# Train - Acurácia 2:  0.9790427640894931
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47845804988662133
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 530ms/step - loss: 0.5020 - accuracy: 0.8411 - val_loss: 2.4639 - val_accuracy: 0.4785
# Epoch 27/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.883743981874823
# Train - Acurácia 2:  0.9847068819031436
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 530ms/step - loss: 0.4444 - accuracy: 0.8577 - val_loss: 2.5113 - val_accuracy: 0.4898
# Epoch 28/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8895497026338148
# Train - Acurácia 2:  0.9879637496459927
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.49206349206349204
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 530ms/step - loss: 0.4191 - accuracy: 0.8653 - val_loss: 2.5840 - val_accuracy: 0.4921
# Epoch 29/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.8855848201642594
# Train - Acurácia 2:  0.9852732936845087
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.891156462585034
# 111/111 [==============================] - 59s 530ms/step - loss: 0.4191 - accuracy: 0.8651 - val_loss: 2.6528 - val_accuracy: 0.4807
# Epoch 30/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9078164825828378
# Train - Acurácia 2:  0.9844236760124611
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4943310657596372
# validation - Acurácia 2:  0.8900226757369615
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3915 - accuracy: 0.8781 - val_loss: 2.5214 - val_accuracy: 0.4943
# Epoch 31/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9148966298499008
# Train - Acurácia 2:  0.991928632115548
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3436 - accuracy: 0.8853 - val_loss: 2.6857 - val_accuracy: 0.4977
# Epoch 32/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9238176154064005
# Train - Acurácia 2:  0.9939110733503257
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5204081632653061
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3068 - accuracy: 0.9012 - val_loss: 2.6203 - val_accuracy: 0.5204
# Epoch 33/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.924667233078448
# Train - Acurácia 2:  0.9937694704049844
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4988662131519274
# validation - Acurácia 2:  0.8979591836734694
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3214 - accuracy: 0.8954 - val_loss: 2.5812 - val_accuracy: 0.4989
# Epoch 34/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9280657037666383
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5113378684807256
# validation - Acurácia 2:  0.8775510204081632
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2922 - accuracy: 0.9014 - val_loss: 2.6737 - val_accuracy: 0.5113
# Epoch 35/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9188615123194562
# Train - Acurácia 2:  0.991928632115548
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47959183673469385
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 530ms/step - loss: 0.3035 - accuracy: 0.8978 - val_loss: 2.8092 - val_accuracy: 0.4796
# Epoch 36/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9301897479467572
# Train - Acurácia 2:  0.994619088077032
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5056689342403629
# validation - Acurácia 2:  0.8945578231292517
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2856 - accuracy: 0.9014 - val_loss: 2.7304 - val_accuracy: 0.5057
# Epoch 37/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9280657037666383
# Train - Acurácia 2:  0.9930614556782781
# 14/14 [==============================] - 1s 75ms/step
# Validation - Acurácia 0:  0.5
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 531ms/step - loss: 0.2873 - accuracy: 0.9046 - val_loss: 2.8301 - val_accuracy: 0.5000
# Epoch 38/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9361370716510904
# Train - Acurácia 2:  0.9951854998583971
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5045351473922902
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2507 - accuracy: 0.9112 - val_loss: 2.8607 - val_accuracy: 0.5045
# Epoch 39/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9369866893231379
# Train - Acurácia 2:  0.9960351175304446
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4977324263038549
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2399 - accuracy: 0.9166 - val_loss: 2.9818 - val_accuracy: 0.4977
# Epoch 40/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9371282922684792
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5022675736961452
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2315 - accuracy: 0.9187 - val_loss: 2.9744 - val_accuracy: 0.5023
# Epoch 41/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9379779099405268
# Train - Acurácia 2:  0.9956103086944208
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.5090702947845805
# validation - Acurácia 2:  0.8877551020408163
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2192 - accuracy: 0.9207 - val_loss: 2.9880 - val_accuracy: 0.5091
# Epoch 42/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9242424242424242
# Train - Acurácia 2:  0.9950438969130558
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4931972789115646
# validation - Acurácia 2:  0.8854875283446711
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2159 - accuracy: 0.9228 - val_loss: 3.0431 - val_accuracy: 0.4932
# Epoch 43/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.935429056924384
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8752834467120182
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2256 - accuracy: 0.9216 - val_loss: 3.0899 - val_accuracy: 0.4898
# Epoch 44/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9320305862361937
# Train - Acurácia 2:  0.9954687057490795
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8820861678004536
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2212 - accuracy: 0.9228 - val_loss: 3.0118 - val_accuracy: 0.4864
# Epoch 45/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9340130274709714
# Train - Acurácia 2:  0.9953271028037384
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8832199546485261
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2325 - accuracy: 0.9159 - val_loss: 3.0195 - val_accuracy: 0.4898
# Epoch 46/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9318889832908525
# Train - Acurácia 2:  0.9950438969130558
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4897959183673469
# validation - Acurácia 2:  0.8809523809523809
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2370 - accuracy: 0.9148 - val_loss: 3.0744 - val_accuracy: 0.4898
# Epoch 47/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9228263947890116
# Train - Acurácia 2:  0.9916454262248655
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.47732426303854875
# validation - Acurácia 2:  0.8639455782312925
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2450 - accuracy: 0.9152 - val_loss: 3.0044 - val_accuracy: 0.4773
# Epoch 48/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9289153214386859
# Train - Acurácia 2:  0.9949022939677146
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48639455782312924
# validation - Acurácia 2:  0.8696145124716553
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2466 - accuracy: 0.9112 - val_loss: 2.9217 - val_accuracy: 0.4864
# Epoch 49/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9327386009629001
# Train - Acurácia 2:  0.9941942792410082
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.48072562358276644
# validation - Acurácia 2:  0.8798185941043084
# 111/111 [==============================] - 59s 529ms/step - loss: 0.2131 - accuracy: 0.9228 - val_loss: 2.9810 - val_accuracy: 0.4807
# Epoch 50/50
# 111/111 [==============================] - 8s 76ms/step
# Train - Acurácia 0:  0.9364202775417728
# Train - Acurácia 2:  0.9957519116397621
# 14/14 [==============================] - 1s 76ms/step
# Validation - Acurácia 0:  0.4886621315192744
# validation - Acurácia 2:  0.8741496598639455
# 111/111 [==============================] - 59s 530ms/step - loss: 0.2059 - accuracy: 0.9230 - val_loss: 3.1026 - val_accuracy: 0.4887
# CPU times: user 52min 14s, sys: 1min 23s, total: 53min 37s
# Wall time: 49min 15s

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = accuracy2_train
val_acc  = accuracy2_validation


epochs   = range(len(acc)) # Get number of epochs
epochs2 = range(len(val_acc))

plt.plot  ( epochs,     acc, label='Treinamento - Acurácia 2')
plt.plot  ( epochs2, val_acc, label='Validação - Acurácia 2' )
plt.title ('Acurácia 2 - Treinamento e Validação - k='+'5')
plt.xlabel('Épocas')
plt.ylabel('Acurácia 2')
plt.legend()
plt.savefig('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k5'+'.pdf', format='pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/acc2_'+'k5',acc)
np.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/val_acc2_'+'k5',val_acc)

# %%
model.save('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k5')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Escalograma with unsupported characters which will be renamed to escalograma in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.

# %%
model = keras.models.load_model('/content/drive/MyDrive/Resultados/mexh_40_kfold/mexh_40_kfold_'+'k5')

# %% [markdown]
# ### Training Results

# %%
train_predictions = model.predict(images_train_ds, batch_size=config.BS, steps=steps_per_epoch_predict, verbose=1)
print(train_predictions.shape)
arg_max = np.argmax(train_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = train_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            train_predictions[i][j]=1
        else:
            train_predictions[i][j]=0 
mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

train_pred_new = mlb.inverse_transform(train_predictions)
train_pred_new = np.array(train_pred_new, int)
train_pred_new = np.reshape(train_pred_new, (train_pred_new.size,))

print(train_pred_new.shape)
print(labels_train_true.shape)
# Out:
# 111/111 [==============================] - 9s 76ms/step
# (7062, 140)
# (7062,)
# (7062,)

# %%
utilities.MakeGraphicPredictions(labels_train_true, train_pred_new, 'Previsões do Modelo - Conjunto de Treinamento mexh_40 k=5', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_train_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_train_true, train_pred_new)
acc1 = utilities.acuracia1(labels_train_true, train_pred_new)
acc2 = utilities.acuracia2(labels_train_true, train_pred_new)

experimento = 'train_mexh_40_k=5'
resultados = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

print(resultados)
# Out:
#          Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0  train_mexh_40_k=5     0.93642    0.995327     0.995752

# %% [markdown]
# ### Validation Results

# %%
num_images_val = len(glob(VAL_DATASET + '/*/*'))
validation_steps = math.ceil(num_images_val/config.BS)

val_predictions = model.predict(images_validation_ds, batch_size=config.BS, steps=validation_steps, verbose=1)
print(val_predictions.shape)
arg_max = np.argmax(val_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = val_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            val_predictions[i][j]=1
        else:
            val_predictions[i][j]=0  

print(val_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

val_pred_new = mlb.inverse_transform(val_predictions)
val_pred_new = np.array(val_pred_new, int)
val_pred_new = np.reshape(val_pred_new, (val_pred_new.size,))

print(val_pred_new.shape)
print(labels_validation_true.shape)
# Out:
# 14/14 [==============================] - 1s 76ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_validation_true, val_pred_new, 'Previsões do Modelo - Conjunto de Validação mexh_40 k=5', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_validation_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_validation_true, val_pred_new)
acc1 = utilities.acuracia1(labels_validation_true, val_pred_new)
acc2 = utilities.acuracia2(labels_validation_true, val_pred_new)

experimento = 'validation_mexh_40_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=5    0.936420    0.995327     0.995752
# 1  validation_mexh_40_k=5    0.488662    0.848073     0.874150

# %% [markdown]
# ### Test Results

# %%
num_images_test = len(glob(TEST_DATASET + '/*/*'))
test_steps = math.ceil(num_images_test/config.BS)

test_predictions = model.predict(images_test_ds, batch_size=config.BS, steps=test_steps, verbose=1)
print(test_predictions.shape)
arg_max = np.argmax(test_predictions, axis=1)
#print(arg_max)
#print(arg_max)
shape = test_predictions.shape
#print(shape[0])
for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        if (j==arg_max[i]):
            test_predictions[i][j]=1
        else:
            test_predictions[i][j]=0  

print(test_predictions.shape)

mlb = MultiLabelBinarizer()

dicionario = mlb.fit_transform([classes])
#print(mlb.classes_)

test_pred_new = mlb.inverse_transform(test_predictions)
test_pred_new = np.array(test_pred_new, int)
test_pred_new = np.reshape(test_pred_new, (test_pred_new.size,))

print(test_pred_new.shape)
print(labels_test_true.shape)
# Out:
# 14/14 [==============================] - 1s 75ms/step
# (882, 140)
# (882, 140)
# (882,)
# (882,)

# %%
utilities.MakeGraphicPredictions(labels_test_true, test_pred_new, 'Previsões do Modelo - Conjunto de Teste mexh_40 k=5', '/content/drive/MyDrive/Resultados/mexh_40_kfold/prev_test_'+'k5'+'.pdf')

# %%
acc0 = utilities.acuracia0(labels_test_true, test_pred_new)
acc1 = utilities.acuracia1(labels_test_true, test_pred_new)
acc2 = utilities.acuracia2(labels_test_true, test_pred_new)

experimento = 'test_mexh_40_k=5'
newline = pd.DataFrame([[experimento, acc0, acc1, acc2]], columns=['Experimento','Acurácia 0', 'Acurácia 1', 'Acuarária 2'])

resultados = resultados.append(newline, ignore_index=True)

print(resultados)
# Out:
#               Experimento  Acurácia 0  Acurácia 1  Acuarária 2
# 0       train_mexh_40_k=5    0.936420    0.995327     0.995752
# 1  validation_mexh_40_k=5    0.488662    0.848073     0.874150
# 2        test_mexh_40_k=5    0.500000    0.845805     0.880952

# %%
resultados.to_excel("/content/drive/MyDrive/Resultados/mexh_40_kfold/Resultados_mexh_40_k5.xlsx", index=False)
